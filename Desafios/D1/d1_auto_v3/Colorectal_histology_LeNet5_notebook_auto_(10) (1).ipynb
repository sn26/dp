# %% [markdown]
# # Colorectal histology dataset with LeNet 5

# %% [markdown]
# # Preview: Neural Network examples with `tf.keras`
#
# - `tf.keras` Software (http://keras.io/);
#
# - Visual example of LeNet-5 (http://yann.lecun.com/exdb/lenet/) using MNIST digits dataset;
#
# - Examples with common neural network topologies (https://machinelearningmastery.com/tensorflow-tutorial-deep-learning-with-tf-keras/).

# %% [markdown]
# ## Colorectal histology
#
# Methods to diagnose colorectal using histology images (<https://zenodo.org/record/53169#.XGZemKwzbmG>, <https://www.tensorflow.org/datasets/catalog/colorectal_histology>)
#
# In this case, the purpose is to classify the type of histology in a given image in the following categories:
#
# - 0: TUMOR
# - 1: STROMA
# - 2: COMPLEX
# - 3: LYMPHO
# - 4: DEBRIS
# - 5: MUCOSA
# - 6: ADIPOSE
# - 7: EMPTY

# %% [markdown]
# ## Local instalation (option 1)

# %% [markdown]
# Install the following Python packages to run this notebook

# %% [markdown]
# `pip install pip -U`
#
# `pip install tensorflow jupyter`

# %% [markdown]
# ## Google Colab (option 2)

# %% [markdown]
# [Google Colab](https://colab.research.google.com/) is a research project created to help disseminate machine learning education and research. It's a `Jupyter notebook` environment that requires no setup to use and runs entirely in the cloud.
#
# Colaboratory notebooks are stored in [Google Drive](https://drive.google.com) and can be shared just as you would with Google Docs or Sheets. Colaboratory is free to use.
#
# For more information, see our [FAQ](https://research.google.com/colaboratory/faq.html).

# %% [markdown]
# ### How install extra packages
# Google Colab installs a series of basic packages if we need any additional package just install it.

# %%
# !pip install -q keras sklearn

# %% [markdown]
# ## Import packages

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import collections

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn import metrics

import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow import keras
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img, ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

from scipy.stats import wilcoxon
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Define global constants

# %% [markdown]
# Lets start with a few epochs to test learning network parameters

# %%
#Function to set the number of epochs and batches
def set_epochs_batches(epochs_number , batches ): 
  epochs= epochs_number
  batch_size = batches
  return

# %%
batch_size = 32 #Number of training examples
nb_classes = 8  #or 8
epochs = 5 #Number of iterations // Passes the entire training has completed
# Scaling input image to theses dimensions
img_rows, img_cols = 32, 32

# %% [markdown]
# ## Load image database

# %%
def format_example(image):
    image = tf.cast(image, tf.float32)
    # Normalize the pixel values
    image = image / 255.0
    # Resize the image
    image = tf.image.resize(image, (img_rows, img_cols))
    return image


def load_data(name="colorectal_histology"):
  train_ds = tfds.load(name, split=tfds.Split.TRAIN, batch_size=-1)
  train_ds['image'] = tf.map_fn(format_example, train_ds['image'], dtype=tf.float32)
  numpy_ds = tfds.as_numpy(train_ds)
  X, y = numpy_ds['image'], numpy_ds['label']

  return np.array(X), np.array(y)

# %% [markdown]
# ## Plot images

# %%
def plot_symbols(X,y,n=15):
    index = np.random.randint(len(y), size=n)
    plt.figure(figsize=(25, 2))
    for i in np.arange(n):
        ax = plt.subplot(1,n,i+1)
        plt.imshow(X[index[i],:,:,:])
        plt.gray()
        ax.set_title(f'{y[index[i]]}-{index[i]}')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %% [markdown]
# ## Build LeNet5 structure
#
# <center><img src="https://www.dlsi.ua.es/~juanra/UA/curso_verano_DL/images/LeNet5.jpg"></center>

# %%
#
# Build an ANN structure - LeNet5
#
# The model will receive the activation functions
def cnn_model(activation_functions):
    #
    # Neural Network Structure
    #
    
    model = Sequential()
    
    
    model.add(layers.Conv2D(6, (5, 5))) #Output dimensionality, kernel_size (Height, width)
    model.add(layers.Activation(activation_functions[0])) #Applies an activation function to an output
    model.add(layers.MaxPooling2D(pool_size=(2, 2))) #Getting a size 2x2 for the window
    
    model.add(layers.Conv2D(16, (5, 5)))
    model.add(layers.Activation(activation_functions[1]))
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
        
    model.add(layers.Flatten())
    
    model.add(layers.Dense(120)) #dense(Dimensionality of the output space)
    model.add(layers.Activation(activation_functions[2]))
    
    model.add(layers.Dense(84))
    model.add(layers.Activation(activation_functions[3]))
    
    model.add(layers.Dense(nb_classes))
    model.add(layers.Activation(activation_functions[4]))

    return model

# %% [markdown]
# ## Start to run the program

# %% [markdown]
# ### Load data

# %%
##################################################################################
# Main program

X, y = load_data()
print("Los resultados que hemos obtenido, son los siguientes")

print(X.shape, 'train samples')
print(img_rows,'x', img_cols, 'image size')
print(epochs,'epochs')
# Out:
# Downloading and preparing dataset colorectal_histology/2.0.0 (download: 246.14 MiB, generated: Unknown size, total: 246.14 MiB) to /root/tensorflow_datasets/colorectal_histology/2.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Extraction completed...', max=1.0, styl…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/colorectal_histology/2.0.0.incompleteIVPEWB/colorectal_histology-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=5000.0), HTML(value='')))
# Dataset colorectal_histology downloaded and prepared to /root/tensorflow_datasets/colorectal_histology/2.0.0. Subsequent calls will reuse this data.
# Los resultados que hemos obtenido, son los siguientes
# (5000, 32, 32, 3) train samples
# 32 x 32 image size
# 5 epochs

# %% [markdown]
# Only for binary classification. All number of classes greater than 0 will be set to 1.

# %%
if nb_classes==2:
  y[y>0] = 1

# %% [markdown]
# ### Let to see examples of the dataset

# %%
plot_symbols(X, y, 2)

# %% [markdown]
# ## Number of examples per class

# %%
collections.Counter(y)
# Out:
# Counter({0: 625, 1: 625, 2: 625, 3: 625, 4: 625, 5: 625, 6: 625, 7: 625})

# %% [markdown]
# ## Split examples in training/test sets

# %% [markdown]
# #Fucntion to create some models with different epochs in order to compare each other and get the best one

# %%
import time
#Primero, cambiaremos las funciones de activación
activation_functions = []
activation_functions.append(["tanh", "tanh", "tanh", "tanh", "softmax"] )
activation_functions.append(["sigmoid", "sigmoid" , "sigmoid", "sigmoid" , "softmax"])
activation_functions.append( ["relu", "relu", "relu", "relu", "softmax"])
activation_functions.append( ["tanh", "tanh", "tanh", "tanh", "relu"])
activation_functions.append( ["sigmoid", "sigmoid", "sigmoid", "sigmoid", "relu"])
activation_functions.append( ["relu", "relu", "relu", "relu", "relu"])
optimizers = ['adam' , 'sgd' , 'adadelta'] 
augmentation = [True, False]
best = 0
best_optimizer = ''
with_data_augmentation = False
best_function = []
best_epoch_number = 0
best_batch_number = 0

# %%
def get_best_optimizer(data_augmentation): 
  optimizers = ['adam' , 'sgd' , 'adadelta'] 
  best_acc = 0
  best_auc=0
  best_optimizer = ''
  with_data_augmentation = True
  best_function = ["relu", "relu", "relu", "relu", "softmax"]
  best_epoch_number = 0
  best_batch_number = 0
  set_epochs_batches(8,32 ) #Probamos cuál es el mejor modelo con las mismas épocas y batches
  best_epoch = 8
  best_batch_number= 32
  last_acc_percent_per_fold= []
  last_auc_percent_per_fold=[]
  for optimizer_i in optimizers:
    epochs = 8
    batch_size = 32
    #set_epochs_batches(epoch_i , batch_i ) 
    print("The new size is " , str(epochs) , ", " , batch_size)
    #Getting the result
    acc_per_fold, loss_per_fold, auc_per_fold, acc_percent_per_fold, auc_percent_per_fold, model = cross_validation(10 , best_function , optimizer_i , True , 32 , 8)
    plt.plot(range(len( auc_percent_per_fold)) , auc_percent_per_fold , label=best_function[0] + ", " +  best_function[4] + " [ " + str(8) + ", " + str(32) + ", " + str(optimizer_i) + ", " + str(True)  +" ]")
    #Getting the media_value
    total_acc = 0
    total_auc = 0
    for i in range(len(acc_per_fold)): 
      total_acc = total_acc + acc_per_fold[i]
      total_auc = total_auc + auc_per_fold[i]

    media_value_acc = total_acc/len(acc_per_fold)
    media_value_auc = total_auc/len(auc_per_fold)
    print("The media value acc is  " , media_value_acc , "And the value auc is " , media_value_auc , "And the activation optimizer is " , optimizer_i)
    if media_value_acc > best_acc and media_value_auc > best_auc: 
      if len(last_acc_percent_per_fold)>0: 
        wilcox_v_acc, p_val_acc = wilcoxon(acc_percent_per_fold , last_acc_percent_per_fold)  
        wilcox_v_auc, p_val_auc = wilcoxon(auc_percent_per_fold, last_auc_percent_per_fold)
        if p_val_acc<0.05 and p_val_auc < 0.05: #Rechazamos la hipótesis nula
          last_acc_percent_per_fold = acc_percent_per_fold
          last_auc_percent_per_fold = auc_percent_per_fold
          best_acc = media_value_acc
          best_auc = media_value_auc
          best_epoch_number = 8
          best_batch_number = 32
          best_optimizer =optimizer_i
      else: 
        last_acc_percent_per_fold = acc_percent_per_fold
        last_auc_percent_per_fold = auc_percent_per_fold
        best_acc = media_value_acc
        best_auc = media_value_auc
        best_epoch_number = 8
        best_batch_number = 32
        best_optimizer =optimizer_i

    
  print("AND WITH THE OPTIMIZER " + best_optimizer)
  print("THE BEST MODEL IS " , best_function )
  print("WITH A EPOCH_NUMBER OF " , best_epoch_number , " AND A BATCH SIZE OF " , best_batch_number )
  print("BEST MEDIA AUC " ,best_auc)
  print("BEST MEDIA ACC " , best_acc)
  print("AND WITH DATA_AUGMENTATION "  , with_data_augmentation )
  print("FIRST MODEL GRAPHIC")
  plt.ylabel('Aciertos')
  plt.xlabel('Fold')
  plt.legend()
  return

# %%
def get_best_epoch(data_augmentation , optimizer_i ):
  best_acc = 0
  best_auc=0
  best_optimizer = ''
  with_data_augmentation = True
  best_function = ["relu", "relu", "relu", "relu", "softmax"]
  best_epoch_number = 0
  best_batch_number = 0
  set_epochs_batches(8,32 ) #Probamos cuál es el mejor modelo con las mismas épocas y batches
  best_epoch = 8
  best_batch_number= 32
  last_acc_percent_per_fold= []
  last_auc_percent_per_fold=[]
  for epoch_i  in range(5,12): 
    epochs = epoch_i
    batch_size = 32
    #set_epochs_batches(epoch_i , batch_i ) 
    print("The new size is " , str(epochs) , ", " , batch_size)
    #Getting the result
    acc_per_fold, loss_per_fold, auc_per_fold, acc_percent_per_fold, auc_percent_per_fold, model = cross_validation(10 , best_function , 'adam' , True , 32 , epoch_i)
    plt.plot(range(len( auc_percent_per_fold)) , auc_percent_per_fold , label=best_function[0] + ", " +  best_function[4] + " [ " + str(epoch_i) + ", " + str(32) + ", " + str(optimizer_i) + ", " + str(True)  +" ]")
     #Getting the media_value
    total_acc = 0
    total_auc = 0
    for i in range(len(acc_per_fold)): 
      total_acc = total_acc + acc_per_fold[i]
      total_auc = total_auc + auc_per_fold[i]

    media_value_acc = total_acc/len(acc_per_fold)
    media_value_auc = total_auc/len(auc_per_fold)
    print("The media value acc is  " , media_value_acc , "And the value auc is " , media_value_auc , "And the activation epoch is " , epoch_i)
    if media_value_acc > best_acc and media_value_auc > best_auc: 
      if len(last_acc_percent_per_fold)>0: 
        wilcox_v_acc, p_val_acc = wilcoxon(acc_percent_per_fold , last_acc_percent_per_fold)  
        wilcox_v_auc, p_val_auc = wilcoxon(auc_percent_per_fold, last_auc_percent_per_fold)
        print("VALUES ACC " , wilcox_v_acc , p_val_acc )
        print("VALUES AUC ", wilcox_v_auc, p_val_auc)
        if p_val_acc<0.05 and p_val_auc < 0.05: #Rechazamos la hipótesis nula
          last_acc_percent_per_fold = acc_percent_per_fold
          last_auc_percent_per_fold = auc_percent_per_fold
          best_acc = media_value_acc
          best_auc = media_value_auc
          best_epoch_number = epoch_i
          best_batch_number = 32
          best_optimizer ='adam'
      else: 
        
        last_acc_percent_per_fold = acc_percent_per_fold
        last_auc_percent_per_fold = auc_percent_per_fold
        best_acc = media_value_acc
        best_auc = media_value_auc
        best_epoch_number = epoch_i
        best_batch_number = 32
        best_optimizer =optimizer_i

    
  print("AND WITH THE OPTIMIZER " + best_optimizer)
  print("THE BEST MODEL IS " , best_function )
  print("WITH A EPOCH_NUMBER OF " , best_epoch_number , " AND A BATCH SIZE OF " , best_batch_number )
  print("BEST MEDIA AUC " ,best_auc)
  print("BEST MEDIA ACC " , best_acc)
  print("AND WITH DATA_AUGMENTATION "  , with_data_augmentation )
  print("FIRST MODEL GRAPHIC")
  plt.ylabel('Aciertos')
  plt.xlabel('Fold')
  plt.legend()
  return

# %%
def get_best_activation_function(data_augmentation):
  activation_functions = []
  activation_functions.append(["sigmoid", "sigmoid" , "sigmoid", "sigmoid" , "softmax"])
  activation_functions.append( ["relu", "relu", "relu", "relu", "softmax"])
  activation_functions.append(["tanh", "tanh", "tanh", "tanh", "softmax"] )
  
  
  best_acc = 0
  best_auc=0
  best_optimizer = ''
  with_data_augmentation = True
  best_function = ["tanh", "tanh", "tanh", "tanh", "softmax"]
  best_epoch_number = 0
  best_batch_number = 0
  set_epochs_batches(8,32 ) #Probamos cuál es el mejor modelo con las mismas épocas y batches
  best_epoch = 8
  best_batch_number= 32
  last_acc_percent_per_fold= []
  last_auc_percent_per_fold=[]
 
  #Pondremos el optimizador de adam
  for activation_function in activation_functions: 
    acc_per_fold, loss_per_fold, auc_per_fold, acc_percent_per_fold, auc_percent_per_fold, model = cross_validation(10 , activation_function , "adam" , data_augmentation , 32,8)
    print("Sacando la gráfica del modelo")
    plt.plot(range(len( auc_percent_per_fold)) , auc_percent_per_fold , label=str(activation_function[0]) + ", " +  activation_function[4] )
    #Getting the media_value
    total_acc = 0
    total_auc = 0
    for i in range(len(acc_per_fold)): 
      total_acc = total_acc + acc_per_fold[i]
      total_auc = total_auc + auc_per_fold[i]

    media_value_acc = total_acc/len(acc_per_fold)
    
    media_value_auc = total_auc/len(auc_per_fold)
    print("The media value acc is  " , media_value_acc , "And the value auc is " , media_value_auc , "And the activation function is " , activation_function)
    if media_value_acc > best_acc and media_value_auc > best_auc: 
      if len(last_acc_percent_per_fold)>0: 
        wilcox_v_acc, p_val_acc = wilcoxon(acc_percent_per_fold , last_acc_percent_per_fold)  
        wilcox_v_auc, p_val_auc = wilcoxon(auc_percent_per_fold, last_auc_percent_per_fold)
        if p_val_acc<0.05 and p_val_auc < 0.05: #Rechazamos la hipótesis nula
          last_acc_percent_per_fold = acc_percent_per_fold
          last_auc_percent_per_fold = auc_percent_per_fold
          best_function = activation_function
          best_acc = media_value_acc
          best_auc = media_value_auc
          best_epoch_number = 8
          best_batch_number = 32
          best_optimizer ='adam'
      else: 
        last_acc_percent_per_fold = acc_percent_per_fold
        last_auc_percent_per_fold = auc_percent_per_fold
        best_function = activation_function
        best_acc = media_value_acc
        best_auc = media_value_auc
        best_epoch_number = 8
        best_batch_number = 32
        best_optimizer ='adam'

    
  print("AND WITH THE OPTIMIZER " + best_optimizer)
  print("THE BEST MODEL IS " , best_function )
  print("WITH A EPOCH_NUMBER OF " , best_epoch_number , " AND A BATCH SIZE OF " , best_batch_number )
  print("BEST MEDIA AUC " ,best_auc)
  print("BEST MEDIA ACC " , best_acc)
  print("AND WITH DATA_AUGMENTATION "  , with_data_augmentation )
  print("FIRST MODEL GRAPHIC")
  plt.ylabel('Aciertos')
  plt.xlabel('Fold')
  plt.legend()
  return

# %%
get_best_activation_function(False)
# Out:
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.2077 - accuracy: 0.9111 - val_loss: 0.3554 - val_accuracy: 0.8566
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2821 - accuracy: 0.8820
# loss: 0.28 acc: 0.88
# Predictions Counter({1: 497, 0: 3})
#
# Confusion matrix
# [[  3  59]
#  [  0 438]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       1.00      0.05      0.09        62
#      HEALTHY       0.88      1.00      0.94       438
#
#     accuracy                           0.88       500
#    macro avg       0.94      0.52      0.51       500
# weighted avg       0.90      0.88      0.83       500
#
# AUC 0.8940
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.1928 - accuracy: 0.9172 - val_loss: 0.3535 - val_accuracy: 0.8716
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3110 - accuracy: 0.8940
# loss: 0.31 acc: 0.89
# Predictions Counter({1: 487, 0: 13})
#
# Confusion matrix
# [[ 11  51]
#  [  2 436]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.85      0.18      0.29        62
#      HEALTHY       0.90      1.00      0.94       438
#
#     accuracy                           0.89       500
#    macro avg       0.87      0.59      0.62       500
# weighted avg       0.89      0.89      0.86       500
#
# AUC 0.8809
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.2077 - accuracy: 0.9184 - val_loss: 0.3031 - val_accuracy: 0.8743
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2339 - accuracy: 0.9060
# loss: 0.23 acc: 0.91
# Predictions Counter({1: 477, 0: 23})
#
# Confusion matrix
# [[ 19  43]
#  [  4 434]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.83      0.31      0.45        62
#      HEALTHY       0.91      0.99      0.95       438
#
#     accuracy                           0.91       500
#    macro avg       0.87      0.65      0.70       500
# weighted avg       0.90      0.91      0.89       500
#
# AUC 0.9163
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.2020 - accuracy: 0.9204 - val_loss: 0.3185 - val_accuracy: 0.8675
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2338 - accuracy: 0.9080
# loss: 0.23 acc: 0.91
# Predictions Counter({1: 470, 0: 30})
#
# Confusion matrix
# [[ 23  39]
#  [  7 431]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.77      0.37      0.50        62
#      HEALTHY       0.92      0.98      0.95       438
#
#     accuracy                           0.91       500
#    macro avg       0.84      0.68      0.72       500
# weighted avg       0.90      0.91      0.89       500
#
# AUC 0.9107
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.1853 - accuracy: 0.9250 - val_loss: 0.3264 - val_accuracy: 0.8511
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2923 - accuracy: 0.8640
# loss: 0.29 acc: 0.86
# Predictions Counter({1: 416, 0: 84})
#
# Confusion matrix
# [[ 39  23]
#  [ 45 393]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.46      0.63      0.53        62
#      HEALTHY       0.94      0.90      0.92       438
#
#     accuracy                           0.86       500
#    macro avg       0.70      0.76      0.73       500
# weighted avg       0.89      0.86      0.87       500
#
# AUC 0.8797
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.1843 - accuracy: 0.9249 - val_loss: 0.3648 - val_accuracy: 0.8452
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3079 - accuracy: 0.8620
# loss: 0.31 acc: 0.86
# Predictions Counter({1: 420, 0: 80})
#
# Confusion matrix
# [[ 37  26]
#  [ 43 394]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.46      0.59      0.52        63
#      HEALTHY       0.94      0.90      0.92       437
#
#     accuracy                           0.86       500
#    macro avg       0.70      0.74      0.72       500
# weighted avg       0.88      0.86      0.87       500
#
# AUC 0.8907
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.1723 - accuracy: 0.9266 - val_loss: 0.2629 - val_accuracy: 0.8832
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2143 - accuracy: 0.9080
# loss: 0.21 acc: 0.91
# Predictions Counter({1: 467, 0: 33})
#
# Confusion matrix
# [[ 25  38]
#  [  8 429]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.76      0.40      0.52        63
#      HEALTHY       0.92      0.98      0.95       437
#
#     accuracy                           0.91       500
#    macro avg       0.84      0.69      0.73       500
# weighted avg       0.90      0.91      0.90       500
#
# AUC 0.9270
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.1884 - accuracy: 0.9232 - val_loss: 0.3506 - val_accuracy: 0.8401
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3508 - accuracy: 0.8300
# loss: 0.35 acc: 0.83
# Predictions Counter({1: 406, 0: 94})
#
# Confusion matrix
# [[ 36  27]
#  [ 58 379]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.38      0.57      0.46        63
#      HEALTHY       0.93      0.87      0.90       437
#
#     accuracy                           0.83       500
#    macro avg       0.66      0.72      0.68       500
# weighted avg       0.86      0.83      0.84       500
#
# AUC 0.8452
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.1871 - accuracy: 0.9248 - val_loss: 0.2900 - val_accuracy: 0.8718
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2529 - accuracy: 0.9000
# loss: 0.25 acc: 0.90
# Predictions Counter({1: 473, 0: 27})
#
# Confusion matrix
# [[ 20  43]
#  [  7 430]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.74      0.32      0.44        63
#      HEALTHY       0.91      0.98      0.95       437
#
#     accuracy                           0.90       500
#    macro avg       0.82      0.65      0.69       500
# weighted avg       0.89      0.90      0.88       500
#
# AUC 0.8734
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 0 0 0]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The new size is  3934
# Y TRAIN [0 0 0 ... 0 0 0]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.1913 - accuracy: 0.9219 - val_loss: 0.2907 - val_accuracy: 0.8845
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2685 - accuracy: 0.8780
# loss: 0.27 acc: 0.88
# Predictions Counter({1: 482, 0: 18})
#
# Confusion matrix
# [[ 10  53]
#  [  8 429]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.56      0.16      0.25        63
#      HEALTHY       0.89      0.98      0.93       437
#
#     accuracy                           0.88       500
#    macro avg       0.72      0.57      0.59       500
# weighted avg       0.85      0.88      0.85       500
#
# AUC 0.8705
# Sacando la gráfica del modelo
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.6687 - accuracy: 0.5613 - val_loss: 0.4712 - val_accuracy: 0.7486
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4393 - accuracy: 0.8000
# loss: 0.44 acc: 0.80
# Predictions Counter({1: 446, 0: 54})
#
# Confusion matrix
# [[  8  54]
#  [ 46 392]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.15      0.13      0.14        62
#      HEALTHY       0.88      0.89      0.89       438
#
#     accuracy                           0.80       500
#    macro avg       0.51      0.51      0.51       500
# weighted avg       0.79      0.80      0.79       500
#
# AUC 0.6527
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.5364 - accuracy: 0.6886 - val_loss: 0.5473 - val_accuracy: 0.7527
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4467 - accuracy: 0.8040
# loss: 0.45 acc: 0.80
# Predictions Counter({1: 442, 0: 58})
#
# Confusion matrix
# [[ 11  51]
#  [ 47 391]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.19      0.18      0.18        62
#      HEALTHY       0.88      0.89      0.89       438
#
#     accuracy                           0.80       500
#    macro avg       0.54      0.54      0.54       500
# weighted avg       0.80      0.80      0.80       500
#
# AUC 0.6996
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.5730 - accuracy: 0.6731 - val_loss: 0.5307 - val_accuracy: 0.7514
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4543 - accuracy: 0.7940
# loss: 0.45 acc: 0.79
# Predictions Counter({1: 439, 0: 61})
#
# Confusion matrix
# [[ 10  52]
#  [ 51 387]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.16      0.16      0.16        62
#      HEALTHY       0.88      0.88      0.88       438
#
#     accuracy                           0.79       500
#    macro avg       0.52      0.52      0.52       500
# weighted avg       0.79      0.79      0.79       500
#
# AUC 0.6762
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.5915 - accuracy: 0.6497 - val_loss: 0.5066 - val_accuracy: 0.7363
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3967 - accuracy: 0.8040
# loss: 0.40 acc: 0.80
# Predictions Counter({1: 412, 0: 88})
#
# Confusion matrix
# [[ 26  36]
#  [ 62 376]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.30      0.42      0.35        62
#      HEALTHY       0.91      0.86      0.88       438
#
#     accuracy                           0.80       500
#    macro avg       0.60      0.64      0.62       500
# weighted avg       0.84      0.80      0.82       500
#
# AUC 0.7711
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.6183 - accuracy: 0.6334 - val_loss: 0.5865 - val_accuracy: 0.6981
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4495 - accuracy: 0.7840
# loss: 0.45 acc: 0.78
# Predictions Counter({1: 404, 0: 96})
#
# Confusion matrix
# [[ 25  37]
#  [ 71 367]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.26      0.40      0.32        62
#      HEALTHY       0.91      0.84      0.87       438
#
#     accuracy                           0.78       500
#    macro avg       0.58      0.62      0.59       500
# weighted avg       0.83      0.78      0.80       500
#
# AUC 0.7559
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.5672 - accuracy: 0.6868 - val_loss: 0.7261 - val_accuracy: 0.6536
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5524 - accuracy: 0.7360
# loss: 0.55 acc: 0.74
# Predictions Counter({1: 345, 0: 155})
#
# Confusion matrix
# [[ 43  20]
#  [112 325]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.28      0.68      0.39        63
#      HEALTHY       0.94      0.74      0.83       437
#
#     accuracy                           0.74       500
#    macro avg       0.61      0.71      0.61       500
# weighted avg       0.86      0.74      0.78       500
#
# AUC 0.7939
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.5567 - accuracy: 0.7044 - val_loss: 0.6418 - val_accuracy: 0.6967
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5112 - accuracy: 0.7520
# loss: 0.51 acc: 0.75
# Predictions Counter({1: 397, 0: 103})
#
# Confusion matrix
# [[ 21  42]
#  [ 82 355]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.20      0.33      0.25        63
#      HEALTHY       0.89      0.81      0.85       437
#
#     accuracy                           0.75       500
#    macro avg       0.55      0.57      0.55       500
# weighted avg       0.81      0.75      0.78       500
#
# AUC 0.7038
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.5384 - accuracy: 0.7129 - val_loss: 0.5768 - val_accuracy: 0.7005
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5551 - accuracy: 0.7400
# loss: 0.56 acc: 0.74
# Predictions Counter({1: 391, 0: 109})
#
# Confusion matrix
# [[ 21  42]
#  [ 88 349]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.19      0.33      0.24        63
#      HEALTHY       0.89      0.80      0.84       437
#
#     accuracy                           0.74       500
#    macro avg       0.54      0.57      0.54       500
# weighted avg       0.80      0.74      0.77       500
#
# AUC 0.6761
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.5643 - accuracy: 0.6961 - val_loss: 0.6069 - val_accuracy: 0.6929
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6576 - accuracy: 0.6720
# loss: 0.66 acc: 0.67
# Predictions Counter({1: 359, 0: 141})
#
# Confusion matrix
# [[ 20  43]
#  [121 316]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.14      0.32      0.20        63
#      HEALTHY       0.88      0.72      0.79       437
#
#     accuracy                           0.67       500
#    macro avg       0.51      0.52      0.50       500
# weighted avg       0.79      0.67      0.72       500
#
# AUC 0.6214
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 0 0 0]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The new size is  3934
# Y TRAIN [0 0 0 ... 0 0 0]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.5704 - accuracy: 0.6931 - val_loss: 0.5745 - val_accuracy: 0.7272
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5624 - accuracy: 0.7120
# loss: 0.56 acc: 0.71
# Predictions Counter({1: 375, 0: 125})
#
# Confusion matrix
# [[ 22  41]
#  [103 334]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.18      0.35      0.23        63
#      HEALTHY       0.89      0.76      0.82       437
#
#     accuracy                           0.71       500
#    macro avg       0.53      0.56      0.53       500
# weighted avg       0.80      0.71      0.75       500
#
# AUC 0.6672
# Sacando la gráfica del modelo
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.1972 - accuracy: 0.9230 - val_loss: 0.2557 - val_accuracy: 0.8948
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2180 - accuracy: 0.9120
# loss: 0.22 acc: 0.91
# Predictions Counter({1: 470, 0: 30})
#
# Confusion matrix
# [[ 24  38]
#  [  6 432]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.80      0.39      0.52        62
#      HEALTHY       0.92      0.99      0.95       438
#
#     accuracy                           0.91       500
#    macro avg       0.86      0.69      0.74       500
# weighted avg       0.90      0.91      0.90       500
#
# AUC 0.9255
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.2347 - accuracy: 0.9007 - val_loss: 0.2979 - val_accuracy: 0.8634
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2782 - accuracy: 0.8960
# loss: 0.28 acc: 0.90
# Predictions Counter({1: 478, 0: 22})
#
# Confusion matrix
# [[ 16  46]
#  [  6 432]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.73      0.26      0.38        62
#      HEALTHY       0.90      0.99      0.94       438
#
#     accuracy                           0.90       500
#    macro avg       0.82      0.62      0.66       500
# weighted avg       0.88      0.90      0.87       500
#
# AUC 0.8472
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.2391 - accuracy: 0.9079 - val_loss: 0.3400 - val_accuracy: 0.8511
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2840 - accuracy: 0.8760
# loss: 0.28 acc: 0.88
# Predictions Counter({1: 500})
#
# Confusion matrix
# [[  0  62]
#  [  0 438]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        62
#      HEALTHY       0.88      1.00      0.93       438
#
#     accuracy                           0.88       500
#    macro avg       0.44      0.50      0.47       500
# weighted avg       0.77      0.88      0.82       500
#
# AUC 0.8638
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.2294 - accuracy: 0.9054 - val_loss: 0.3288 - val_accuracy: 0.8552
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2784 - accuracy: 0.8820
# loss: 0.28 acc: 0.88
# Predictions Counter({1: 495, 0: 5})
#
# Confusion matrix
# [[  4  58]
#  [  1 437]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.80      0.06      0.12        62
#      HEALTHY       0.88      1.00      0.94       438
#
#     accuracy                           0.88       500
#    macro avg       0.84      0.53      0.53       500
# weighted avg       0.87      0.88      0.84       500
#
# AUC 0.8823
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.2173 - accuracy: 0.9187 - val_loss: 0.3351 - val_accuracy: 0.8497
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2817 - accuracy: 0.8800
# loss: 0.28 acc: 0.88
# Predictions Counter({1: 496, 0: 4})
#
# Confusion matrix
# [[  3  59]
#  [  1 437]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.75      0.05      0.09        62
#      HEALTHY       0.88      1.00      0.94       438
#
#     accuracy                           0.88       500
#    macro avg       0.82      0.52      0.51       500
# weighted avg       0.86      0.88      0.83       500
#
# AUC 0.8703
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.2049 - accuracy: 0.9190 - val_loss: 0.3127 - val_accuracy: 0.8668
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2678 - accuracy: 0.8800
# loss: 0.27 acc: 0.88
# Predictions Counter({1: 491, 0: 9})
#
# Confusion matrix
# [[  6  57]
#  [  3 434]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.67      0.10      0.17        63
#      HEALTHY       0.88      0.99      0.94       437
#
#     accuracy                           0.88       500
#    macro avg       0.78      0.54      0.55       500
# weighted avg       0.86      0.88      0.84       500
#
# AUC 0.8794
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.2072 - accuracy: 0.9222 - val_loss: 0.3017 - val_accuracy: 0.8617
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2649 - accuracy: 0.8780
# loss: 0.26 acc: 0.88
# Predictions Counter({1: 498, 0: 2})
#
# Confusion matrix
# [[  2  61]
#  [  0 437]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       1.00      0.03      0.06        63
#      HEALTHY       0.88      1.00      0.93       437
#
#     accuracy                           0.88       500
#    macro avg       0.94      0.52      0.50       500
# weighted avg       0.89      0.88      0.82       500
#
# AUC 0.9159
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.1992 - accuracy: 0.9233 - val_loss: 0.3450 - val_accuracy: 0.8414
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8500
# loss: 0.33 acc: 0.85
# Predictions Counter({1: 466, 0: 34})
#
# Confusion matrix
# [[ 11  52]
#  [ 23 414]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.32      0.17      0.23        63
#      HEALTHY       0.89      0.95      0.92       437
#
#     accuracy                           0.85       500
#    macro avg       0.61      0.56      0.57       500
# weighted avg       0.82      0.85      0.83       500
#
# AUC 0.7962
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.2130 - accuracy: 0.9106 - val_loss: 0.3221 - val_accuracy: 0.8642
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2829 - accuracy: 0.8740
# loss: 0.28 acc: 0.87
# Predictions Counter({1: 494, 0: 6})
#
# Confusion matrix
# [[  3  60]
#  [  3 434]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.50      0.05      0.09        63
#      HEALTHY       0.88      0.99      0.93       437
#
#     accuracy                           0.87       500
#    macro avg       0.69      0.52      0.51       500
# weighted avg       0.83      0.87      0.83       500
#
# AUC 0.8684
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 0 0 0]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The new size is  3934
# Y TRAIN [0 0 0 ... 0 0 0]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.2135 - accuracy: 0.9136 - val_loss: 0.3285 - val_accuracy: 0.8566
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3153 - accuracy: 0.8640
# loss: 0.32 acc: 0.86
# Predictions Counter({1: 479, 0: 21})
#
# Confusion matrix
# [[  8  55]
#  [ 13 424]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.38      0.13      0.19        63
#      HEALTHY       0.89      0.97      0.93       437
#
#     accuracy                           0.86       500
#    macro avg       0.63      0.55      0.56       500
# weighted avg       0.82      0.86      0.83       500
#
# AUC 0.8399
# Sacando la gráfica del modelo
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 1.1268 - accuracy: 0.9161 - val_loss: 2.4001 - val_accuracy: 0.8470
# 16/16 [==============================] - 0s 3ms/step - loss: 1.9664 - accuracy: 0.8740
# loss: 1.97 acc: 0.87
# Predictions Counter({1: 497, 0: 3})
#
# Confusion matrix
# [[  1  61]
#  [  2 436]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.33      0.02      0.03        62
#      HEALTHY       0.88      1.00      0.93       438
#
#     accuracy                           0.87       500
#    macro avg       0.61      0.51      0.48       500
# weighted avg       0.81      0.87      0.82       500
#
# AUC 0.6144
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 8.0040 - accuracy: 0.5030 - val_loss: 2.4001 - val_accuracy: 0.8511
# 16/16 [==============================] - 0s 2ms/step - loss: 1.9986 - accuracy: 0.8760
# loss: 2.00 acc: 0.88
# Predictions Counter({1: 500})
#
# Confusion matrix
# [[  0  62]
#  [  0 438]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        62
#      HEALTHY       0.88      1.00      0.93       438
#
#     accuracy                           0.88       500
#    macro avg       0.44      0.50      0.47       500
# weighted avg       0.77      0.88      0.82       500
#
# AUC 0.6904
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 7.5461 - accuracy: 0.4313 - val_loss: 1.4313 - val_accuracy: 0.7473
# 16/16 [==============================] - 0s 2ms/step - loss: 1.1927 - accuracy: 0.7180
# loss: 1.19 acc: 0.72
# Predictions Counter({1: 371, 0: 129})
#
# Confusion matrix
# [[ 25  37]
#  [104 334]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.19      0.40      0.26        62
#      HEALTHY       0.90      0.76      0.83       438
#
#     accuracy                           0.72       500
#    macro avg       0.55      0.58      0.54       500
# weighted avg       0.81      0.72      0.76       500
#
# AUC 0.6497
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 8.0040 - accuracy: 0.5033 - val_loss: 2.4001 - val_accuracy: 0.8511
# 16/16 [==============================] - 0s 2ms/step - loss: 1.9986 - accuracy: 0.8760
# loss: 2.00 acc: 0.88
# Predictions Counter({1: 500})
#
# Confusion matrix
# [[  0  62]
#  [  0 438]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        62
#      HEALTHY       0.88      1.00      0.93       438
#
#     accuracy                           0.88       500
#    macro avg       0.44      0.50      0.47       500
# weighted avg       0.77      0.88      0.82       500
#
# AUC 0.6448
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 206/206 - 1s - loss: 1.1465 - accuracy: 0.6992 - val_loss: 0.4331 - val_accuracy: 0.8456
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3930 - accuracy: 0.8740
# loss: 0.39 acc: 0.87
# Predictions Counter({1: 499, 0: 1})
#
# Confusion matrix
# [[  0  62]
#  [  1 437]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        62
#      HEALTHY       0.88      1.00      0.93       438
#
#     accuracy                           0.87       500
#    macro avg       0.44      0.50      0.47       500
# weighted avg       0.77      0.87      0.82       500
#
# AUC 0.6672
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.6843 - accuracy: 0.6625 - val_loss: 0.9147 - val_accuracy: 0.1434
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9236 - accuracy: 0.1260
# loss: 0.92 acc: 0.13
# Predictions Counter({0: 500})
#
# Confusion matrix
# [[ 63   0]
#  [437   0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.13      1.00      0.22        63
#      HEALTHY       0.00      0.00      0.00       437
#
#     accuracy                           0.13       500
#    macro avg       0.06      0.50      0.11       500
# weighted avg       0.02      0.13      0.03       500
#
# AUC 0.5682
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 1.1921e-07 - accuracy: 0.5394 - val_loss: 1.1921e-07 - val_accuracy: 0.1434
# 16/16 [==============================] - 0s 2ms/step - loss: 1.1921e-07 - accuracy: 0.1260
# loss: 0.00 acc: 0.13
# Predictions Counter({0: 500})
#
# Confusion matrix
# [[ 63   0]
#  [437   0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.13      1.00      0.22        63
#      HEALTHY       0.00      0.00      0.00       437
#
#     accuracy                           0.13       500
#    macro avg       0.06      0.50      0.11       500
# weighted avg       0.02      0.13      0.03       500
#
# AUC 0.5000
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 8.6940 - accuracy: 0.4606 - val_loss: 2.3114 - val_accuracy: 0.8566
# 16/16 [==============================] - 0s 2ms/step - loss: 2.0309 - accuracy: 0.8740
# loss: 2.03 acc: 0.87
# Predictions Counter({1: 500})
#
# Confusion matrix
# [[  0  63]
#  [  0 437]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        63
#      HEALTHY       0.87      1.00      0.93       437
#
#     accuracy                           0.87       500
#    macro avg       0.44      0.50      0.47       500
# weighted avg       0.76      0.87      0.82       500
#
# AUC 0.7726
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 0.2880 - accuracy: 0.8618 - val_loss: 0.3445 - val_accuracy: 0.5470
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3091 - accuracy: 0.5640
# loss: 0.31 acc: 0.56
# Predictions Counter({1: 341, 0: 159})
#
# Confusion matrix
# [[  2  61]
#  [157 280]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.01      0.03      0.02        63
#      HEALTHY       0.82      0.64      0.72       437
#
# ...
#
# AUC 0.6291
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 0 0 0]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The new size is  3934
# Y TRAIN [0 0 0 ... 0 0 0]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 1.1921e-07 - accuracy: 0.5392 - val_loss: 1.1921e-07 - val_accuracy: 0.1447
# 16/16 [==============================] - 0s 2ms/step - loss: 1.1921e-07 - accuracy: 0.1260
# loss: 0.00 acc: 0.13
# Predictions Counter({0: 500})
#
# Confusion matrix
# [[ 63   0]
#  [437   0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.13      1.00      0.22        63
#      HEALTHY       0.00      0.00      0.00       437
#
#     accuracy                           0.13       500
#    macro avg       0.06      0.50      0.11       500
# weighted avg       0.02      0.13      0.03       500
#
# AUC 0.5000
# Sacando la gráfica del modelo
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 1.0854 - accuracy: 0.8879 - val_loss: 2.2460 - val_accuracy: 0.8279
# 16/16 [==============================] - 0s 2ms/step - loss: 1.8375 - accuracy: 0.8620
# loss: 1.84 acc: 0.86
# Predictions Counter({1: 483, 0: 17})
#
# Confusion matrix
# [[  5  57]
#  [ 12 426]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.29      0.08      0.13        62
#      HEALTHY       0.88      0.97      0.93       438
#
#     accuracy                           0.86       500
#    macro avg       0.59      0.53      0.53       500
# weighted avg       0.81      0.86      0.83       500
#
# AUC 0.6554
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 6.6205 - accuracy: 0.5523 - val_loss: 2.4001 - val_accuracy: 0.8511
# 16/16 [==============================] - 0s 2ms/step - loss: 1.9986 - accuracy: 0.8760
# loss: 2.00 acc: 0.88
# Predictions Counter({1: 500})
#
# Confusion matrix
# [[  0  62]
#  [  0 438]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        62
#      HEALTHY       0.88      1.00      0.93       438
#
#     accuracy                           0.88       500
#    macro avg       0.44      0.50      0.47       500
# weighted avg       0.77      0.88      0.82       500
#
# AUC 0.8268
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.3479 - accuracy: 0.9010 - val_loss: 0.4877 - val_accuracy: 0.8511
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3572 - accuracy: 0.8760
# loss: 0.36 acc: 0.88
# Predictions Counter({1: 500})
#
# Confusion matrix
# [[  0  62]
#  [  0 438]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        62
#      HEALTHY       0.88      1.00      0.93       438
#
#     accuracy                           0.88       500
#    macro avg       0.44      0.50      0.47       500
# weighted avg       0.77      0.88      0.82       500
#
# AUC 0.7997
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 0.9421 - accuracy: 0.9048 - val_loss: 2.2239 - val_accuracy: 0.8429
# 16/16 [==============================] - 0s 2ms/step - loss: 1.9342 - accuracy: 0.8640
# loss: 1.93 acc: 0.86
# Predictions Counter({1: 490, 0: 10})
#
# Confusion matrix
# [[  2  60]
#  [  8 430]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.20      0.03      0.06        62
#      HEALTHY       0.88      0.98      0.93       438
#
#     accuracy                           0.86       500
#    macro avg       0.54      0.51      0.49       500
# weighted avg       0.79      0.86      0.82       500
#
# AUC 0.7441
# Before  4500
# Getting the len of the arrays  563   563
# The old size was  563
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5063, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5626, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6189, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6752, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3378
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3378
# X_train (7315, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7315,) y_test (500,)
# y_train_nn (7315, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 206/206 - 1s - loss: 5.1948 - accuracy: 0.6175 - val_loss: 13.7180 - val_accuracy: 0.1489
# 16/16 [==============================] - 0s 2ms/step - loss: 14.1195 - accuracy: 0.1240
# loss: 14.12 acc: 0.12
# Predictions Counter({0: 500})
#
# Confusion matrix
# [[ 62   0]
#  [438   0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.12      1.00      0.22        62
#      HEALTHY       0.00      0.00      0.00       438
#
#     accuracy                           0.12       500
#    macro avg       0.06      0.50      0.11       500
# weighted avg       0.02      0.12      0.03       500
#
# AUC 0.5000
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 7.4244 - accuracy: 0.5394 - val_loss: 13.8067 - val_accuracy: 0.1434
# 16/16 [==============================] - 0s 2ms/step - loss: 14.0872 - accuracy: 0.1260
# loss: 14.09 acc: 0.13
# Predictions Counter({0: 500})
#
# Confusion matrix
# [[ 63   0]
#  [437   0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.13      1.00      0.22        63
#      HEALTHY       0.00      0.00      0.00       437
#
#     accuracy                           0.13       500
#    macro avg       0.06      0.50      0.11       500
# weighted avg       0.02      0.13      0.03       500
#
# AUC 0.5000
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 6.0192 - accuracy: 0.5916 - val_loss: 2.3114 - val_accuracy: 0.8566
# 16/16 [==============================] - 0s 2ms/step - loss: 2.0309 - accuracy: 0.8740
# loss: 2.03 acc: 0.87
# Predictions Counter({1: 500})
#
# Confusion matrix
# [[  0  63]
#  [  0 437]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        63
#      HEALTHY       0.87      1.00      0.93       437
#
#     accuracy                           0.87       500
#    macro avg       0.44      0.50      0.47       500
# weighted avg       0.76      0.87      0.82       500
#
# AUC 0.8877
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 7.1330 - accuracy: 0.5394 - val_loss: 13.1317 - val_accuracy: 0.1434
# 16/16 [==============================] - 0s 2ms/step - loss: 13.3458 - accuracy: 0.1260
# loss: 13.35 acc: 0.13
# Predictions Counter({0: 500})
#
# Confusion matrix
# [[ 63   0]
#  [437   0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.13      1.00      0.22        63
#      HEALTHY       0.00      0.00      0.00       437
#
#     accuracy                           0.13       500
#    macro avg       0.06      0.50      0.11       500
# weighted avg       0.02      0.13      0.03       500
#
# AUC 0.5000
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 1 1 1]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 1 1 1]
# The new size is  3934
# Y TRAIN [0 0 0 ... 1 1 1]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 222/222 - 1s - loss: 8.5415 - accuracy: 0.4640 - val_loss: 2.3318 - val_accuracy: 0.8553
# 16/16 [==============================] - 0s 2ms/step - loss: 2.0309 - accuracy: 0.8740
# loss: 2.03 acc: 0.87
# Predictions Counter({1: 500})
#
# Confusion matrix
# [[  0  63]
#  [  0 437]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        63
#      HEALTHY       0.87      1.00      0.93       437
#
#     accuracy                           0.87       500
#    macro avg       0.44      0.50      0.47       500
# weighted avg       0.76      0.87      0.82       500
#
# AUC 0.7899
# Before  4500
# Getting the len of the arrays  562   562
# The old size was  562
# The shape is  (4500, 32, 32, 3)
# [1 1 1 ... 0 0 0]
# The shape is  (5062, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (5624, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (6186, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (6748, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# The shape is  (7310, 32, 32, 3)
# [0 0 0 ... 0 0 0]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The new size is  3934
# Y TRAIN [0 0 0 ... 0 0 0]
# After  3934
# X_train (7872, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (7872,) y_test (500,)
# y_train_nn (7872, 2) y_test_nn (500, 2)
# The batch and the epoch are   32 ,  8
# 222/222 - 1s - loss: 8.1296 - accuracy: 0.4639 - val_loss: 2.3318 - val_accuracy: 0.8553
# 16/16 [==============================] - 0s 2ms/step - loss: 2.0309 - accuracy: 0.8740
# loss: 2.03 acc: 0.87
# Predictions Counter({1: 500})
#
# Confusion matrix
# [[  0  63]
#  [  0 437]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        63
#      HEALTHY       0.87      1.00      0.93       437
#
#     accuracy                           0.87       500
#    macro avg       0.44      0.50      0.47       500
# weighted avg       0.76      0.87      0.82       500
#
# AUC 0.8655
# Sacando la gráfica del modelo
# FIRST MODEL GRAPHIC
# THE BEST MODEL IS  ['tanh', 'tanh', 'tanh', 'tanh', 'softmax']
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
get_best_activation_function(True)
# Out:
# Before  4500
# Y TRAIN [7 7 6 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.9652 - accuracy: 0.1858
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4495 - accuracy: 0.3631
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2473 - accuracy: 0.4329
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1539 - accuracy: 0.4891
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0958 - accuracy: 0.5173
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0998 - accuracy: 0.5091
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0726 - accuracy: 0.5196
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0647 - accuracy: 0.5211
# Predictions Counter({2: 79, 3: 79, 7: 75, 1: 63, 4: 63, 6: 52, 5: 46, 0: 43})
#
# Confusion matrix
# [[19  0  6 35  0  3  0  0]
#  [ 0 28 14  0 21  0  0  0]
#  [ 2 10 28  1  2 19  0  0]
#  [14  0  2 37  0  9  0  0]
#  [ 0 18  4  0 37  1  3  0]
#  [ 8  7 25  6  2 14  0  0]
#  [ 0  0  0  0  1  0 49 12]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.44      0.30      0.36        63
#       STROMA       0.44      0.44      0.44        63
#      COMPLEX       0.35      0.45      0.40        62
#       LYMPHO       0.47      0.60      0.52        62
#       DEBRIS       0.59      0.59      0.59        63
#       MUCOSA       0.30      0.23      0.26        62
#      ADIPOSE       0.94      0.79      0.86        62
#        EMPTY       0.84      1.00      0.91        63
#
#     accuracy                           0.55       500
#    macro avg       0.55      0.55      0.54       500
# weighted avg       0.55      0.55      0.54       500
#
# AUC 0.9096
# loss: 1.01 acc: 0.55
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.8937 - accuracy: 0.2184
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4174 - accuracy: 0.3811
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2450 - accuracy: 0.4291
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1278 - accuracy: 0.4867
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1061 - accuracy: 0.4976
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0865 - accuracy: 0.5122
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0690 - accuracy: 0.5147
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0545 - accuracy: 0.5340
# Predictions Counter({2: 88, 7: 72, 4: 68, 0: 64, 3: 61, 6: 51, 5: 50, 1: 46})
#
# Confusion matrix
# [[27  2  6 24  0  4  0  0]
#  [ 0 25 18  0 19  0  1  0]
#  [ 2  3 37  1  1 18  0  0]
#  [17  0  2 36  0  7  0  0]
#  [ 0 11  7  0 44  0  1  0]
#  [18  5 18  0  0 21  0  0]
#  [ 0  0  0  0  3  0 48 11]
#  [ 0  0  0  0  1  0  1 61]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.42      0.43      0.43        63
#       STROMA       0.54      0.40      0.46        63
#      COMPLEX       0.42      0.60      0.49        62
#       LYMPHO       0.59      0.58      0.59        62
#       DEBRIS       0.65      0.70      0.67        63
#       MUCOSA       0.42      0.34      0.38        62
#      ADIPOSE       0.94      0.77      0.85        62
#        EMPTY       0.85      0.97      0.90        63
#
#     accuracy                           0.60       500
#    macro avg       0.60      0.60      0.60       500
# weighted avg       0.60      0.60      0.60       500
#
# AUC 0.9238
# loss: 0.96 acc: 0.60
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.9398 - accuracy: 0.1949
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4876 - accuracy: 0.3400
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3597 - accuracy: 0.3789
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2575 - accuracy: 0.4431
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.1797 - accuracy: 0.4758
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.1191 - accuracy: 0.5067
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0945 - accuracy: 0.5062
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0897 - accuracy: 0.5040
# Predictions Counter({3: 84, 0: 79, 6: 76, 4: 63, 2: 54, 1: 51, 7: 50, 5: 43})
#
# Confusion matrix
# [[17  1  1 40  1  3  0  0]
#  [ 1 33 12  0 15  1  1  0]
#  [16  3 21  0  1 21  0  0]
#  [18  0  2 41  0  1  0  0]
#  [ 0 12  5  0 44  1  1  0]
#  [27  2 13  3  1 16  0  0]
#  [ 0  0  0  0  1  0 60  1]
#  [ 0  0  0  0  0  0 14 49]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.22      0.27      0.24        63
#       STROMA       0.65      0.52      0.58        63
#      COMPLEX       0.39      0.34      0.36        62
#       LYMPHO       0.49      0.66      0.56        62
#       DEBRIS       0.70      0.70      0.70        63
#       MUCOSA       0.37      0.26      0.30        62
#      ADIPOSE       0.79      0.97      0.87        62
#        EMPTY       0.98      0.78      0.87        63
#
#     accuracy                           0.56       500
#    macro avg       0.57      0.56      0.56       500
# weighted avg       0.57      0.56      0.56       500
#
# AUC 0.9156
# loss: 1.04 acc: 0.56
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0317 - accuracy: 0.1747
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5289 - accuracy: 0.3271
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3245 - accuracy: 0.4140
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1751 - accuracy: 0.4831
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1299 - accuracy: 0.4842
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0930 - accuracy: 0.4944
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0642 - accuracy: 0.5218
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0542 - accuracy: 0.5144
# Predictions Counter({1: 102, 2: 69, 7: 67, 3: 64, 6: 52, 0: 52, 5: 51, 4: 43})
#
# Confusion matrix
# [[22  0  4 28  0  9  0  0]
#  [ 0 45  9  0  9  0  0  0]
#  [ 4 18 32  0  0  8  0  0]
#  [12  0  4 36  0 10  0  0]
#  [ 0 34  2  0 26  0  1  0]
#  [14  5 18  0  1 24  0  0]
#  [ 0  0  0  0  7  0 50  5]
#  [ 0  0  0  0  0  0  1 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.42      0.35      0.38        63
#       STROMA       0.44      0.71      0.55        63
#      COMPLEX       0.46      0.52      0.49        62
#       LYMPHO       0.56      0.58      0.57        62
#       DEBRIS       0.60      0.41      0.49        63
#       MUCOSA       0.47      0.39      0.42        62
#      ADIPOSE       0.96      0.81      0.88        62
#        EMPTY       0.93      0.98      0.95        63
#
#     accuracy                           0.59       500
#    macro avg       0.61      0.59      0.59       500
# weighted avg       0.61      0.59      0.59       500
#
# AUC 0.9206
# loss: 0.98 acc: 0.59
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0904 - accuracy: 0.1258
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.6267 - accuracy: 0.2951
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4229 - accuracy: 0.3582
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2949 - accuracy: 0.4098
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1745 - accuracy: 0.4676
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1289 - accuracy: 0.4916
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1151 - accuracy: 0.4904
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0921 - accuracy: 0.4982
# Predictions Counter({0: 125, 7: 78, 2: 77, 5: 59, 4: 58, 1: 55, 6: 48})
#
# Confusion matrix
# [[48  2  5  0  0  8  0  0]
#  [ 0 27 18  0 17  0  1  0]
#  [ 8  5 32  0  0 17  0  0]
#  [52  0  2  0  0  8  0  0]
#  [ 0 18  3  0 39  1  2  0]
#  [17  3 17  0  0 25  0  0]
#  [ 0  0  0  0  2  0 45 15]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.38      0.76      0.51        63
#       STROMA       0.49      0.43      0.46        63
#      COMPLEX       0.42      0.52      0.46        62
#       LYMPHO       0.00      0.00      0.00        62
#       DEBRIS       0.67      0.62      0.64        63
#       MUCOSA       0.42      0.40      0.41        62
#      ADIPOSE       0.94      0.73      0.82        62
#        EMPTY       0.81      1.00      0.89        63
#
#     accuracy                           0.56       500
#    macro avg       0.52      0.56      0.52       500
# weighted avg       0.52      0.56      0.53       500
#
# AUC 0.9155
# loss: 1.02 acc: 0.56
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.9528 - accuracy: 0.2033
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3606 - accuracy: 0.4004
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.1782 - accuracy: 0.4724
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1495 - accuracy: 0.4807
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0985 - accuracy: 0.5093
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0741 - accuracy: 0.5173
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0703 - accuracy: 0.5156
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0563 - accuracy: 0.5309
# Predictions Counter({3: 118, 5: 73, 6: 73, 4: 69, 1: 57, 2: 57, 7: 48, 0: 5})
#
# Confusion matrix
# [[ 1  0  2 51  0  8  0  0]
#  [ 0 25 13  0 24  0  0  0]
#  [ 1  9 19  7  1 26  0  0]
#  [ 2  0  2 50  0  9  0  0]
#  [ 0 18  4  0 39  1  0  0]
#  [ 1  5 17 10  1 29  0  0]
#  [ 0  0  0  0  4  0 57  2]
#  [ 0  0  0  0  0  0 16 46]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.20      0.02      0.03        62
#       STROMA       0.44      0.40      0.42        62
#      COMPLEX       0.33      0.30      0.32        63
#       LYMPHO       0.42      0.79      0.55        63
#       DEBRIS       0.57      0.63      0.60        62
#       MUCOSA       0.40      0.46      0.43        63
#      ADIPOSE       0.78      0.90      0.84        63
#        EMPTY       0.96      0.74      0.84        62
#
#     accuracy                           0.53       500
#    macro avg       0.51      0.53      0.50       500
# weighted avg       0.51      0.53      0.50       500
#
# AUC 0.9134
# loss: 1.02 acc: 0.53
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.9639 - accuracy: 0.1827
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4634 - accuracy: 0.3567
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.2708 - accuracy: 0.4147
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1730 - accuracy: 0.4647
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1203 - accuracy: 0.4947
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0925 - accuracy: 0.5213
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0919 - accuracy: 0.5118
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0582 - accuracy: 0.5233
# Predictions Counter({0: 114, 7: 80, 5: 79, 2: 74, 4: 57, 1: 51, 6: 45})
#
# Confusion matrix
# [[51  0  2  0  0  9  0  0]
#  [ 0 24 17  0 18  1  2  0]
#  [ 5  3 31  0  1 23  0  0]
#  [52  0  1  0  0 10  0  0]
#  [ 0 19  6  0 32  1  3  1]
#  [ 6  5 17  0  0 35  0  0]
#  [ 0  0  0  0  6  0 40 17]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.45      0.82      0.58        62
#       STROMA       0.47      0.39      0.42        62
#      COMPLEX       0.42      0.49      0.45        63
#       LYMPHO       0.00      0.00      0.00        63
#       DEBRIS       0.56      0.52      0.54        62
#       MUCOSA       0.44      0.56      0.49        63
#      ADIPOSE       0.89      0.63      0.74        63
#        EMPTY       0.78      1.00      0.87        62
#
#     accuracy                           0.55       500
#    macro avg       0.50      0.55      0.51       500
# weighted avg       0.50      0.55      0.51       500
#
# AUC 0.9214
# loss: 0.99 acc: 0.55
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0268 - accuracy: 0.1736
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5221 - accuracy: 0.3356
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4096 - accuracy: 0.3836
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2905 - accuracy: 0.4313
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1818 - accuracy: 0.4764
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1115 - accuracy: 0.4940
# Epoch 7/8
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0753 - accuracy: 0.5182
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0537 - accuracy: 0.5318
# Predictions Counter({2: 92, 1: 69, 4: 69, 6: 64, 7: 62, 3: 62, 5: 41, 0: 41})
#
# Confusion matrix
# [[15  0  9 19  2 17  0  0]
#  [ 0 32 12  0 18  0  0  0]
#  [ 3 13 37  1  4  5  0  0]
#  [15  0  1 42  0  5  0  0]
#  [ 0 15  2  0 43  0  2  0]
#  [ 8  9 31  0  1 14  0  0]
#  [ 0  0  0  0  1  0 58  4]
#  [ 0  0  0  0  0  0  4 58]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.37      0.24      0.29        62
#       STROMA       0.46      0.52      0.49        62
#      COMPLEX       0.40      0.59      0.48        63
#       LYMPHO       0.68      0.67      0.67        63
#       DEBRIS       0.62      0.69      0.66        62
#       MUCOSA       0.34      0.22      0.27        63
#      ADIPOSE       0.91      0.92      0.91        63
#        EMPTY       0.94      0.94      0.94        62
#
#     accuracy                           0.60       500
#    macro avg       0.59      0.60      0.59       500
# weighted avg       0.59      0.60      0.59       500
#
# AUC 0.9162
# loss: 0.98 acc: 0.60
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0266 - accuracy: 0.1673
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5252 - accuracy: 0.3167
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.3177 - accuracy: 0.4222
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.2098 - accuracy: 0.4529
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1271 - accuracy: 0.4933
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0896 - accuracy: 0.5018
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0617 - accuracy: 0.5122
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0727 - accuracy: 0.5136
# Predictions Counter({2: 157, 3: 139, 6: 116, 1: 58, 4: 27, 0: 3})
#
# Confusion matrix
# [[ 1  0 11 50  0  0  0  0]
#  [ 0 17 39  0  6  0  0  0]
#  [ 1  3 53  6  0  0  0  0]
#  [ 0  0  3 60  0  0  0  0]
#  [ 0 37 13  0 10  0  2  0]
#  [ 1  1 38 23  0  0  0  0]
#  [ 0  0  0  0 11  0 52  0]
#  [ 0  0  0  0  0  0 62  0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.33      0.02      0.03        62
#       STROMA       0.29      0.27      0.28        62
#      COMPLEX       0.34      0.84      0.48        63
#       LYMPHO       0.43      0.95      0.59        63
#       DEBRIS       0.37      0.16      0.22        62
#       MUCOSA       0.00      0.00      0.00        63
#      ADIPOSE       0.45      0.83      0.58        63
#        EMPTY       0.00      0.00      0.00        62
#
#     accuracy                           0.39       500
#    macro avg       0.28      0.38      0.27       500
# weighted avg       0.28      0.39      0.28       500
#
# AUC 0.8983
# loss: 1.16 acc: 0.39
# Before  4500
# Y TRAIN [4 5 5 ... 0 0 0]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.8911 - accuracy: 0.2158
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4542 - accuracy: 0.3527
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3213 - accuracy: 0.4122
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2108 - accuracy: 0.4651
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1134 - accuracy: 0.4844
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0734 - accuracy: 0.5058
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0711 - accuracy: 0.5149
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0324 - accuracy: 0.5373
# Predictions Counter({5: 78, 7: 77, 1: 69, 3: 66, 2: 64, 4: 57, 6: 51, 0: 38})
#
# Confusion matrix
# [[15  1  2 27  0 17  0  0]
#  [ 0 28 14  0 19  1  0  0]
#  [ 0 13 26  1  2 21  0  0]
#  [16  0  1 38  0  8  0  0]
#  [ 0 19  4  0 36  0  3  0]
#  [ 7  8 17  0  0 31  0  0]
#  [ 0  0  0  0  0  0 48 15]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.39      0.24      0.30        62
#       STROMA       0.41      0.45      0.43        62
#      COMPLEX       0.41      0.41      0.41        63
#       LYMPHO       0.58      0.60      0.59        63
#       DEBRIS       0.63      0.58      0.61        62
#       MUCOSA       0.40      0.49      0.44        63
#      ADIPOSE       0.94      0.76      0.84        63
#        EMPTY       0.81      1.00      0.89        62
#
#     accuracy                           0.57       500
#    macro avg       0.57      0.57      0.56       500
# weighted avg       0.57      0.57      0.56       500
#
# AUC 0.9245
# loss: 0.93 acc: 0.57
# Sacando la gráfica del modelo
# The media value acc is   0.549600002169609 And the value auc is  0.9158913677199267 And the activation function is  ['sigmoid', 'sigmoid', 'sigmoid', 'sigmoid', 'softmax']
# Before  4500
# Y TRAIN [7 7 6 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5715 - accuracy: 0.3091
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1379 - accuracy: 0.5158
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9884 - accuracy: 0.5958
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9283 - accuracy: 0.6271
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9260 - accuracy: 0.6253
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9184 - accuracy: 0.6296
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8479 - accuracy: 0.6564
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9014 - accuracy: 0.6331
# Predictions Counter({5: 128, 3: 99, 7: 81, 4: 53, 6: 46, 2: 40, 0: 31, 1: 22})
#
# Confusion matrix
# [[26  0  0 26  0 11  0  0]
#  [ 0 14 17  0 15 17  0  0]
#  [ 1  0 20  6  4 31  0  0]
#  [ 3  0  0 53  0  6  0  0]
#  [ 0  8  3  0 33 16  3  0]
#  [ 1  0  0 14  0 47  0  0]
#  [ 0  0  0  0  1  0 43 18]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.84      0.41      0.55        63
#       STROMA       0.64      0.22      0.33        63
#      COMPLEX       0.50      0.32      0.39        62
#       LYMPHO       0.54      0.85      0.66        62
#       DEBRIS       0.62      0.52      0.57        63
#       MUCOSA       0.37      0.76      0.49        62
#      ADIPOSE       0.93      0.69      0.80        62
#        EMPTY       0.78      1.00      0.88        63
#
#     accuracy                           0.60       500
#    macro avg       0.65      0.60      0.58       500
# weighted avg       0.65      0.60      0.58       500
#
# AUC 0.9336
# loss: 1.00 acc: 0.60
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4066 - accuracy: 0.3933
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0388 - accuracy: 0.5522
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9947 - accuracy: 0.5642
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9263 - accuracy: 0.6093
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8986 - accuracy: 0.6293
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8446 - accuracy: 0.6338
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8382 - accuracy: 0.6569
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8369 - accuracy: 0.6496
# Predictions Counter({2: 114, 3: 85, 7: 65, 5: 62, 0: 57, 6: 43, 1: 41, 4: 33})
#
# Confusion matrix
# [[41  0  2 10  0 10  0  0]
#  [ 0 13 45  0  3  2  0  0]
#  [ 8  1 45  8  0  0  0  0]
#  [ 2  0  1 57  0  2  0  0]
#  [ 0 26 15  0 13  9  0  0]
#  [ 6  1  6 10  0 39  0  0]
#  [ 0  0  0  0 16  0 41  5]
#  [ 0  0  0  0  1  0  2 60]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.72      0.65      0.68        63
#       STROMA       0.32      0.21      0.25        63
#      COMPLEX       0.39      0.73      0.51        62
#       LYMPHO       0.67      0.92      0.78        62
#       DEBRIS       0.39      0.21      0.27        63
#       MUCOSA       0.63      0.63      0.63        62
#      ADIPOSE       0.95      0.66      0.78        62
#        EMPTY       0.92      0.95      0.94        63
#
#     accuracy                           0.62       500
#    macro avg       0.63      0.62      0.60       500
# weighted avg       0.62      0.62      0.60       500
#
# AUC 0.9381
# loss: 0.94 acc: 0.62
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3804 - accuracy: 0.3971
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0492 - accuracy: 0.5420
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9732 - accuracy: 0.5853
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9584 - accuracy: 0.5804
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9279 - accuracy: 0.6160
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8982 - accuracy: 0.6276
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8565 - accuracy: 0.6507
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8342 - accuracy: 0.6584
# Predictions Counter({5: 97, 3: 93, 1: 88, 7: 82, 6: 45, 2: 45, 0: 28, 4: 22})
#
# Confusion matrix
# [[27  0  0 21  0 15  0  0]
#  [ 0 51  7  0  1  3  1  0]
#  [ 0  5 36  8  0 13  0  0]
#  [ 1  0  0 55  0  6  0  0]
#  [ 0 32  2  0 19  8  2  0]
#  [ 0  0  0  9  1 52  0  0]
#  [ 0  0  0  0  1  0 41 20]
#  [ 0  0  0  0  0  0  1 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.96      0.43      0.59        63
#       STROMA       0.58      0.81      0.68        63
#      COMPLEX       0.80      0.58      0.67        62
#       LYMPHO       0.59      0.89      0.71        62
#       DEBRIS       0.86      0.30      0.45        63
#       MUCOSA       0.54      0.84      0.65        62
#      ADIPOSE       0.91      0.66      0.77        62
#        EMPTY       0.76      0.98      0.86        63
#
#     accuracy                           0.69       500
#    macro avg       0.75      0.69      0.67       500
# weighted avg       0.75      0.69      0.67       500
#
# AUC 0.9627
# loss: 0.78 acc: 0.69
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.2873 - accuracy: 0.4529
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0294 - accuracy: 0.5604
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9932 - accuracy: 0.5727
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9411 - accuracy: 0.6187
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9348 - accuracy: 0.6104
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8665 - accuracy: 0.6527
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8819 - accuracy: 0.6353
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8554 - accuracy: 0.6544
# Predictions Counter({3: 129, 5: 85, 4: 72, 7: 69, 6: 53, 1: 44, 2: 27, 0: 21})
#
# Confusion matrix
# [[14  0  0 44  0  5  0  0]
#  [ 0 30  7  0 17  9  0  0]
#  [ 3  4 17 12  5 21  0  0]
#  [ 3  0  0 53  0  6  0  0]
#  [ 0 10  2  0 44  6  1  0]
#  [ 1  0  1 20  2 38  0  0]
#  [ 0  0  0  0  4  0 51  7]
#  [ 0  0  0  0  0  0  1 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.67      0.22      0.33        63
#       STROMA       0.68      0.48      0.56        63
#      COMPLEX       0.63      0.27      0.38        62
#       LYMPHO       0.41      0.85      0.55        62
#       DEBRIS       0.61      0.70      0.65        63
#       MUCOSA       0.45      0.61      0.52        62
#      ADIPOSE       0.96      0.82      0.89        62
#        EMPTY       0.90      0.98      0.94        63
#
#     accuracy                           0.62       500
#    macro avg       0.66      0.62      0.60       500
# weighted avg       0.66      0.62      0.60       500
#
# AUC 0.9371
# loss: 1.02 acc: 0.62
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3950 - accuracy: 0.4098
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0735 - accuracy: 0.5467
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0218 - accuracy: 0.5647
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9565 - accuracy: 0.6149
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9312 - accuracy: 0.6249
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8839 - accuracy: 0.6411
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8756 - accuracy: 0.6491
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8458 - accuracy: 0.6491
# Predictions Counter({3: 146, 7: 97, 5: 75, 1: 51, 6: 40, 2: 36, 0: 30, 4: 25})
#
# Confusion matrix
# [[22  0  0 35  0  6  0  0]
#  [ 0 31  9  0  7 15  1  0]
#  [ 2  1 25 23  0 11  0  0]
#  [ 2  0  0 58  0  2  0  0]
#  [ 0 19  2  2 18 11 10  1]
#  [ 4  0  0 28  0 30  0  0]
#  [ 0  0  0  0  0  0 29 33]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.73      0.35      0.47        63
#       STROMA       0.61      0.49      0.54        63
#      COMPLEX       0.69      0.40      0.51        62
#       LYMPHO       0.40      0.94      0.56        62
#       DEBRIS       0.72      0.29      0.41        63
#       MUCOSA       0.40      0.48      0.44        62
#      ADIPOSE       0.72      0.47      0.57        62
#        EMPTY       0.65      1.00      0.79        63
#
#     accuracy                           0.55       500
#    macro avg       0.62      0.55      0.54       500
# weighted avg       0.62      0.55      0.54       500
#
# AUC 0.9233
# loss: 1.21 acc: 0.55
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2888 - accuracy: 0.4576
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0381 - accuracy: 0.5560
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9867 - accuracy: 0.5640
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9423 - accuracy: 0.5980
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9378 - accuracy: 0.5869
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8855 - accuracy: 0.6198
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8929 - accuracy: 0.6100
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8255 - accuracy: 0.6636
# Predictions Counter({3: 100, 1: 86, 7: 69, 0: 69, 2: 68, 6: 52, 5: 32, 4: 24})
#
# Confusion matrix
# [[40  0  2 20  0  0  0  0]
#  [ 0 46 16  0  0  0  0  0]
#  [10  3 38 11  0  1  0  0]
#  [ 4  0  3 56  0  0  0  0]
#  [ 0 35  5  0 19  3  0  0]
#  [15  2  4 13  1 28  0  0]
#  [ 0  0  0  0  4  0 50  9]
#  [ 0  0  0  0  0  0  2 60]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.58      0.65      0.61        62
#       STROMA       0.53      0.74      0.62        62
#      COMPLEX       0.56      0.60      0.58        63
#       LYMPHO       0.56      0.89      0.69        63
#       DEBRIS       0.79      0.31      0.44        62
#       MUCOSA       0.88      0.44      0.59        63
#      ADIPOSE       0.96      0.79      0.87        63
#        EMPTY       0.87      0.97      0.92        62
#
#     accuracy                           0.67       500
#    macro avg       0.72      0.67      0.66       500
# weighted avg       0.72      0.67      0.66       500
#
# AUC 0.9484
# loss: 0.86 acc: 0.67
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4218 - accuracy: 0.3869
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1572 - accuracy: 0.4711
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0549 - accuracy: 0.5291
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0255 - accuracy: 0.5491
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9956 - accuracy: 0.5460
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9730 - accuracy: 0.5591
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9239 - accuracy: 0.5962
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9822 - accuracy: 0.5689
# Predictions Counter({1: 119, 7: 86, 2: 74, 5: 52, 0: 50, 3: 49, 6: 39, 4: 31})
#
# Confusion matrix
# [[29  0  5 21  0  7  0  0]
#  [ 0 54  4  0  3  1  0  0]
#  [ 0 26 36  1  0  0  0  0]
#  [21  1 12 26  0  3  0  0]
#  [ 0 33  0  0 23  2  3  1]
#  [ 0  5 17  1  1 39  0  0]
#  [ 0  0  0  0  4  0 36 23]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.58      0.47      0.52        62
#       STROMA       0.45      0.87      0.60        62
#      COMPLEX       0.49      0.57      0.53        63
#       LYMPHO       0.53      0.41      0.46        63
#       DEBRIS       0.74      0.37      0.49        62
#       MUCOSA       0.75      0.62      0.68        63
#      ADIPOSE       0.92      0.57      0.71        63
#        EMPTY       0.72      1.00      0.84        62
#
#     accuracy                           0.61       500
#    macro avg       0.65      0.61      0.60       500
# weighted avg       0.65      0.61      0.60       500
#
# AUC 0.9444
# loss: 0.86 acc: 0.61
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5028 - accuracy: 0.3847
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0544 - accuracy: 0.5551
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9724 - accuracy: 0.5911
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9799 - accuracy: 0.5771
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8626 - accuracy: 0.6518
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8306 - accuracy: 0.6556
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.7946 - accuracy: 0.6853
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8322 - accuracy: 0.6653
# Predictions Counter({3: 123, 2: 70, 1: 61, 7: 61, 4: 57, 6: 55, 5: 54, 0: 19})
#
# Confusion matrix
# [[17  0  4 30  0 11  0  0]
#  [ 0 32 18  0 11  1  0  0]
#  [ 2  7 41  9  3  1  0  0]
#  [ 0  0  0 63  0  0  0  0]
#  [ 0 21  4  1 29  5  2  0]
#  [ 0  1  3 20  3 36  0  0]
#  [ 0  0  0  0 11  0 51  1]
#  [ 0  0  0  0  0  0  2 60]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.89      0.27      0.42        62
#       STROMA       0.52      0.52      0.52        62
#      COMPLEX       0.59      0.65      0.62        63
#       LYMPHO       0.51      1.00      0.68        63
#       DEBRIS       0.51      0.47      0.49        62
#       MUCOSA       0.67      0.57      0.62        63
#      ADIPOSE       0.93      0.81      0.86        63
#        EMPTY       0.98      0.97      0.98        62
#
#     accuracy                           0.66       500
#    macro avg       0.70      0.66      0.65       500
# weighted avg       0.70      0.66      0.65       500
#
# AUC 0.9422
# loss: 0.93 acc: 0.66
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4310 - accuracy: 0.3713
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0684 - accuracy: 0.5218
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0022 - accuracy: 0.5582
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9691 - accuracy: 0.5640
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9207 - accuracy: 0.6102
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8946 - accuracy: 0.6176
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8525 - accuracy: 0.6656
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8076 - accuracy: 0.6793
# Predictions Counter({3: 117, 2: 112, 7: 78, 1: 55, 6: 50, 5: 46, 4: 22, 0: 20})
#
# Confusion matrix
# [[16  0  5 35  0  6  0  0]
#  [ 0 29 28  0  3  2  0  0]
#  [ 0  3 56  4  0  0  0  0]
#  [ 0  0  6 57  0  0  0  0]
#  [ 0 23  7  0 19 10  2  1]
#  [ 4  0 10 21  0 28  0  0]
#  [ 0  0  0  0  0  0 48 15]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.80      0.26      0.39        62
#       STROMA       0.53      0.47      0.50        62
#      COMPLEX       0.50      0.89      0.64        63
#       LYMPHO       0.49      0.90      0.63        63
#       DEBRIS       0.86      0.31      0.45        62
#       MUCOSA       0.61      0.44      0.51        63
#      ADIPOSE       0.96      0.76      0.85        63
#        EMPTY       0.79      1.00      0.89        62
#
#     accuracy                           0.63       500
#    macro avg       0.69      0.63      0.61       500
# weighted avg       0.69      0.63      0.61       500
#
# AUC 0.9553
# loss: 0.90 acc: 0.63
# Before  4500
# Y TRAIN [4 5 5 ... 0 0 0]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.3646 - accuracy: 0.4189
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0499 - accuracy: 0.5633
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0124 - accuracy: 0.5629
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0015 - accuracy: 0.5693
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9535 - accuracy: 0.5916
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9330 - accuracy: 0.6036
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9398 - accuracy: 0.5964
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9112 - accuracy: 0.6193
# Predictions Counter({3: 165, 1: 77, 7: 67, 5: 60, 6: 58, 2: 38, 4: 18, 0: 17})
#
# Confusion matrix
# [[ 4  0  1 55  0  2  0  0]
#  [ 0 39 10  0  2 11  0  0]
#  [12  4 24 14  1  8  0  0]
#  [ 1  0  0 61  0  1  0  0]
#  [ 0 34  2  0 15 11  0  0]
#  [ 0  0  1 35  0 27  0  0]
#  [ 0  0  0  0  0  0 57  6]
#  [ 0  0  0  0  0  0  1 61]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.24      0.06      0.10        62
#       STROMA       0.51      0.63      0.56        62
#      COMPLEX       0.63      0.38      0.48        63
#       LYMPHO       0.37      0.97      0.54        63
#       DEBRIS       0.83      0.24      0.38        62
#       MUCOSA       0.45      0.43      0.44        63
#      ADIPOSE       0.98      0.90      0.94        63
#        EMPTY       0.91      0.98      0.95        62
#
#     accuracy                           0.58       500
#    macro avg       0.61      0.58      0.55       500
# weighted avg       0.61      0.58      0.55       500
#
# AUC 0.9112
# loss: 1.22 acc: 0.58
# Sacando la gráfica del modelo
# The media value acc is   0.621999990940094 And the value auc is  0.9396195659898305 And the activation function is  ['relu', 'relu', 'relu', 'relu', 'softmax']
# Before  4500
# Y TRAIN [7 7 6 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.2551 - accuracy: 0.4667
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9739 - accuracy: 0.6071
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8850 - accuracy: 0.6478
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8783 - accuracy: 0.6469
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8775 - accuracy: 0.6471
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8119 - accuracy: 0.6811
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8549 - accuracy: 0.6518
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8063 - accuracy: 0.6753
# Predictions Counter({3: 111, 2: 87, 7: 74, 4: 56, 6: 49, 1: 47, 0: 45, 5: 31})
#
# Confusion matrix
# [[30  0  3 28  0  2  0  0]
#  [ 0 22 22  1 18  0  0  0]
#  [ 5  7 43  6  0  1  0  0]
#  [ 6  0  2 54  0  0  0  0]
#  [ 0 12  7  0 36  5  3  0]
#  [ 4  3 10 22  0 23  0  0]
#  [ 0  3  0  0  2  0 46 11]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.67      0.48      0.56        63
#       STROMA       0.47      0.35      0.40        63
#      COMPLEX       0.49      0.69      0.58        62
#       LYMPHO       0.49      0.87      0.62        62
#       DEBRIS       0.64      0.57      0.61        63
#       MUCOSA       0.74      0.37      0.49        62
#      ADIPOSE       0.94      0.74      0.83        62
#        EMPTY       0.85      1.00      0.92        63
#
#     accuracy                           0.63       500
#    macro avg       0.66      0.63      0.63       500
# weighted avg       0.66      0.63      0.63       500
#
# AUC 0.9393
# loss: 0.93 acc: 0.63
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.2301 - accuracy: 0.4689
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0174 - accuracy: 0.5607
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9624 - accuracy: 0.5909
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9200 - accuracy: 0.6247
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9205 - accuracy: 0.6067
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8663 - accuracy: 0.6456
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8960 - accuracy: 0.6247
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8519 - accuracy: 0.6591
# Predictions Counter({3: 118, 5: 72, 7: 69, 2: 63, 1: 62, 6: 57, 4: 40, 0: 19})
#
# Confusion matrix
# [[17  1  1 36  0  8  0  0]
#  [ 0 39 15  0  6  2  1  0]
#  [ 0  2 43  9  1  7  0  0]
#  [ 0  0  0 57  0  5  0  0]
#  [ 0 19  1  0 32 10  1  0]
#  [ 2  1  3 16  0 40  0  0]
#  [ 0  0  0  0  0  0 55  7]
#  [ 0  0  0  0  1  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.89      0.27      0.41        63
#       STROMA       0.63      0.62      0.62        63
#      COMPLEX       0.68      0.69      0.69        62
#       LYMPHO       0.48      0.92      0.63        62
#       DEBRIS       0.80      0.51      0.62        63
#       MUCOSA       0.56      0.65      0.60        62
#      ADIPOSE       0.96      0.89      0.92        62
#        EMPTY       0.90      0.98      0.94        63
#
#     accuracy                           0.69       500
#    macro avg       0.74      0.69      0.68       500
# weighted avg       0.74      0.69      0.68       500
#
# AUC 0.9507
# loss: 0.87 acc: 0.69
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1955 - accuracy: 0.5000
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9753 - accuracy: 0.6047
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9127 - accuracy: 0.6324
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8981 - accuracy: 0.6313
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8549 - accuracy: 0.6569
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8526 - accuracy: 0.6464
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8110 - accuracy: 0.6687
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.7914 - accuracy: 0.6767
# Predictions Counter({3: 130, 4: 80, 2: 68, 7: 64, 6: 63, 5: 39, 0: 34, 1: 22})
#
# Confusion matrix
# [[23  0  0 34  0  6  0  0]
#  [ 0 17 19  0 25  1  1  0]
#  [ 4  3 40 14  0  1  0  0]
#  [ 1  0  3 58  0  0  0  0]
#  [ 0  2  3  2 53  1  2  0]
#  [ 6  0  3 22  1 30  0  0]
#  [ 0  0  0  0  1  0 57  4]
#  [ 0  0  0  0  0  0  3 60]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.68      0.37      0.47        63
#       STROMA       0.77      0.27      0.40        63
#      COMPLEX       0.59      0.65      0.62        62
#       LYMPHO       0.45      0.94      0.60        62
#       DEBRIS       0.66      0.84      0.74        63
#       MUCOSA       0.77      0.48      0.59        62
#      ADIPOSE       0.90      0.92      0.91        62
#        EMPTY       0.94      0.95      0.94        63
#
#     accuracy                           0.68       500
#    macro avg       0.72      0.68      0.66       500
# weighted avg       0.72      0.68      0.66       500
#
# AUC 0.9457
# loss: 0.91 acc: 0.68
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.3833 - accuracy: 0.4180
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0364 - accuracy: 0.5671
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9630 - accuracy: 0.5949
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9473 - accuracy: 0.6124
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8871 - accuracy: 0.6411
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8467 - accuracy: 0.6500
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8256 - accuracy: 0.6684
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8248 - accuracy: 0.6691
# Predictions Counter({3: 135, 2: 68, 6: 67, 7: 58, 4: 52, 5: 48, 1: 48, 0: 24})
#
# Confusion matrix
# [[19  0  1 39  0  4  0  0]
#  [ 0 23 17  0 18  5  0  0]
#  [ 1  7 39 13  1  1  0  0]
#  [ 4  0  2 56  0  0  0  0]
#  [ 0 17  6  0 31  8  1  0]
#  [ 0  1  3 27  1 30  0  0]
#  [ 0  0  0  0  1  0 61  0]
#  [ 0  0  0  0  0  0  5 58]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.79      0.30      0.44        63
#       STROMA       0.48      0.37      0.41        63
#      COMPLEX       0.57      0.63      0.60        62
#       LYMPHO       0.41      0.90      0.57        62
#       DEBRIS       0.60      0.49      0.54        63
#       MUCOSA       0.62      0.48      0.55        62
#      ADIPOSE       0.91      0.98      0.95        62
#        EMPTY       1.00      0.92      0.96        63
#
#     accuracy                           0.63       500
#    macro avg       0.67      0.63      0.63       500
# weighted avg       0.67      0.63      0.63       500
#
# AUC 0.9438
# loss: 0.93 acc: 0.63
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.2248 - accuracy: 0.4789
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9883 - accuracy: 0.5864
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9029 - accuracy: 0.6289
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8458 - accuracy: 0.6513
# Epoch 5/8
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8188 - accuracy: 0.6722
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8083 - accuracy: 0.6798
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.7673 - accuracy: 0.6931
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.7811 - accuracy: 0.6876
# Predictions Counter({4: 75, 3: 73, 7: 72, 2: 68, 6: 62, 5: 57, 0: 48, 1: 45})
#
# Confusion matrix
# [[40  1  8 10  0  4  0  0]
#  [ 0 25  9  0 28  1  0  0]
#  [ 2  9 41  4  1  5  0  0]
#  [ 3  0  2 54  0  3  0  0]
#  [ 0  6  2  0 45  1  9  0]
#  [ 3  4  6  5  1 43  0  0]
#  [ 0  0  0  0  0  0 53  9]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.83      0.63      0.72        63
#       STROMA       0.56      0.40      0.46        63
#      COMPLEX       0.60      0.66      0.63        62
#       LYMPHO       0.74      0.87      0.80        62
#       DEBRIS       0.60      0.71      0.65        63
#       MUCOSA       0.75      0.69      0.72        62
#      ADIPOSE       0.85      0.85      0.85        62
#        EMPTY       0.88      1.00      0.93        63
#
#     accuracy                           0.73       500
#    macro avg       0.73      0.73      0.72       500
# weighted avg       0.73      0.73      0.72       500
#
# AUC 0.9585
# loss: 0.75 acc: 0.73
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.2360 - accuracy: 0.4578
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0120 - accuracy: 0.5640
# Epoch 3/8
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9744 - accuracy: 0.5920
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9668 - accuracy: 0.5931
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9075 - accuracy: 0.6331
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8650 - accuracy: 0.6598
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8547 - accuracy: 0.6553
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8032 - accuracy: 0.6769
# Predictions Counter({3: 142, 4: 83, 6: 66, 2: 65, 5: 60, 7: 56, 1: 17, 0: 11})
#
# Confusion matrix
# [[ 9  0  4 45  0  4  0  0]
#  [ 0 14 17  0 26  5  0  0]
#  [ 1  2 37 19  1  3  0  0]
#  [ 1  0  1 59  0  2  0  0]
#  [ 0  0  5  1 52  4  0  0]
#  [ 0  1  1 18  1 42  0  0]
#  [ 0  0  0  0  3  0 59  1]
#  [ 0  0  0  0  0  0  7 55]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.82      0.15      0.25        62
#       STROMA       0.82      0.23      0.35        62
#      COMPLEX       0.57      0.59      0.58        63
#       LYMPHO       0.42      0.94      0.58        63
#       DEBRIS       0.63      0.84      0.72        62
#       MUCOSA       0.70      0.67      0.68        63
#      ADIPOSE       0.89      0.94      0.91        63
#        EMPTY       0.98      0.89      0.93        62
#
#     accuracy                           0.65       500
#    macro avg       0.73      0.65      0.63       500
# weighted avg       0.73      0.65      0.63       500
#
# AUC 0.9510
# loss: 0.89 acc: 0.65
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 17ms/step - loss: 1.2598 - accuracy: 0.4709
# Epoch 2/8
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9790 - accuracy: 0.6098
# Epoch 3/8
# 141/140 [==============================] - 2s 18ms/step - loss: 0.9223 - accuracy: 0.6402
# Epoch 4/8
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8804 - accuracy: 0.6416
# Epoch 5/8
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8594 - accuracy: 0.6571
# Epoch 6/8
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8272 - accuracy: 0.6718
# Epoch 7/8
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8676 - accuracy: 0.6618
# Epoch 8/8
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8161 - accuracy: 0.6744
# Predictions Counter({3: 189, 6: 116, 4: 61, 5: 43, 2: 41, 1: 39, 0: 11})
#
# Confusion matrix
# [[ 9  0  0 51  0  2  0  0]
#  [ 0 21 14  1 17  9  0  0]
#  [ 1  0 23 36  1  2  0  0]
#  [ 0  0  1 62  0  0  0  0]
#  [ 0 18  2  0 32  9  1  0]
#  [ 1  0  1 39  1 21  0  0]
#  [ 0  0  0  0 10  0 53  0]
#  [ 0  0  0  0  0  0 62  0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.82      0.15      0.25        62
#       STROMA       0.54      0.34      0.42        62
#      COMPLEX       0.56      0.37      0.44        63
#       LYMPHO       0.33      0.98      0.49        63
#       DEBRIS       0.52      0.52      0.52        62
#       MUCOSA       0.49      0.33      0.40        63
#      ADIPOSE       0.46      0.84      0.59        63
#        EMPTY       0.00      0.00      0.00        62
#
#     accuracy                           0.44       500
#    macro avg       0.46      0.44      0.39       500
# weighted avg       0.46      0.44      0.39       500
#
# AUC 0.9144
# loss: 1.30 acc: 0.44
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 17ms/step - loss: 1.2250 - accuracy: 0.4769
# Epoch 2/8
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9998 - accuracy: 0.5971
# Epoch 3/8
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9081 - accuracy: 0.6356
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8787 - accuracy: 0.6478
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8751 - accuracy: 0.6527
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8455 - accuracy: 0.6589
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8273 - accuracy: 0.6622
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8006 - accuracy: 0.6771
# Predictions Counter({3: 157, 4: 89, 7: 70, 2: 69, 6: 55, 5: 35, 1: 17, 0: 8})
#
# Confusion matrix
# [[ 6  0  5 46  0  5  0  0]
#  [ 0  7 19  0 35  1  0  0]
#  [ 2  5 36 15  3  2  0  0]
#  [ 0  0  0 63  0  0  0  0]
#  [ 0  3  1  2 49  5  2  0]
#  [ 0  2  8 31  0 22  0  0]
#  [ 0  0  0  0  2  0 53  8]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.75      0.10      0.17        62
#       STROMA       0.41      0.11      0.18        62
#      COMPLEX       0.52      0.57      0.55        63
#       LYMPHO       0.40      1.00      0.57        63
#       DEBRIS       0.55      0.79      0.65        62
#       MUCOSA       0.63      0.35      0.45        63
#      ADIPOSE       0.96      0.84      0.90        63
#        EMPTY       0.89      1.00      0.94        62
#
#     accuracy                           0.60       500
#    macro avg       0.64      0.60      0.55       500
# weighted avg       0.64      0.60      0.55       500
#
# AUC 0.9280
# loss: 1.15 acc: 0.60
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.2376 - accuracy: 0.4904
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0291 - accuracy: 0.5718
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9717 - accuracy: 0.5996
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9194 - accuracy: 0.6251
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9058 - accuracy: 0.6340
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8539 - accuracy: 0.6578
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8365 - accuracy: 0.6629
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8039 - accuracy: 0.6793
# Predictions Counter({2: 105, 3: 87, 7: 69, 5: 64, 6: 59, 1: 59, 4: 51, 0: 6})
#
# Confusion matrix
# [[ 6  2 10 33  0 11  0  0]
#  [ 0 36 12  0 10  4  0  0]
#  [ 0  8 53  0  1  1  0  0]
#  [ 0  0 11 51  0  1  0  0]
#  [ 0 12  3  0 39  5  2  1]
#  [ 0  1 16  3  1 42  0  0]
#  [ 0  0  0  0  0  0 57  6]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       1.00      0.10      0.18        62
#       STROMA       0.61      0.58      0.60        62
#      COMPLEX       0.50      0.84      0.63        63
#       LYMPHO       0.59      0.81      0.68        63
#       DEBRIS       0.76      0.63      0.69        62
#       MUCOSA       0.66      0.67      0.66        63
#      ADIPOSE       0.97      0.90      0.93        63
#        EMPTY       0.90      1.00      0.95        62
#
#     accuracy                           0.69       500
#    macro avg       0.75      0.69      0.66       500
# weighted avg       0.75      0.69      0.66       500
#
# AUC 0.9538
# loss: 0.81 acc: 0.69
# Before  4500
# Y TRAIN [4 5 5 ... 0 0 0]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.3545 - accuracy: 0.4489
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9811 - accuracy: 0.5987
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9283 - accuracy: 0.6253
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8767 - accuracy: 0.6518
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8815 - accuracy: 0.6538
# Epoch 6/8
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8499 - accuracy: 0.6713
# Epoch 7/8
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8098 - accuracy: 0.6784
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8120 - accuracy: 0.6760
# Predictions Counter({3: 171, 4: 81, 7: 74, 6: 54, 2: 45, 1: 36, 5: 35, 0: 4})
#
# Confusion matrix
# [[ 4  1  1 52  0  4  0  0]
#  [ 0 23  6  3 28  2  0  0]
#  [ 0  6 37 16  3  1  0  0]
#  [ 0  0  0 63  0  0  0  0]
#  [ 0  4  0  1 48  6  3  0]
#  [ 0  2  1 36  2 22  0  0]
#  [ 0  0  0  0  0  0 51 12]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       1.00      0.06      0.12        62
#       STROMA       0.64      0.37      0.47        62
#      COMPLEX       0.82      0.59      0.69        63
#       LYMPHO       0.37      1.00      0.54        63
#       DEBRIS       0.59      0.77      0.67        62
#       MUCOSA       0.63      0.35      0.45        63
#      ADIPOSE       0.94      0.81      0.87        63
#        EMPTY       0.84      1.00      0.91        62
#
#     accuracy                           0.62       500
#    macro avg       0.73      0.62      0.59       500
# weighted avg       0.73      0.62      0.59       500
#
# AUC 0.9422
# loss: 1.04 acc: 0.62
# Sacando la gráfica del modelo
# The media value acc is   0.6365999966859818 And the value auc is  0.9427265149928686 And the activation function is  ['tanh', 'tanh', 'tanh', 'tanh', 'softmax']
# AND WITH THE OPTIMIZER adam
# THE BEST MODEL IS  ['relu', 'relu', 'relu', 'relu', 'softmax']
# WITH A EPOCH_NUMBER OF  8  AND A BATCH SIZE OF  32
# BEST MEDIA AUC  0.9396195659898305
# BEST MEDIA ACC  0.621999990940094
# AND WITH DATA_AUGMENTATION  True
# FIRST MODEL GRAPHIC

# %%
get_best_optimizer(True)
# Out:
# The new size is  8 ,  32
# Before  4500
# Y TRAIN [7 7 6 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3764 - accuracy: 0.3962
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0568 - accuracy: 0.5478
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0071 - accuracy: 0.5787
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9307 - accuracy: 0.6184
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9365 - accuracy: 0.6082
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9189 - accuracy: 0.6104
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8693 - accuracy: 0.6464
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8841 - accuracy: 0.6338
# Predictions Counter({0: 88, 7: 88, 2: 73, 4: 65, 5: 55, 1: 46, 3: 46, 6: 39})
#
# Confusion matrix
# [[51  0  3  3  0  6  0  0]
#  [ 0 25 15  0 23  0  0  0]
#  [ 8  7 45  0  0  2  0  0]
#  [16  0  2 41  0  3  0  0]
#  [ 0 13  3  0 38  6  3  0]
#  [13  1  5  2  3 38  0  0]
#  [ 0  0  0  0  1  0 36 25]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.58      0.81      0.68        63
#       STROMA       0.54      0.40      0.46        63
#      COMPLEX       0.62      0.73      0.67        62
#       LYMPHO       0.89      0.66      0.76        62
#       DEBRIS       0.58      0.60      0.59        63
#       MUCOSA       0.69      0.61      0.65        62
#      ADIPOSE       0.92      0.58      0.71        62
#        EMPTY       0.72      1.00      0.83        63
#
#     accuracy                           0.67       500
#    macro avg       0.69      0.67      0.67       500
# weighted avg       0.69      0.67      0.67       500
#
# AUC 0.9548
# loss: 0.80 acc: 0.67
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3312 - accuracy: 0.4467
# Epoch 2/8
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0476 - accuracy: 0.5447
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0581 - accuracy: 0.5382
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9482 - accuracy: 0.5958
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9342 - accuracy: 0.6096
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9022 - accuracy: 0.6316
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8668 - accuracy: 0.6449
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8905 - accuracy: 0.6282
# Predictions Counter({3: 132, 2: 106, 7: 62, 6: 56, 1: 54, 5: 34, 4: 30, 0: 26})
#
# Confusion matrix
# [[22  0  3 33  0  5  0  0]
#  [ 0 24 34  0  2  3  0  0]
#  [ 1  1 51  9  0  0  0  0]
#  [ 0  0  4 57  0  1  0  0]
#  [ 0 29  5  0 20  8  1  0]
#  [ 3  0  9 33  0 17  0  0]
#  [ 0  0  0  0  7  0 52  3]
#  [ 0  0  0  0  1  0  3 59]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.85      0.35      0.49        63
#       STROMA       0.44      0.38      0.41        63
#      COMPLEX       0.48      0.82      0.61        62
#       LYMPHO       0.43      0.92      0.59        62
#       DEBRIS       0.67      0.32      0.43        63
#       MUCOSA       0.50      0.27      0.35        62
#      ADIPOSE       0.93      0.84      0.88        62
#        EMPTY       0.95      0.94      0.94        63
#
#     accuracy                           0.60       500
#    macro avg       0.66      0.60      0.59       500
# weighted avg       0.66      0.60      0.59       500
#
# AUC 0.9493
# loss: 0.94 acc: 0.60
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5612 - accuracy: 0.3340
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1117 - accuracy: 0.5224
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0262 - accuracy: 0.5622
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9751 - accuracy: 0.5791
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9648 - accuracy: 0.5964
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9058 - accuracy: 0.6398
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8852 - accuracy: 0.6347
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9062 - accuracy: 0.6216
# Predictions Counter({3: 138, 6: 111, 4: 82, 5: 74, 2: 51, 1: 33, 0: 11})
#
# Confusion matrix
# [[ 9  0  0 47  1  6  0  0]
#  [ 0 23 17  0 17  6  0  0]
#  [ 1  2 30 12  1 16  0  0]
#  [ 1  0  0 58  0  3  0  0]
#  [ 0  8  3  1 48  3  0  0]
#  [ 0  0  1 20  1 40  0  0]
#  [ 0  0  0  0 14  0 48  0]
#  [ 0  0  0  0  0  0 63  0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.82      0.14      0.24        63
#       STROMA       0.70      0.37      0.48        63
#      COMPLEX       0.59      0.48      0.53        62
#       LYMPHO       0.42      0.94      0.58        62
#       DEBRIS       0.59      0.76      0.66        63
#       MUCOSA       0.54      0.65      0.59        62
#      ADIPOSE       0.43      0.77      0.55        62
#        EMPTY       0.00      0.00      0.00        63
#
#     accuracy                           0.51       500
#    macro avg       0.51      0.51      0.45       500
# weighted avg       0.51      0.51      0.45       500
#
# AUC 0.9286
# loss: 1.14 acc: 0.51
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5253 - accuracy: 0.3487
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0382 - accuracy: 0.5596
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9892 - accuracy: 0.5678
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9317 - accuracy: 0.6036
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8995 - accuracy: 0.6256
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8873 - accuracy: 0.6500
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8115 - accuracy: 0.6911
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8679 - accuracy: 0.6456
# Predictions Counter({3: 139, 1: 78, 7: 64, 2: 59, 6: 55, 5: 51, 4: 44, 0: 10})
#
# Confusion matrix
# [[ 9  0  1 50  0  3  0  0]
#  [ 0 39 13  0  9  2  0  0]
#  [ 0  9 36 11  0  6  0  0]
#  [ 1  0  2 55  0  4  0  0]
#  [ 0 29  4  0 27  2  1  0]
#  [ 0  1  3 23  1 34  0  0]
#  [ 0  0  0  0  7  0 51  4]
#  [ 0  0  0  0  0  0  3 60]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.90      0.14      0.25        63
#       STROMA       0.50      0.62      0.55        63
#      COMPLEX       0.61      0.58      0.60        62
#       LYMPHO       0.40      0.89      0.55        62
#       DEBRIS       0.61      0.43      0.50        63
#       MUCOSA       0.67      0.55      0.60        62
#      ADIPOSE       0.93      0.82      0.87        62
#        EMPTY       0.94      0.95      0.94        63
#
#     accuracy                           0.62       500
#    macro avg       0.69      0.62      0.61       500
# weighted avg       0.69      0.62      0.61       500
#
# AUC 0.9432
# loss: 0.99 acc: 0.62
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3648 - accuracy: 0.4347
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0097 - accuracy: 0.5593
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9736 - accuracy: 0.5849
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9522 - accuracy: 0.6076
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8837 - accuracy: 0.6338
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8525 - accuracy: 0.6504
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 0.7939 - accuracy: 0.6813
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.7829 - accuracy: 0.6869
# Predictions Counter({3: 135, 4: 93, 7: 81, 2: 53, 6: 47, 5: 47, 1: 25, 0: 19})
#
# Confusion matrix
# [[16  0  2 39  1  5  0  0]
#  [ 0 21 12  0 29  1  0  0]
#  [ 0  1 35 16  6  4  0  0]
#  [ 0  0  2 59  0  1  0  0]
#  [ 0  3  1  1 55  0  3  0]
#  [ 3  0  1 20  2 36  0  0]
#  [ 0  0  0  0  0  0 44 18]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.84      0.25      0.39        63
#       STROMA       0.84      0.33      0.48        63
#      COMPLEX       0.66      0.56      0.61        62
#       LYMPHO       0.44      0.95      0.60        62
#       DEBRIS       0.59      0.87      0.71        63
#       MUCOSA       0.77      0.58      0.66        62
#      ADIPOSE       0.94      0.71      0.81        62
#        EMPTY       0.78      1.00      0.88        63
#
#     accuracy                           0.66       500
#    macro avg       0.73      0.66      0.64       500
# weighted avg       0.73      0.66      0.64       500
#
# AUC 0.9561
# loss: 0.94 acc: 0.66
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5670 - accuracy: 0.3156
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1182 - accuracy: 0.5240
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0139 - accuracy: 0.5642
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0128 - accuracy: 0.5616
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9384 - accuracy: 0.6004
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9287 - accuracy: 0.6000
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9048 - accuracy: 0.6151
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8610 - accuracy: 0.6320
# Predictions Counter({3: 152, 6: 113, 1: 66, 5: 64, 2: 56, 4: 44, 0: 5})
#
# Confusion matrix
# [[ 4  0  2 51  0  5  0  0]
#  [ 0 38 17  0  3  4  0  0]
#  [ 1  3 32 20  0  7  0  0]
#  [ 0  0  1 60  0  2  0  0]
#  [ 0 25  4  1 27  5  0  0]
#  [ 0  0  0 20  2 41  0  0]
#  [ 0  0  0  0 12  0 51  0]
#  [ 0  0  0  0  0  0 62  0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.80      0.06      0.12        62
#       STROMA       0.58      0.61      0.59        62
#      COMPLEX       0.57      0.51      0.54        63
#       LYMPHO       0.39      0.95      0.56        63
#       DEBRIS       0.61      0.44      0.51        62
#       MUCOSA       0.64      0.65      0.65        63
#      ADIPOSE       0.45      0.81      0.58        63
#        EMPTY       0.00      0.00      0.00        62
#
#     accuracy                           0.51       500
#    macro avg       0.51      0.50      0.44       500
# weighted avg       0.51      0.51      0.44       500
#
# AUC 0.9165
# loss: 1.16 acc: 0.51
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3725 - accuracy: 0.4151
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0157 - accuracy: 0.5589
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9810 - accuracy: 0.5744
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9447 - accuracy: 0.5980
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9366 - accuracy: 0.6042
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8938 - accuracy: 0.6322
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8657 - accuracy: 0.6553
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8436 - accuracy: 0.6560
# Predictions Counter({3: 166, 7: 71, 1: 57, 6: 52, 2: 46, 5: 42, 4: 42, 0: 24})
#
# Confusion matrix
# [[13  0  0 46  0  3  0  0]
#  [ 0 33 15  1  7  6  0  0]
#  [ 7  0 26 27  1  2  0  0]
#  [ 2  0  1 60  0  0  0  0]
#  [ 0 23  3  0 26  6  4  0]
#  [ 2  1  1 32  2 25  0  0]
#  [ 0  0  0  0  6  0 48  9]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.54      0.21      0.30        62
#       STROMA       0.58      0.53      0.55        62
#      COMPLEX       0.57      0.41      0.48        63
#       LYMPHO       0.36      0.95      0.52        63
#       DEBRIS       0.62      0.42      0.50        62
#       MUCOSA       0.60      0.40      0.48        63
#      ADIPOSE       0.92      0.76      0.83        63
#        EMPTY       0.87      1.00      0.93        62
#
#     accuracy                           0.59       500
#    macro avg       0.63      0.59      0.58       500
# weighted avg       0.63      0.59      0.58       500
#
# AUC 0.9281
# loss: 1.12 acc: 0.59
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4252 - accuracy: 0.3922
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0389 - accuracy: 0.5498
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9623 - accuracy: 0.5833
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9568 - accuracy: 0.5876
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9209 - accuracy: 0.6042
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8884 - accuracy: 0.6289
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8865 - accuracy: 0.6309
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8760 - accuracy: 0.6382
# Predictions Counter({5: 124, 1: 82, 7: 66, 6: 61, 3: 59, 2: 46, 0: 36, 4: 26})
#
# Confusion matrix
# [[26  0  3  9  0 24  0  0]
#  [ 0 44  9  0  2  7  0  0]
#  [ 1  8 31  0  1 22  0  0]
#  [ 7  0  0 50  0  6  0  0]
#  [ 0 30  3  0 22  5  2  0]
#  [ 2  0  0  0  1 60  0  0]
#  [ 0  0  0  0  0  0 59  4]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.72      0.42      0.53        62
#       STROMA       0.54      0.71      0.61        62
#      COMPLEX       0.67      0.49      0.57        63
#       LYMPHO       0.85      0.79      0.82        63
#       DEBRIS       0.85      0.35      0.50        62
#       MUCOSA       0.48      0.95      0.64        63
#      ADIPOSE       0.97      0.94      0.95        63
#        EMPTY       0.94      1.00      0.97        62
#
#     accuracy                           0.71       500
#    macro avg       0.75      0.71      0.70       500
# weighted avg       0.75      0.71      0.70       500
#
# AUC 0.9602
# loss: 0.74 acc: 0.71
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3554 - accuracy: 0.4167
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0803 - accuracy: 0.5393
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9949 - accuracy: 0.5707
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9966 - accuracy: 0.5642
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9404 - accuracy: 0.5967
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9065 - accuracy: 0.6009
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9170 - accuracy: 0.6153
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8369 - accuracy: 0.6509
# Predictions Counter({6: 123, 3: 114, 2: 86, 5: 62, 1: 60, 4: 32, 0: 23})
#
# Confusion matrix
# [[19  0  3 32  0  8  0  0]
#  [ 0 33 18  0  6  5  0  0]
#  [ 0  8 49  4  0  2  0  0]
#  [ 2  0  7 54  0  0  0  0]
#  [ 0 19  6  0 21 13  3  0]
#  [ 2  0  3 24  0 34  0  0]
#  [ 0  0  0  0  5  0 58  0]
#  [ 0  0  0  0  0  0 62  0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.83      0.31      0.45        62
#       STROMA       0.55      0.53      0.54        62
#      COMPLEX       0.57      0.78      0.66        63
#       LYMPHO       0.47      0.86      0.61        63
#       DEBRIS       0.66      0.34      0.45        62
#       MUCOSA       0.55      0.54      0.54        63
#      ADIPOSE       0.47      0.92      0.62        63
#        EMPTY       0.00      0.00      0.00        62
#
#     accuracy                           0.54       500
#    macro avg       0.51      0.53      0.48       500
# weighted avg       0.51      0.54      0.48       500
#
# AUC 0.9517
# loss: 0.91 acc: 0.54
# Before  4500
# Y TRAIN [4 5 5 ... 0 0 0]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5856 - accuracy: 0.3273
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1732 - accuracy: 0.4613
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0896 - accuracy: 0.5224
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0442 - accuracy: 0.5476
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0540 - accuracy: 0.5360
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0614 - accuracy: 0.5407
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0261 - accuracy: 0.5473
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9742 - accuracy: 0.5907
# Predictions Counter({3: 126, 7: 91, 4: 83, 2: 72, 1: 49, 6: 45, 5: 31, 0: 3})
#
# Confusion matrix
# [[ 2  1  8 46  0  5  0  0]
#  [ 0 21  8  0 31  0  2  0]
#  [ 0 11 39  5  7  1  0  0]
#  [ 1  0  2 60  0  0  0  0]
#  [ 0  8  3  0 42  0  9  0]
#  [ 0  8 12 15  3 25  0  0]
#  [ 0  0  0  0  0  0 34 29]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.67      0.03      0.06        62
#       STROMA       0.43      0.34      0.38        62
#      COMPLEX       0.54      0.62      0.58        63
#       LYMPHO       0.48      0.95      0.63        63
#       DEBRIS       0.51      0.68      0.58        62
#       MUCOSA       0.81      0.40      0.53        63
#      ADIPOSE       0.76      0.54      0.63        63
#        EMPTY       0.68      1.00      0.81        62
#
#     accuracy                           0.57       500
#    macro avg       0.61      0.57      0.53       500
# weighted avg       0.61      0.57      0.53       500
#
# AUC 0.9445
# loss: 0.94 acc: 0.57
# The media value acc is   0.5976000010967255 And the value auc is  0.9433003789983069 And the activation optimizer is  adam
# The new size is  8 ,  32
# Before  4500
# Y TRAIN [7 7 6 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.9784 - accuracy: 0.1716
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.6638 - accuracy: 0.2831
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.4895 - accuracy: 0.3478
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.4099 - accuracy: 0.3920
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2690 - accuracy: 0.4393
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1952 - accuracy: 0.4644
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1225 - accuracy: 0.4931
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0899 - accuracy: 0.5169
# Predictions Counter({6: 128, 3: 120, 5: 102, 4: 73, 2: 51, 1: 22, 0: 4})
#
# Confusion matrix
# [[ 4  0  0 49  0 10  0  0]
#  [ 0 12 13  0 28 10  0  0]
#  [ 0  1 35  3  5 18  0  0]
#  [ 0  0  1 55  0  6  0  0]
#  [ 0  9  2  0 38 11  3  0]
#  [ 0  0  0 13  2 47  0  0]
#  [ 0  0  0  0  0  0 62  0]
#  [ 0  0  0  0  0  0 63  0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       1.00      0.06      0.12        63
#       STROMA       0.55      0.19      0.28        63
#      COMPLEX       0.69      0.56      0.62        62
#       LYMPHO       0.46      0.89      0.60        62
#       DEBRIS       0.52      0.60      0.56        63
#       MUCOSA       0.46      0.76      0.57        62
#      ADIPOSE       0.48      1.00      0.65        62
#        EMPTY       0.00      0.00      0.00        63
#
#     accuracy                           0.51       500
#    macro avg       0.52      0.51      0.43       500
# weighted avg       0.52      0.51      0.42       500
#
# AUC 0.9334
# loss: 1.01 acc: 0.51
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.9363 - accuracy: 0.2049
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.5604 - accuracy: 0.3291
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.3402 - accuracy: 0.4044
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.2353 - accuracy: 0.4489
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1491 - accuracy: 0.4816
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1093 - accuracy: 0.4987
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0827 - accuracy: 0.5222
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0703 - accuracy: 0.5198
# Predictions Counter({1: 103, 0: 95, 5: 80, 7: 78, 2: 48, 6: 46, 3: 28, 4: 22})
#
# Confusion matrix
# [[40  1  1 10  0 11  0  0]
#  [ 0 53  6  0  2  2  0  0]
#  [ 4 13 38  0  0  7  0  0]
#  [34  0  0 18  0 10  0  0]
#  [ 0 35  0  0 17 10  1  0]
#  [17  1  3  0  1 40  0  0]
#  [ 0  0  0  0  1  0 45 16]
#  [ 0  0  0  0  1  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.42      0.63      0.51        63
#       STROMA       0.51      0.84      0.64        63
#      COMPLEX       0.79      0.61      0.69        62
#       LYMPHO       0.64      0.29      0.40        62
#       DEBRIS       0.77      0.27      0.40        63
#       MUCOSA       0.50      0.65      0.56        62
#      ADIPOSE       0.98      0.73      0.83        62
#        EMPTY       0.79      0.98      0.88        63
#
#     accuracy                           0.63       500
#    macro avg       0.68      0.63      0.61       500
# weighted avg       0.68      0.63      0.61       500
#
# AUC 0.9445
# loss: 0.89 acc: 0.63
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.9412 - accuracy: 0.1780
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.6317 - accuracy: 0.3062
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4938 - accuracy: 0.3491
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4025 - accuracy: 0.3824
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2763 - accuracy: 0.4218
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1976 - accuracy: 0.4651
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1498 - accuracy: 0.4833
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1395 - accuracy: 0.4644
# Predictions Counter({3: 125, 5: 92, 7: 74, 1: 61, 2: 58, 6: 55, 4: 30, 0: 5})
#
# Confusion matrix
# [[ 2  0  0 52  0  9  0  0]
#  [ 0 35 17  0  8  2  1  0]
#  [ 0  2 37  6  1 16  0  0]
#  [ 1  0  1 49  0 11  0  0]
#  [ 0 24  3  0 20 12  4  0]
#  [ 2  0  0 18  0 42  0  0]
#  [ 0  0  0  0  1  0 47 14]
#  [ 0  0  0  0  0  0  3 60]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.40      0.03      0.06        63
#       STROMA       0.57      0.56      0.56        63
#      COMPLEX       0.64      0.60      0.62        62
#       LYMPHO       0.39      0.79      0.52        62
#       DEBRIS       0.67      0.32      0.43        63
#       MUCOSA       0.46      0.68      0.55        62
#      ADIPOSE       0.85      0.76      0.80        62
#        EMPTY       0.81      0.95      0.88        63
#
#     accuracy                           0.58       500
#    macro avg       0.60      0.58      0.55       500
# weighted avg       0.60      0.58      0.55       500
#
# AUC 0.9355
# loss: 0.99 acc: 0.58
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.8421 - accuracy: 0.2316
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5512 - accuracy: 0.3087
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4732 - accuracy: 0.3416
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4111 - accuracy: 0.3691
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3150 - accuracy: 0.4109
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2140 - accuracy: 0.4573
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1845 - accuracy: 0.4649
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1438 - accuracy: 0.4729
# Predictions Counter({7: 134, 5: 121, 4: 119, 1: 71, 2: 20, 6: 18, 0: 9, 3: 8})
#
# Confusion matrix
# [[ 3  1 11  2  3 43  0  0]
#  [ 0 15  0  0 44  0  4  0]
#  [ 0 39  3  0 14  4  2  0]
#  [ 6  8  6  6  0 36  0  0]
#  [ 0  1  0  0 43  0  9 10]
#  [ 0  7  0  0 15 38  2  0]
#  [ 0  0  0  0  0  0  1 61]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.33      0.05      0.08        63
#       STROMA       0.21      0.24      0.22        63
#      COMPLEX       0.15      0.05      0.07        62
#       LYMPHO       0.75      0.10      0.17        62
#       DEBRIS       0.36      0.68      0.47        63
#       MUCOSA       0.31      0.61      0.42        62
#      ADIPOSE       0.06      0.02      0.02        62
#        EMPTY       0.47      1.00      0.64        63
#
#     accuracy                           0.34       500
#    macro avg       0.33      0.34      0.26       500
# weighted avg       0.33      0.34      0.26       500
#
# AUC 0.8584
# loss: 1.56 acc: 0.34
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0505 - accuracy: 0.1798
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.7229 - accuracy: 0.2880
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5555 - accuracy: 0.3244
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3457 - accuracy: 0.4118
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2573 - accuracy: 0.4413
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1949 - accuracy: 0.4569
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.1427 - accuracy: 0.4836
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1148 - accuracy: 0.4922
# Predictions Counter({6: 138, 5: 104, 3: 88, 2: 69, 4: 48, 1: 37, 0: 16})
#
# Confusion matrix
# [[14  1  6 33  1  8  0  0]
#  [ 0 22 18  0 16  6  1  0]
#  [ 0  1 37  4  1 19  0  0]
#  [ 0  0  1 46  0 15  0  0]
#  [ 0 13  3  0 29  6 12  0]
#  [ 2  0  4  5  1 50  0  0]
#  [ 0  0  0  0  0  0 62  0]
#  [ 0  0  0  0  0  0 63  0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.88      0.22      0.35        63
#       STROMA       0.59      0.35      0.44        63
#      COMPLEX       0.54      0.60      0.56        62
#       LYMPHO       0.52      0.74      0.61        62
#       DEBRIS       0.60      0.46      0.52        63
#       MUCOSA       0.48      0.81      0.60        62
#      ADIPOSE       0.45      1.00      0.62        62
#        EMPTY       0.00      0.00      0.00        63
#
#     accuracy                           0.52       500
#    macro avg       0.51      0.52      0.46       500
# weighted avg       0.51      0.52      0.46       500
#
# AUC 0.9306
# loss: 1.05 acc: 0.52
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.9929 - accuracy: 0.2073
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.6420 - accuracy: 0.2933
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5082 - accuracy: 0.3360
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3968 - accuracy: 0.3824
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3022 - accuracy: 0.4142
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2251 - accuracy: 0.4391
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1595 - accuracy: 0.4669
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.1443 - accuracy: 0.4864
# Predictions Counter({3: 95, 1: 93, 2: 85, 6: 74, 7: 68, 0: 52, 4: 19, 5: 14})
#
# Confusion matrix
# [[16  0  9 37  0  0  0  0]
#  [ 0 46 10  0  6  0  0  0]
#  [ 8 13 39  3  0  0  0  0]
#  [15  0  8 40  0  0  0  0]
#  [ 0 32  3  0 10  1 16  0]
#  [13  2 16 15  3 13  1  0]
#  [ 0  0  0  0  0  0 53 10]
#  [ 0  0  0  0  0  0  4 58]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.31      0.26      0.28        62
#       STROMA       0.49      0.74      0.59        62
#      COMPLEX       0.46      0.62      0.53        63
#       LYMPHO       0.42      0.63      0.51        63
#       DEBRIS       0.53      0.16      0.25        62
#       MUCOSA       0.93      0.21      0.34        63
#      ADIPOSE       0.72      0.84      0.77        63
#        EMPTY       0.85      0.94      0.89        62
#
#     accuracy                           0.55       500
#    macro avg       0.59      0.55      0.52       500
# weighted avg       0.59      0.55      0.52       500
#
# AUC 0.9296
# loss: 1.05 acc: 0.55
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0178 - accuracy: 0.1431
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.7128 - accuracy: 0.2824
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.4887 - accuracy: 0.3538
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3016 - accuracy: 0.4253
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1865 - accuracy: 0.4596
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1235 - accuracy: 0.4813
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1083 - accuracy: 0.4853
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0573 - accuracy: 0.5129
# Predictions Counter({2: 104, 0: 98, 1: 85, 7: 72, 5: 55, 6: 47, 4: 38, 3: 1})
#
# Confusion matrix
# [[44  0 10  0  0  8  0  0]
#  [ 0 42 10  0  8  2  0  0]
#  [ 3  9 49  0  0  2  0  0]
#  [47  0 12  1  0  3  0  0]
#  [ 0 31  2  0 21  5  3  0]
#  [ 4  3 21  0  0 35  0  0]
#  [ 0  0  0  0  9  0 44 10]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.45      0.71      0.55        62
#       STROMA       0.49      0.68      0.57        62
#      COMPLEX       0.47      0.78      0.59        63
#       LYMPHO       1.00      0.02      0.03        63
#       DEBRIS       0.55      0.34      0.42        62
#       MUCOSA       0.64      0.56      0.59        63
#      ADIPOSE       0.94      0.70      0.80        63
#        EMPTY       0.86      1.00      0.93        62
#
#     accuracy                           0.60       500
#    macro avg       0.68      0.60      0.56       500
# weighted avg       0.68      0.60      0.56       500
#
# AUC 0.9403
# loss: 0.94 acc: 0.60
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.9783 - accuracy: 0.1582
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.6322 - accuracy: 0.2780
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.5036 - accuracy: 0.3389
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4283 - accuracy: 0.3720
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3703 - accuracy: 0.3909
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3188 - accuracy: 0.4109
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2554 - accuracy: 0.4496
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.2313 - accuracy: 0.4476
# Predictions Counter({0: 126, 2: 96, 6: 70, 7: 56, 1: 52, 4: 52, 5: 38, 3: 10})
#
# Confusion matrix
# [[47  0  4  2  2  7  0  0]
#  [ 0 29 23  0  9  1  0  0]
#  [ 8  4 46  0  2  3  0  0]
#  [53  0  1  8  0  1  0  0]
#  [ 0 17  1  0 37  5  2  0]
#  [18  2 21  0  1 21  0  0]
#  [ 0  0  0  0  1  0 58  4]
#  [ 0  0  0  0  0  0 10 52]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.37      0.76      0.50        62
#       STROMA       0.56      0.47      0.51        62
#      COMPLEX       0.48      0.73      0.58        63
#       LYMPHO       0.80      0.13      0.22        63
#       DEBRIS       0.71      0.60      0.65        62
#       MUCOSA       0.55      0.33      0.42        63
#      ADIPOSE       0.83      0.92      0.87        63
#        EMPTY       0.93      0.84      0.88        62
#
#     accuracy                           0.60       500
#    macro avg       0.65      0.60      0.58       500
# weighted avg       0.65      0.60      0.58       500
#
# AUC 0.9206
# loss: 1.08 acc: 0.60
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.8752 - accuracy: 0.2240
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.5239 - accuracy: 0.3247
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4292 - accuracy: 0.3682
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.3309 - accuracy: 0.4087
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2713 - accuracy: 0.4264
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1862 - accuracy: 0.4733
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1760 - accuracy: 0.4853
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.1312 - accuracy: 0.4938
# Predictions Counter({3: 133, 2: 79, 1: 74, 7: 70, 6: 58, 4: 57, 5: 29})
#
# Confusion matrix
# [[ 0  1  5 51  0  5  0  0]
#  [ 0 38 10  0 14  0  0  0]
#  [ 0 15 44  2  1  1  0  0]
#  [ 0  0  6 55  0  2  0  0]
#  [ 0 20  2  0 33  2  4  1]
#  [ 0  0 12 25  7 19  0  0]
#  [ 0  0  0  0  2  0 54  7]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        62
#       STROMA       0.51      0.61      0.56        62
#      COMPLEX       0.56      0.70      0.62        63
#       LYMPHO       0.41      0.87      0.56        63
#       DEBRIS       0.58      0.53      0.55        62
#       MUCOSA       0.66      0.30      0.41        63
#      ADIPOSE       0.93      0.86      0.89        63
#        EMPTY       0.89      1.00      0.94        62
#
#     accuracy                           0.61       500
#    macro avg       0.57      0.61      0.57       500
# weighted avg       0.57      0.61      0.57       500
#
# AUC 0.9411
# loss: 0.97 acc: 0.61
# Before  4500
# Y TRAIN [4 5 5 ... 0 0 0]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.8823 - accuracy: 0.2227
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.5454 - accuracy: 0.3204
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.4069 - accuracy: 0.3676
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3042 - accuracy: 0.4149
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2069 - accuracy: 0.4502
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 1.1656 - accuracy: 0.4767
# Epoch 7/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1108 - accuracy: 0.4933
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1155 - accuracy: 0.4944
# Predictions Counter({4: 110, 3: 101, 2: 78, 7: 77, 6: 49, 1: 33, 5: 32, 0: 20})
#
# Confusion matrix
# [[ 9  2  9 37  0  5  0  0]
#  [ 0 16  9  0 35  2  0  0]
#  [ 0 10 38  2 10  3  0  0]
#  [ 5  0  4 53  0  1  0  0]
#  [ 0  2  2  0 56  1  1  0]
#  [ 6  3 16  9  9 20  0  0]
#  [ 0  0  0  0  0  0 48 15]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.45      0.15      0.22        62
#       STROMA       0.48      0.26      0.34        62
#      COMPLEX       0.49      0.60      0.54        63
#       LYMPHO       0.52      0.84      0.65        63
#       DEBRIS       0.51      0.90      0.65        62
#       MUCOSA       0.62      0.32      0.42        63
#      ADIPOSE       0.98      0.76      0.86        63
#        EMPTY       0.81      1.00      0.89        62
#
#     accuracy                           0.60       500
#    macro avg       0.61      0.60      0.57       500
# weighted avg       0.61      0.60      0.57       500
#
# AUC 0.9368
# loss: 0.96 acc: 0.60
# The media value acc is   0.5535999983549118 And the value auc is  0.9270752778978769 And the activation optimizer is  sgd
# The new size is  8 ,  32
# Before  4500
# Y TRAIN [7 7 6 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0827 - accuracy: 0.1176
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0808 - accuracy: 0.1144
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0797 - accuracy: 0.1147
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0775 - accuracy: 0.1113
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0762 - accuracy: 0.1073
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0754 - accuracy: 0.1073
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0735 - accuracy: 0.1093
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0724 - accuracy: 0.1089
# Predictions Counter({3: 352, 6: 119, 4: 27, 2: 2})
#
# Confusion matrix
# [[ 0  0  0 49  3  0 11  0]
#  [ 0  0  0 23  9  0 31  0]
#  [ 0  0  0 38  2  0 22  0]
#  [ 0  0  1 42  1  0 18  0]
#  [ 0  0  0 38  3  0 22  0]
#  [ 0  0  1 45  5  0 11  0]
#  [ 0  0  0 54  4  0  4  0]
#  [ 0  0  0 63  0  0  0  0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        63
#       STROMA       0.00      0.00      0.00        63
#      COMPLEX       0.00      0.00      0.00        62
#       LYMPHO       0.12      0.68      0.20        62
#       DEBRIS       0.11      0.05      0.07        63
#       MUCOSA       0.00      0.00      0.00        62
#      ADIPOSE       0.03      0.06      0.04        62
#        EMPTY       0.00      0.00      0.00        63
#
#     accuracy                           0.10       500
#    macro avg       0.03      0.10      0.04       500
# weighted avg       0.03      0.10      0.04       500
#
# AUC 0.6350
# loss: 2.07 acc: 0.10
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0776 - accuracy: 0.1069
# Epoch 2/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0724 - accuracy: 0.2049
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0679 - accuracy: 0.1878
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0629 - accuracy: 0.1813
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0579 - accuracy: 0.1667
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0546 - accuracy: 0.1642
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0515 - accuracy: 0.1580
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0484 - accuracy: 0.1493
# Predictions Counter({7: 442, 2: 22, 6: 17, 3: 14, 1: 4, 4: 1})
#
# Confusion matrix
# [[ 0  1  7  9  0  0  3 43]
#  [ 0  0  2  0  0  0  2 59]
#  [ 0  2  5  2  1  0  3 49]
#  [ 0  0  3  1  0  0  3 55]
#  [ 0  1  2  0  0  0  3 57]
#  [ 0  0  3  2  0  0  3 54]
#  [ 0  0  0  0  0  0  0 62]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        63
#       STROMA       0.00      0.00      0.00        63
#      COMPLEX       0.23      0.08      0.12        62
#       LYMPHO       0.07      0.02      0.03        62
#       DEBRIS       0.00      0.00      0.00        63
#       MUCOSA       0.00      0.00      0.00        62
#      ADIPOSE       0.00      0.00      0.00        62
#        EMPTY       0.14      1.00      0.25        63
#
#     accuracy                           0.14       500
#    macro avg       0.06      0.14      0.05       500
# weighted avg       0.05      0.14      0.05       500
#
# AUC 0.6543
# loss: 2.05 acc: 0.14
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0828 - accuracy: 0.1349
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0782 - accuracy: 0.1284
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0753 - accuracy: 0.1469
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0720 - accuracy: 0.2436
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0692 - accuracy: 0.2331
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0651 - accuracy: 0.2320
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0627 - accuracy: 0.2124
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0614 - accuracy: 0.2036
# Predictions Counter({4: 224, 7: 213, 2: 63})
#
# Confusion matrix
# [[ 0  0 10  0 37  0  0 16]
#  [ 0  0 10  0 40  0  0 13]
#  [ 0  0 10  0 43  0  0  9]
#  [ 0  0 12  0 38  0  0 12]
#  [ 0  0 11  0 27  0  0 25]
#  [ 0  0 10  0 37  0  0 15]
#  [ 0  0  0  0  2  0  0 60]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        63
#       STROMA       0.00      0.00      0.00        63
#      COMPLEX       0.16      0.16      0.16        62
#       LYMPHO       0.00      0.00      0.00        62
#       DEBRIS       0.12      0.43      0.19        63
#       MUCOSA       0.00      0.00      0.00        62
#      ADIPOSE       0.00      0.00      0.00        62
#        EMPTY       0.30      1.00      0.46        63
#
#     accuracy                           0.20       500
#    macro avg       0.07      0.20      0.10       500
# weighted avg       0.07      0.20      0.10       500
#
# AUC 0.6531
# loss: 2.06 acc: 0.20
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0883 - accuracy: 0.1109
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0873 - accuracy: 0.1144
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0864 - accuracy: 0.1149
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0859 - accuracy: 0.1193
# Epoch 5/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0854 - accuracy: 0.1229
# Epoch 6/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0851 - accuracy: 0.1218
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0846 - accuracy: 0.1238
# Epoch 8/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0834 - accuracy: 0.1216
# Predictions Counter({0: 496, 7: 4})
#
# Confusion matrix
# [[62  0  0  0  0  0  0  1]
#  [63  0  0  0  0  0  0  0]
#  [61  0  0  0  0  0  0  1]
#  [62  0  0  0  0  0  0  0]
#  [63  0  0  0  0  0  0  0]
#  [61  0  0  0  0  0  0  1]
#  [61  0  0  0  0  0  0  1]
#  [63  0  0  0  0  0  0  0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.12      0.98      0.22        63
#       STROMA       0.00      0.00      0.00        63
#      COMPLEX       0.00      0.00      0.00        62
#       LYMPHO       0.00      0.00      0.00        62
#       DEBRIS       0.00      0.00      0.00        63
#       MUCOSA       0.00      0.00      0.00        62
#      ADIPOSE       0.00      0.00      0.00        62
#        EMPTY       0.00      0.00      0.00        63
#
#     accuracy                           0.12       500
#    macro avg       0.02      0.12      0.03       500
# weighted avg       0.02      0.12      0.03       500
#
# AUC 0.4284
# loss: 2.08 acc: 0.12
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.1072 - accuracy: 0.1211
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0989 - accuracy: 0.1267
# Epoch 3/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0908 - accuracy: 0.1318
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0827 - accuracy: 0.1340
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0760 - accuracy: 0.1329
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0694 - accuracy: 0.1376
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0635 - accuracy: 0.1256
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0571 - accuracy: 0.1338
# Predictions Counter({0: 243, 4: 169, 5: 79, 1: 6, 6: 3})
#
# Confusion matrix
# [[36  4  0  0  6 16  1  0]
#  [50  0  0  0  3 10  0  0]
#  [48  0  0  0  2 12  0  0]
#  [36  1  0  0 11 13  1  0]
#  [37  0  0  0 13 13  0  0]
#  [35  1  0  0 10 15  1  0]
#  [ 1  0  0  0 61  0  0  0]
#  [ 0  0  0  0 63  0  0  0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.15      0.57      0.24        63
#       STROMA       0.00      0.00      0.00        63
#      COMPLEX       0.00      0.00      0.00        62
#       LYMPHO       0.00      0.00      0.00        62
#       DEBRIS       0.08      0.21      0.11        63
#       MUCOSA       0.19      0.24      0.21        62
#      ADIPOSE       0.00      0.00      0.00        62
#        EMPTY       0.00      0.00      0.00        63
#
#     accuracy                           0.13       500
#    macro avg       0.05      0.13      0.07       500
# weighted avg       0.05      0.13      0.07       500
#
# AUC 0.5711
# loss: 2.05 acc: 0.13
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0827 - accuracy: 0.2318
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0815 - accuracy: 0.2449
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0803 - accuracy: 0.2504
# Epoch 4/8
# 141/140 [==============================] - 2s 15ms/step - loss: 2.0792 - accuracy: 0.2547
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0780 - accuracy: 0.2567
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0769 - accuracy: 0.2647
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0754 - accuracy: 0.2660
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0745 - accuracy: 0.2664
# Predictions Counter({1: 373, 7: 79, 2: 18, 3: 11, 0: 9, 6: 8, 4: 2})
#
# Confusion matrix
# [[ 0 60  1  0  0  0  0  1]
#  [ 0 62  0  0  0  0  0  0]
#  [ 0 63  0  0  0  0  0  0]
#  [ 2 48  8  0  0  0  0  5]
#  [ 2 56  2  0  0  0  0  2]
#  [ 2 58  2  0  0  0  0  1]
#  [ 3 25  5 11  1  0  7 11]
#  [ 0  1  0  0  1  0  1 59]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        62
#       STROMA       0.17      1.00      0.29        62
#      COMPLEX       0.00      0.00      0.00        63
#       LYMPHO       0.00      0.00      0.00        63
#       DEBRIS       0.00      0.00      0.00        62
#       MUCOSA       0.00      0.00      0.00        63
#      ADIPOSE       0.88      0.11      0.20        63
#        EMPTY       0.75      0.95      0.84        62
#
#     accuracy                           0.26       500
#    macro avg       0.22      0.26      0.16       500
# weighted avg       0.22      0.26      0.16       500
#
# AUC 0.5563
# loss: 2.07 acc: 0.26
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 3s 18ms/step - loss: 2.0820 - accuracy: 0.1144
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0756 - accuracy: 0.1193
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0705 - accuracy: 0.1209
# Epoch 4/8
# 141/140 [==============================] - 2s 17ms/step - loss: 2.0637 - accuracy: 0.1282
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0594 - accuracy: 0.1273
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0561 - accuracy: 0.1220
# Epoch 7/8
# 141/140 [==============================] - 2s 18ms/step - loss: 2.0503 - accuracy: 0.1496
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0478 - accuracy: 0.1884
# Predictions Counter({6: 165, 4: 159, 7: 96, 1: 47, 5: 33})
#
# Confusion matrix
# [[ 0  8  0  0 25  9  3 17]
#  [ 0 12  0  0 20  5 11 14]
#  [ 0  5  0  0 35  6  7 10]
#  [ 0  7  0  0 27  4  6 19]
#  [ 0  7  0  0 19  6 21  9]
#  [ 0  8  0  0 29  3  5 18]
#  [ 0  0  0  0  4  0 50  9]
#  [ 0  0  0  0  0  0 62  0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        62
#       STROMA       0.26      0.19      0.22        62
#      COMPLEX       0.00      0.00      0.00        63
#       LYMPHO       0.00      0.00      0.00        63
#       DEBRIS       0.12      0.31      0.17        62
#       MUCOSA       0.09      0.05      0.06        63
#      ADIPOSE       0.30      0.79      0.44        63
#        EMPTY       0.00      0.00      0.00        62
#
#     accuracy                           0.17       500
#    macro avg       0.10      0.17      0.11       500
# weighted avg       0.10      0.17      0.11       500
#
# AUC 0.6847
# loss: 2.05 acc: 0.17
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0901 - accuracy: 0.1240
# Epoch 2/8
# 141/140 [==============================] - 2s 17ms/step - loss: 2.0844 - accuracy: 0.1258
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0796 - accuracy: 0.1293
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0768 - accuracy: 0.1278
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0730 - accuracy: 0.1322
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0693 - accuracy: 0.1304
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0656 - accuracy: 0.1307
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0633 - accuracy: 0.1942
# Predictions Counter({0: 274, 2: 135, 7: 68, 3: 21, 6: 2})
#
# Confusion matrix
# [[44  0 10  7  0  0  1  0]
#  [31  0 31  0  0  0  0  0]
#  [27  0 33  3  0  0  0  0]
#  [36  0 21  5  0  0  1  0]
#  [36  0 24  2  0  0  0  0]
#  [44  0 16  3  0  0  0  0]
#  [56  0  0  1  0  0  0  6]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.16      0.71      0.26        62
#       STROMA       0.00      0.00      0.00        62
#      COMPLEX       0.24      0.52      0.33        63
#       LYMPHO       0.24      0.08      0.12        63
#       DEBRIS       0.00      0.00      0.00        62
#       MUCOSA       0.00      0.00      0.00        63
#      ADIPOSE       0.00      0.00      0.00        63
#        EMPTY       0.91      1.00      0.95        62
#
#     accuracy                           0.29       500
#    macro avg       0.19      0.29      0.21       500
# weighted avg       0.19      0.29      0.21       500
#
# AUC 0.5922
# loss: 2.06 acc: 0.29
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.1493 - accuracy: 0.1251
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.1362 - accuracy: 0.1251
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.1225 - accuracy: 0.1251
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.1110 - accuracy: 0.1251
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.1040 - accuracy: 0.1251
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0940 - accuracy: 0.1251
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0871 - accuracy: 0.1251
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0818 - accuracy: 0.1251
# Predictions Counter({4: 498, 1: 2})
#
# Confusion matrix
# [[ 0  1  0  0 61  0  0  0]
#  [ 0  0  0  0 62  0  0  0]
#  [ 0  0  0  0 63  0  0  0]
#  [ 0  0  0  0 63  0  0  0]
#  [ 0  0  0  0 62  0  0  0]
#  [ 0  1  0  0 62  0  0  0]
#  [ 0  0  0  0 63  0  0  0]
#  [ 0  0  0  0 62  0  0  0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        62
#       STROMA       0.00      0.00      0.00        62
#      COMPLEX       0.00      0.00      0.00        63
#       LYMPHO       0.00      0.00      0.00        63
#       DEBRIS       0.12      1.00      0.22        62
#       MUCOSA       0.00      0.00      0.00        63
#      ADIPOSE       0.00      0.00      0.00        63
#        EMPTY       0.00      0.00      0.00        62
#
#     accuracy                           0.12       500
#    macro avg       0.02      0.12      0.03       500
# weighted avg       0.02      0.12      0.03       500
#
# AUC 0.6501
# loss: 2.09 acc: 0.12
# Before  4500
# Y TRAIN [4 5 5 ... 0 0 0]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  8
# Epoch 1/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0820 - accuracy: 0.1067
# Epoch 2/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0785 - accuracy: 0.0938
# Epoch 3/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0771 - accuracy: 0.1438
# Epoch 4/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0753 - accuracy: 0.2076
# Epoch 5/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0734 - accuracy: 0.2029
# Epoch 6/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0719 - accuracy: 0.1922
# Epoch 7/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0705 - accuracy: 0.1849
# Epoch 8/8
# 141/140 [==============================] - 2s 16ms/step - loss: 2.0680 - accuracy: 0.1789
# Predictions Counter({7: 311, 5: 124, 4: 50, 6: 12, 3: 3})
#
# Confusion matrix
# [[ 0  0  0  1  4 24  3 30]
#  [ 0  0  0  0  6  7  1 48]
#  [ 0  0  0  0  6 18  1 38]
#  [ 0  0  0  2 19 23  1 18]
#  [ 0  0  0  0  4 23  0 35]
#  [ 0  0  0  0 10 24  6 23]
#  [ 0  0  0  0  1  5  0 57]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        62
#       STROMA       0.00      0.00      0.00        62
#      COMPLEX       0.00      0.00      0.00        63
#       LYMPHO       0.67      0.03      0.06        63
#       DEBRIS       0.08      0.06      0.07        62
#       MUCOSA       0.19      0.38      0.26        63
#      ADIPOSE       0.00      0.00      0.00        63
#        EMPTY       0.20      1.00      0.33        62
#
#     accuracy                           0.18       500
#    macro avg       0.14      0.18      0.09       500
# weighted avg       0.14      0.18      0.09       500
#
# AUC 0.6239
# loss: 2.07 acc: 0.18
# The media value acc is   0.17079999968409537 And the value auc is  0.604888080643813 And the activation optimizer is  adadelta
# AND WITH THE OPTIMIZER adam
# THE BEST MODEL IS  ['relu', 'relu', 'relu', 'relu', 'softmax']
# WITH A EPOCH_NUMBER OF  8  AND A BATCH SIZE OF  32
# BEST MEDIA AUC  0.9433003789983069
# BEST MEDIA ACC  0.5976000010967255
# AND WITH DATA_AUGMENTATION  True
# FIRST MODEL GRAPHIC

# %% [markdown]
# This section is introductory to serve as a simple example. To test the model created in different situations, a 10 cross validation (10-CV) strategy should be used.

# %%
get_best_epoch(True, 'adam')
# Out:
# The new size is  5 ,  32
# Before  4500
# Y TRAIN [7 7 6 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  5
# Epoch 1/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.3653 - accuracy: 0.4124
# Epoch 2/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0509 - accuracy: 0.5580
# Epoch 3/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0163 - accuracy: 0.5798
# Epoch 4/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9369 - accuracy: 0.6147
# Epoch 5/5
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9045 - accuracy: 0.6253
# Predictions Counter({3: 158, 7: 70, 2: 69, 4: 68, 6: 57, 5: 39, 1: 26, 0: 13})
#
# Confusion matrix
# [[12  0  3 47  0  1  0  0]
#  [ 0 15 22  2 24  0  0  0]
#  [ 1  5 30 22  1  3  0  0]
#  [ 0  0  2 60  0  0  0  0]
#  [ 0  6  8  0 40  6  3  0]
#  [ 0  0  4 27  2 29  0  0]
#  [ 0  0  0  0  1  0 53  8]
#  [ 0  0  0  0  0  0  1 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.92      0.19      0.32        63
#       STROMA       0.58      0.24      0.34        63
#      COMPLEX       0.43      0.48      0.46        62
#       LYMPHO       0.38      0.97      0.55        62
#       DEBRIS       0.59      0.63      0.61        63
#       MUCOSA       0.74      0.47      0.57        62
#      ADIPOSE       0.93      0.85      0.89        62
#        EMPTY       0.89      0.98      0.93        63
#
#     accuracy                           0.60       500
#    macro avg       0.68      0.60      0.58       500
# weighted avg       0.68      0.60      0.58       500
#
# AUC 0.9387
# loss: 0.97 acc: 0.60
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  5
# Epoch 1/5
# 141/140 [==============================] - 2s 16ms/step - loss: 1.4479 - accuracy: 0.3711
# Epoch 2/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.1123 - accuracy: 0.5329
# Epoch 3/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0414 - accuracy: 0.5642
# Epoch 4/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0032 - accuracy: 0.5687
# Epoch 5/5
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9892 - accuracy: 0.5678
# Predictions Counter({3: 141, 2: 97, 7: 67, 5: 62, 6: 51, 1: 31, 0: 31, 4: 20})
#
# Confusion matrix
# [[11  0  2 42  0  8  0  0]
#  [ 0 12 43  0  1  7  0  0]
#  [15  0 36 10  0  1  0  0]
#  [ 1  0  0 58  0  3  0  0]
#  [ 0 19 14  0 11 18  1  0]
#  [ 4  0  2 31  0 25  0  0]
#  [ 0  0  0  0  7  0 50  5]
#  [ 0  0  0  0  1  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.35      0.17      0.23        63
#       STROMA       0.39      0.19      0.26        63
#      COMPLEX       0.37      0.58      0.45        62
#       LYMPHO       0.41      0.94      0.57        62
#       DEBRIS       0.55      0.17      0.27        63
#       MUCOSA       0.40      0.40      0.40        62
#      ADIPOSE       0.98      0.81      0.88        62
#        EMPTY       0.93      0.98      0.95        63
#
#     accuracy                           0.53       500
#    macro avg       0.55      0.53      0.50       500
# weighted avg       0.55      0.53      0.50       500
#
# AUC 0.9029
# loss: 1.26 acc: 0.53
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  5
# Epoch 1/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.3834 - accuracy: 0.4162
# Epoch 2/5
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0465 - accuracy: 0.5571
# Epoch 3/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9774 - accuracy: 0.5862
# Epoch 4/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9998 - accuracy: 0.5778
# Epoch 5/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9208 - accuracy: 0.6153
# Predictions Counter({0: 110, 7: 78, 2: 69, 3: 63, 4: 59, 1: 52, 6: 46, 5: 23})
#
# Confusion matrix
# [[47  0  0 15  0  1  0  0]
#  [ 1 30 17  0 14  0  1  0]
#  [18  3 40  0  1  0  0  0]
#  [12  0  3 47  0  0  0  0]
#  [ 1 18  3  0 39  1  1  0]
#  [31  1  6  1  2 21  0  0]
#  [ 0  0  0  0  3  0 42 17]
#  [ 0  0  0  0  0  0  2 61]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.43      0.75      0.54        63
#       STROMA       0.58      0.48      0.52        63
#      COMPLEX       0.58      0.65      0.61        62
#       LYMPHO       0.75      0.76      0.75        62
#       DEBRIS       0.66      0.62      0.64        63
#       MUCOSA       0.91      0.34      0.49        62
#      ADIPOSE       0.91      0.68      0.78        62
#        EMPTY       0.78      0.97      0.87        63
#
#     accuracy                           0.65       500
#    macro avg       0.70      0.65      0.65       500
# weighted avg       0.70      0.65      0.65       500
#
# AUC 0.9445
# loss: 0.87 acc: 0.65
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  5
# Epoch 1/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.4121 - accuracy: 0.4049
# Epoch 2/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0872 - accuracy: 0.5304
# Epoch 3/5
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9977 - accuracy: 0.5778
# Epoch 4/5
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9227 - accuracy: 0.6142
# Epoch 5/5
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8900 - accuracy: 0.6280
# Predictions Counter({3: 186, 6: 108, 2: 102, 5: 35, 1: 31, 4: 27, 7: 10, 0: 1})
#
# Confusion matrix
# [[ 1  0  1 57  0  4  0  0]
#  [ 0 14 41  0  3  5  0  0]
#  [ 0  1 38 23  0  0  0  0]
#  [ 0  0  0 62  0  0  0  0]
#  [ 0 16 19  1 15 11  1  0]
#  [ 0  0  3 43  1 15  0  0]
#  [ 0  0  0  0  8  0 54  0]
#  [ 0  0  0  0  0  0 53 10]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       1.00      0.02      0.03        63
#       STROMA       0.45      0.22      0.30        63
#      COMPLEX       0.37      0.61      0.46        62
#       LYMPHO       0.33      1.00      0.50        62
#       DEBRIS       0.56      0.24      0.33        63
#       MUCOSA       0.43      0.24      0.31        62
#      ADIPOSE       0.50      0.87      0.64        62
#        EMPTY       1.00      0.16      0.27        63
#
#     accuracy                           0.42       500
#    macro avg       0.58      0.42      0.36       500
# weighted avg       0.58      0.42      0.35       500
#
# AUC 0.9197
# loss: 1.30 acc: 0.42
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  5
# Epoch 1/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.4032 - accuracy: 0.3882
# Epoch 2/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0391 - accuracy: 0.5373
# Epoch 3/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9767 - accuracy: 0.5718
# Epoch 4/5
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9268 - accuracy: 0.6058
# Epoch 5/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9214 - accuracy: 0.6204
# Predictions Counter({3: 144, 5: 91, 7: 79, 4: 52, 6: 48, 1: 47, 2: 33, 0: 6})
#
# Confusion matrix
# [[ 4  0  0 48  0 11  0  0]
#  [ 0 29 11  0 12 11  0  0]
#  [ 1  0 20 10  2 29  0  0]
#  [ 1  0  0 57  0  4  0  0]
#  [ 0 18  2  1 37  3  2  0]
#  [ 0  0  0 28  1 33  0  0]
#  [ 0  0  0  0  0  0 46 16]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.67      0.06      0.12        63
#       STROMA       0.62      0.46      0.53        63
#      COMPLEX       0.61      0.32      0.42        62
#       LYMPHO       0.40      0.92      0.55        62
#       DEBRIS       0.71      0.59      0.64        63
#       MUCOSA       0.36      0.53      0.43        62
#      ADIPOSE       0.96      0.74      0.84        62
#        EMPTY       0.80      1.00      0.89        63
#
#     accuracy                           0.58       500
#    macro avg       0.64      0.58      0.55       500
# weighted avg       0.64      0.58      0.55       500
#
# AUC 0.9275
# loss: 1.14 acc: 0.58
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  5
# Epoch 1/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.5373 - accuracy: 0.3409
# Epoch 2/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.1124 - accuracy: 0.5142
# Epoch 3/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0278 - accuracy: 0.5600
# Epoch 4/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9789 - accuracy: 0.5853
# Epoch 5/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9352 - accuracy: 0.6156
# Predictions Counter({5: 120, 0: 79, 2: 68, 7: 61, 6: 59, 4: 40, 1: 40, 3: 33})
#
# Confusion matrix
# [[46  0  5  1  0 10  0  0]
#  [ 0 23 23  0  8  8  0  0]
#  [ 9  0 31  0  1 22  0  0]
#  [19  0  1 32  0 11  0  0]
#  [ 0 17  7  0 25 13  0  0]
#  [ 5  0  1  0  1 56  0  0]
#  [ 0  0  0  0  5  0 55  3]
#  [ 0  0  0  0  0  0  4 58]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.58      0.74      0.65        62
#       STROMA       0.57      0.37      0.45        62
#      COMPLEX       0.46      0.49      0.47        63
#       LYMPHO       0.97      0.51      0.67        63
#       DEBRIS       0.62      0.40      0.49        62
#       MUCOSA       0.47      0.89      0.61        63
#      ADIPOSE       0.93      0.87      0.90        63
#        EMPTY       0.95      0.94      0.94        62
#
#     accuracy                           0.65       500
#    macro avg       0.69      0.65      0.65       500
# weighted avg       0.69      0.65      0.65       500
#
# AUC 0.9395
# loss: 0.91 acc: 0.65
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  5
# Epoch 1/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.3554 - accuracy: 0.4427
# Epoch 2/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0434 - accuracy: 0.5444
# Epoch 3/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9842 - accuracy: 0.5662
# Epoch 4/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9713 - accuracy: 0.5780
# Epoch 5/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9395 - accuracy: 0.5947
# Predictions Counter({3: 176, 6: 71, 1: 69, 2: 65, 5: 49, 7: 38, 4: 29, 0: 3})
#
# Confusion matrix
# [[ 1  0  0 58  0  3  0  0]
#  [ 0 35 21  0  2  4  0  0]
#  [ 1  1 39 21  0  1  0  0]
#  [ 1  0  1 60  0  1  0  0]
#  [ 0 32  3  0 10 16  1  0]
#  [ 0  1  1 37  0 24  0  0]
#  [ 0  0  0  0 17  0 44  2]
#  [ 0  0  0  0  0  0 26 36]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.33      0.02      0.03        62
#       STROMA       0.51      0.56      0.53        62
#      COMPLEX       0.60      0.62      0.61        63
#       LYMPHO       0.34      0.95      0.50        63
#       DEBRIS       0.34      0.16      0.22        62
#       MUCOSA       0.49      0.38      0.43        63
#      ADIPOSE       0.62      0.70      0.66        63
#        EMPTY       0.95      0.58      0.72        62
#
#     accuracy                           0.50       500
#    macro avg       0.52      0.50      0.46       500
# weighted avg       0.52      0.50      0.46       500
#
# AUC 0.9229
# loss: 1.16 acc: 0.50
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  5
# Epoch 1/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.3429 - accuracy: 0.4200
# Epoch 2/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0056 - accuracy: 0.5618
# Epoch 3/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9303 - accuracy: 0.6202
# Epoch 4/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8961 - accuracy: 0.6224
# Epoch 5/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8199 - accuracy: 0.6647
# Predictions Counter({3: 124, 1: 77, 5: 73, 6: 66, 7: 58, 4: 55, 2: 40, 0: 7})
#
# Confusion matrix
# [[ 6  0  4 34  1 17  0  0]
#  [ 0 45  6  0  8  3  0  0]
#  [ 1 12 28  9  4  9  0  0]
#  [ 0  0  0 62  0  1  0  0]
#  [ 0 19  1  0 37  4  1  0]
#  [ 0  1  1 19  3 39  0  0]
#  [ 0  0  0  0  2  0 59  2]
#  [ 0  0  0  0  0  0  6 56]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.86      0.10      0.17        62
#       STROMA       0.58      0.73      0.65        62
#      COMPLEX       0.70      0.44      0.54        63
#       LYMPHO       0.50      0.98      0.66        63
#       DEBRIS       0.67      0.60      0.63        62
#       MUCOSA       0.53      0.62      0.57        63
#      ADIPOSE       0.89      0.94      0.91        63
#        EMPTY       0.97      0.90      0.93        62
#
#     accuracy                           0.66       500
#    macro avg       0.71      0.66      0.64       500
# weighted avg       0.71      0.66      0.64       500
#
# AUC 0.9515
# loss: 0.97 acc: 0.66
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  5
# Epoch 1/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.3789 - accuracy: 0.4180
# Epoch 2/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0609 - accuracy: 0.5356
# Epoch 3/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9773 - accuracy: 0.5771
# Epoch 4/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9495 - accuracy: 0.6002
# Epoch 5/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9169 - accuracy: 0.6153
# Predictions Counter({3: 144, 5: 130, 7: 70, 6: 59, 1: 39, 2: 28, 4: 20, 0: 10})
#
# Confusion matrix
# [[ 7  0  0 48  0  7  0  0]
#  [ 0 20 10  0  7 25  0  0]
#  [ 0  1 18  8  0 36  0  0]
#  [ 0  0  0 59  0  4  0  0]
#  [ 0 18  0  0 13 27  3  1]
#  [ 3  0  0 29  0 31  0  0]
#  [ 0  0  0  0  0  0 56  7]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.70      0.11      0.19        62
#       STROMA       0.51      0.32      0.40        62
#      COMPLEX       0.64      0.29      0.40        63
#       LYMPHO       0.41      0.94      0.57        63
#       DEBRIS       0.65      0.21      0.32        62
#       MUCOSA       0.24      0.49      0.32        63
#      ADIPOSE       0.95      0.89      0.92        63
#        EMPTY       0.89      1.00      0.94        62
#
#     accuracy                           0.53       500
#    macro avg       0.62      0.53      0.51       500
# weighted avg       0.62      0.53      0.51       500
#
# AUC 0.9214
# loss: 1.20 acc: 0.53
# Before  4500
# Y TRAIN [4 5 5 ... 0 0 0]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  5
# Epoch 1/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.3687 - accuracy: 0.3958
# Epoch 2/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0278 - accuracy: 0.5358
# Epoch 3/5
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0140 - accuracy: 0.5560
# Epoch 4/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9522 - accuracy: 0.5969
# Epoch 5/5
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9344 - accuracy: 0.5996
# Predictions Counter({3: 130, 7: 90, 2: 87, 4: 67, 1: 50, 5: 41, 6: 35})
#
# Confusion matrix
# [[ 0  1  8 48  0  5  0  0]
#  [ 0 29 15  0 17  1  0  0]
#  [ 0  2 48  3  7  3  0  0]
#  [ 0  0  2 61  0  0  0  0]
#  [ 0 17  3  0 40  2  0  0]
#  [ 0  1 11 18  3 30  0  0]
#  [ 0  0  0  0  0  0 35 28]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        62
#       STROMA       0.58      0.47      0.52        62
#      COMPLEX       0.55      0.76      0.64        63
#       LYMPHO       0.47      0.97      0.63        63
#       DEBRIS       0.60      0.65      0.62        62
#       MUCOSA       0.73      0.48      0.58        63
#      ADIPOSE       1.00      0.56      0.71        63
#        EMPTY       0.69      1.00      0.82        62
#
#     accuracy                           0.61       500
#    macro avg       0.58      0.61      0.56       500
# weighted avg       0.58      0.61      0.57       500
#
# AUC 0.9563
# loss: 0.88 acc: 0.61
# The media value acc is   0.5737999975681305 And the value auc is  0.932491239227405 And the activation epoch is  5
# The new size is  6 ,  32
# Before  4500
# Y TRAIN [7 7 6 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  6
# Epoch 1/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.3612 - accuracy: 0.4240
# Epoch 2/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0265 - accuracy: 0.5542
# Epoch 3/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9337 - accuracy: 0.5978
# Epoch 4/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9041 - accuracy: 0.6213
# Epoch 5/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8805 - accuracy: 0.6369
# Epoch 6/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8588 - accuracy: 0.6496
# Predictions Counter({3: 91, 7: 85, 2: 75, 0: 66, 1: 64, 4: 53, 6: 42, 5: 24})
#
# Confusion matrix
# [[44  0  2 13  0  4  0  0]
#  [ 0 36 12  0 15  0  0  0]
#  [ 3  8 43  7  0  1  0  0]
#  [ 7  0  2 53  0  0  0  0]
#  [ 0 18  5  0 34  3  3  0]
#  [12  2 11 18  3 16  0  0]
#  [ 0  0  0  0  1  0 39 22]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.67      0.70      0.68        63
#       STROMA       0.56      0.57      0.57        63
#      COMPLEX       0.57      0.69      0.63        62
#       LYMPHO       0.58      0.85      0.69        62
#       DEBRIS       0.64      0.54      0.59        63
#       MUCOSA       0.67      0.26      0.37        62
#      ADIPOSE       0.93      0.63      0.75        62
#        EMPTY       0.74      1.00      0.85        63
#
#     accuracy                           0.66       500
#    macro avg       0.67      0.66      0.64       500
# weighted avg       0.67      0.66      0.64       500
#
# AUC 0.9508
# loss: 0.87 acc: 0.66
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  6
# Epoch 1/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.3688 - accuracy: 0.4127
# Epoch 2/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0469 - accuracy: 0.5536
# Epoch 3/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0038 - accuracy: 0.5744
# Epoch 4/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9170 - accuracy: 0.6231
# Epoch 5/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9325 - accuracy: 0.6091
# Epoch 6/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9258 - accuracy: 0.6187
# Predictions Counter({5: 131, 6: 125, 3: 94, 1: 57, 4: 42, 2: 35, 0: 16})
#
# Confusion matrix
# [[12  1  1 32  0 17  0  0]
#  [ 0 33 10  0  9 11  0  0]
#  [ 2  2 24  1  1 32  0  0]
#  [ 1  0  0 50  0 11  0  0]
#  [ 0 21  0  0 31 10  1  0]
#  [ 1  0  0 11  0 50  0  0]
#  [ 0  0  0  0  1  0 61  0]
#  [ 0  0  0  0  0  0 63  0]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.75      0.19      0.30        63
#       STROMA       0.58      0.52      0.55        63
#      COMPLEX       0.69      0.39      0.49        62
#       LYMPHO       0.53      0.81      0.64        62
#       DEBRIS       0.74      0.49      0.59        63
#       MUCOSA       0.38      0.81      0.52        62
#      ADIPOSE       0.49      0.98      0.65        62
#        EMPTY       0.00      0.00      0.00        63
#
#     accuracy                           0.52       500
#    macro avg       0.52      0.52      0.47       500
# weighted avg       0.52      0.52      0.47       500
#
# AUC 0.9456
# loss: 1.00 acc: 0.52
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  6
# Epoch 1/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.3250 - accuracy: 0.4456
# Epoch 2/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0857 - accuracy: 0.5327
# Epoch 3/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0145 - accuracy: 0.5589
# Epoch 4/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9625 - accuracy: 0.5749
# Epoch 5/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9153 - accuracy: 0.6247
# Epoch 6/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8787 - accuracy: 0.6304
# Predictions Counter({3: 133, 7: 107, 5: 57, 4: 53, 1: 49, 2: 41, 6: 30, 0: 30})
#
# Confusion matrix
# [[18  0  0 40  0  4  1  0]
#  [ 0 31 10  0 13  7  2  0]
#  [ 9  4 29  9  2  9  0  0]
#  [ 2  0  0 57  0  3  0  0]
#  [ 0 14  2  1 35  1 10  0]
#  [ 1  0  0 26  2 33  0  0]
#  [ 0  0  0  0  1  0 16 45]
#  [ 0  0  0  0  0  0  1 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.60      0.29      0.39        63
#       STROMA       0.63      0.49      0.55        63
#      COMPLEX       0.71      0.47      0.56        62
#       LYMPHO       0.43      0.92      0.58        62
#       DEBRIS       0.66      0.56      0.60        63
#       MUCOSA       0.58      0.53      0.55        62
#      ADIPOSE       0.53      0.26      0.35        62
#        EMPTY       0.58      0.98      0.73        63
#
#     accuracy                           0.56       500
#    macro avg       0.59      0.56      0.54       500
# weighted avg       0.59      0.56      0.54       500
#
# AUC 0.9277
# loss: 1.18 acc: 0.56
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  6
# Epoch 1/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.4503 - accuracy: 0.3724
# Epoch 2/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0882 - accuracy: 0.5189
# Epoch 3/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0249 - accuracy: 0.5567
# Epoch 4/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9592 - accuracy: 0.6111
# Epoch 5/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9402 - accuracy: 0.6100
# Epoch 6/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9097 - accuracy: 0.6351
# Predictions Counter({3: 126, 7: 93, 4: 68, 1: 62, 5: 56, 6: 41, 2: 37, 0: 17})
#
# Confusion matrix
# [[13  0  3 45  0  2  0  0]
#  [ 0 31  5  0 24  3  0  0]
#  [ 1 14 26  8  5  8  0  0]
#  [ 1  0  2 54  0  5  0  0]
#  [ 0 15  0  0 38  2  8  0]
#  [ 2  2  1 19  1 36  1  0]
#  [ 0  0  0  0  0  0 32 30]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.76      0.21      0.32        63
#       STROMA       0.50      0.49      0.50        63
#      COMPLEX       0.70      0.42      0.53        62
#       LYMPHO       0.43      0.87      0.57        62
#       DEBRIS       0.56      0.60      0.58        63
#       MUCOSA       0.64      0.58      0.61        62
#      ADIPOSE       0.78      0.52      0.62        62
#        EMPTY       0.68      1.00      0.81        63
#
#     accuracy                           0.59       500
#    macro avg       0.63      0.59      0.57       500
# weighted avg       0.63      0.59      0.57       500
#
# AUC 0.9339
# loss: 1.04 acc: 0.59
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  6
# Epoch 1/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.3570 - accuracy: 0.4244
# Epoch 2/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0779 - accuracy: 0.5327
# Epoch 3/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0077 - accuracy: 0.5718
# Epoch 4/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9853 - accuracy: 0.5820
# Epoch 5/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9066 - accuracy: 0.6258
# Epoch 6/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9080 - accuracy: 0.6089
# Predictions Counter({3: 214, 7: 76, 5: 64, 2: 62, 6: 45, 4: 24, 1: 15})
#
# Confusion matrix
# [[ 0  0  0 60  0  3  0  0]
#  [ 0  6 34  2  7 14  0  0]
#  [ 0  0 16 41  0  5  0  0]
#  [ 0  0  0 60  0  2  0  0]
#  [ 0  9 11  2 11 28  2  0]
#  [ 0  0  1 49  0 12  0  0]
#  [ 0  0  0  0  6  0 43 13]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.00      0.00      0.00        63
#       STROMA       0.40      0.10      0.15        63
#      COMPLEX       0.26      0.26      0.26        62
#       LYMPHO       0.28      0.97      0.43        62
#       DEBRIS       0.46      0.17      0.25        63
#       MUCOSA       0.19      0.19      0.19        62
#      ADIPOSE       0.96      0.69      0.80        62
#        EMPTY       0.83      1.00      0.91        63
#
#     accuracy                           0.42       500
#    macro avg       0.42      0.42      0.38       500
# weighted avg       0.42      0.42      0.37       500
#
# AUC 0.8704
# loss: 1.82 acc: 0.42
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  6
# Epoch 1/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.5406 - accuracy: 0.3402
# Epoch 2/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0862 - accuracy: 0.5062
# Epoch 3/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9800 - accuracy: 0.5764
# Epoch 4/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9327 - accuracy: 0.6044
# Epoch 5/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9248 - accuracy: 0.5984
# Epoch 6/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8798 - accuracy: 0.6278
# Predictions Counter({3: 95, 5: 91, 6: 63, 2: 59, 7: 58, 4: 54, 1: 49, 0: 31})
#
# Confusion matrix
# [[20  0  5 33  0  4  0  0]
#  [ 0 28 15  0 13  6  0  0]
#  [ 5  4 32  3  0 19  0  0]
#  [ 4  0  1 48  0 10  0  0]
#  [ 0 17  4  0 35  6  0  0]
#  [ 2  0  2 11  2 46  0  0]
#  [ 0  0  0  0  4  0 57  2]
#  [ 0  0  0  0  0  0  6 56]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.65      0.32      0.43        62
#       STROMA       0.57      0.45      0.50        62
#      COMPLEX       0.54      0.51      0.52        63
#       LYMPHO       0.51      0.76      0.61        63
#       DEBRIS       0.65      0.56      0.60        62
#       MUCOSA       0.51      0.73      0.60        63
#      ADIPOSE       0.90      0.90      0.90        63
#        EMPTY       0.97      0.90      0.93        62
#
#     accuracy                           0.64       500
#    macro avg       0.66      0.64      0.64       500
# weighted avg       0.66      0.64      0.64       500
#
# AUC 0.9468
# loss: 0.87 acc: 0.64
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  6
# Epoch 1/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.5056 - accuracy: 0.3567
# Epoch 2/6
# 141/140 [==============================] - 2s 18ms/step - loss: 1.0992 - accuracy: 0.5176
# Epoch 3/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0322 - accuracy: 0.5491
# Epoch 4/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9932 - accuracy: 0.5720
# Epoch 5/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9791 - accuracy: 0.5802
# Epoch 6/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8845 - accuracy: 0.6376
# Predictions Counter({3: 111, 1: 79, 7: 76, 5: 72, 2: 68, 6: 40, 4: 34, 0: 20})
#
# Confusion matrix
# [[15  0  0 39  0  8  0  0]
#  [ 0 41 14  0  5  2  0  0]
#  [ 3  2 46  3  0  9  0  0]
#  [ 2  0  2 53  0  6  0  0]
#  [ 0 34  3  0 19  5  1  0]
#  [ 0  2  3 16  0 42  0  0]
#  [ 0  0  0  0 10  0 39 14]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.75      0.24      0.37        62
#       STROMA       0.52      0.66      0.58        62
#      COMPLEX       0.68      0.73      0.70        63
#       LYMPHO       0.48      0.84      0.61        63
#       DEBRIS       0.56      0.31      0.40        62
#       MUCOSA       0.58      0.67      0.62        63
#      ADIPOSE       0.97      0.62      0.76        63
#        EMPTY       0.82      1.00      0.90        62
#
#     accuracy                           0.63       500
#    macro avg       0.67      0.63      0.62       500
# weighted avg       0.67      0.63      0.62       500
#
# AUC 0.9479
# loss: 0.88 acc: 0.63
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  6
# Epoch 1/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.4321 - accuracy: 0.3967
# Epoch 2/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0619 - accuracy: 0.5447
# Epoch 3/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9999 - accuracy: 0.5780
# Epoch 4/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9457 - accuracy: 0.6062
# Epoch 5/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9193 - accuracy: 0.6238
# Epoch 6/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9081 - accuracy: 0.6269
# Predictions Counter({2: 125, 3: 124, 7: 67, 6: 48, 5: 46, 0: 41, 1: 27, 4: 22})
#
# Confusion matrix
# [[28  0  1 29  0  4  0  0]
#  [ 0  7 55  0  0  0  0  0]
#  [ 5  2 42 12  0  2  0  0]
#  [ 3  0  0 59  0  1  0  0]
#  [ 0 18 20  0 10 13  1  0]
#  [ 5  0  7 24  1 26  0  0]
#  [ 0  0  0  0 11  0 47  5]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.68      0.45      0.54        62
#       STROMA       0.26      0.11      0.16        62
#      COMPLEX       0.34      0.67      0.45        63
#       LYMPHO       0.48      0.94      0.63        63
#       DEBRIS       0.45      0.16      0.24        62
#       MUCOSA       0.57      0.41      0.48        63
#      ADIPOSE       0.98      0.75      0.85        63
#        EMPTY       0.93      1.00      0.96        62
#
#     accuracy                           0.56       500
#    macro avg       0.58      0.56      0.54       500
# weighted avg       0.58      0.56      0.54       500
#
# AUC 0.9256
# loss: 1.16 acc: 0.56
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  6
# Epoch 1/6
# 141/140 [==============================] - 2s 18ms/step - loss: 1.4765 - accuracy: 0.3876
# Epoch 2/6
# 141/140 [==============================] - 2s 18ms/step - loss: 1.0547 - accuracy: 0.5511
# Epoch 3/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0096 - accuracy: 0.5651
# Epoch 4/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9220 - accuracy: 0.6087
# Epoch 5/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9218 - accuracy: 0.6080
# Epoch 6/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9050 - accuracy: 0.6198
# Predictions Counter({3: 108, 6: 102, 1: 75, 5: 62, 0: 47, 2: 45, 4: 38, 7: 23})
#
# Confusion matrix
# [[15  1  1 40  0  5  0  0]
#  [ 0 39 10  0  8  5  0  0]
#  [13  8 30  4  1  7  0  0]
#  [10  0  0 50  0  3  0  0]
#  [ 0 27  4  0 23  5  3  0]
#  [ 9  0  0 14  3 37  0  0]
#  [ 0  0  0  0  3  0 60  0]
#  [ 0  0  0  0  0  0 39 23]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.32      0.24      0.28        62
#       STROMA       0.52      0.63      0.57        62
#      COMPLEX       0.67      0.48      0.56        63
#       LYMPHO       0.46      0.79      0.58        63
#       DEBRIS       0.61      0.37      0.46        62
#       MUCOSA       0.60      0.59      0.59        63
#      ADIPOSE       0.59      0.95      0.73        63
#        EMPTY       1.00      0.37      0.54        62
#
#     accuracy                           0.55       500
#    macro avg       0.59      0.55      0.54       500
# weighted avg       0.59      0.55      0.54       500
#
# AUC 0.9332
# loss: 1.00 acc: 0.55
# Before  4500
# Y TRAIN [4 5 5 ... 0 0 0]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  6
# Epoch 1/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.4530 - accuracy: 0.3782
# Epoch 2/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0473 - accuracy: 0.5511
# Epoch 3/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0329 - accuracy: 0.5511
# Epoch 4/6
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0017 - accuracy: 0.5698
# Epoch 5/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9587 - accuracy: 0.5949
# Epoch 6/6
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9285 - accuracy: 0.5996
# Predictions Counter({3: 127, 1: 85, 2: 74, 7: 64, 6: 58, 5: 46, 4: 38, 0: 8})
#
# Confusion matrix
# [[ 7  1  7 44  0  3  0  0]
#  [ 0 38 12  0  8  4  0  0]
#  [ 0  9 44  5  2  3  0  0]
#  [ 0  0  1 61  0  1  0  0]
#  [ 0 34  2  0 23  3  0  0]
#  [ 1  3  8 17  2 32  0  0]
#  [ 0  0  0  0  3  0 58  2]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.88      0.11      0.20        62
#       STROMA       0.45      0.61      0.52        62
#      COMPLEX       0.59      0.70      0.64        63
#       LYMPHO       0.48      0.97      0.64        63
#       DEBRIS       0.61      0.37      0.46        62
#       MUCOSA       0.70      0.51      0.59        63
#      ADIPOSE       1.00      0.92      0.96        63
#        EMPTY       0.97      1.00      0.98        62
#
#     accuracy                           0.65       500
#    macro avg       0.71      0.65      0.62       500
# weighted avg       0.71      0.65      0.62       500
#
# AUC 0.9512
# loss: 0.83 acc: 0.65
# The media value acc is   0.5791999995708466 And the value auc is  0.93330713029588 And the activation epoch is  6
# VALUES ACC  25.0 0.7988593499960496
# VALUES AUC  25.0 0.7988593499960496
# The new size is  7 ,  32
# Before  4500
# Y TRAIN [7 7 6 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  7
# Epoch 1/7
# 141/140 [==============================] - 2s 17ms/step - loss: 1.4809 - accuracy: 0.3873
# Epoch 2/7
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0404 - accuracy: 0.5422
# Epoch 3/7
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9838 - accuracy: 0.5771
# Epoch 4/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.9367 - accuracy: 0.6044
# Epoch 5/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.8890 - accuracy: 0.6420
# Epoch 6/7
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8804 - accuracy: 0.6393
# Epoch 7/7
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8608 - accuracy: 0.6636
# Predictions Counter({3: 125, 7: 87, 4: 78, 2: 65, 1: 44, 6: 40, 5: 39, 0: 22})
#
# Confusion matrix
# [[18  0  5 37  0  3  0  0]
#  [ 0 29 10  0 24  0  0  0]
#  [ 1  6 41 10  3  1  0  0]
#  [ 3  0  4 55  0  0  0  0]
#  [ 0  7  2  0 47  4  3  0]
#  [ 0  2  3 23  3 31  0  0]
#  [ 0  0  0  0  1  0 37 24]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.82      0.29      0.42        63
#       STROMA       0.66      0.46      0.54        63
#      COMPLEX       0.63      0.66      0.65        62
#       LYMPHO       0.44      0.89      0.59        62
#       DEBRIS       0.60      0.75      0.67        63
#       MUCOSA       0.79      0.50      0.61        62
#      ADIPOSE       0.93      0.60      0.73        62
#        EMPTY       0.72      1.00      0.84        63
#
#     accuracy                           0.64       500
#    macro avg       0.70      0.64      0.63       500
# weighted avg       0.70      0.64      0.63       500
#
# AUC 0.9473
# loss: 0.91 acc: 0.64
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  7
# Epoch 1/7
# 141/140 [==============================] - 2s 17ms/step - loss: 1.4618 - accuracy: 0.3569
# Epoch 2/7
# 141/140 [==============================] - 2s 18ms/step - loss: 1.0659 - accuracy: 0.5189
# Epoch 3/7
# 141/140 [==============================] - 3s 18ms/step - loss: 1.0135 - accuracy: 0.5356
# Epoch 4/7
# 141/140 [==============================] - 3s 18ms/step - loss: 1.0035 - accuracy: 0.5493
# Epoch 5/7
# 141/140 [==============================] - 3s 18ms/step - loss: 0.9602 - accuracy: 0.5704
# Epoch 6/7
# 141/140 [==============================] - 3s 18ms/step - loss: 0.9306 - accuracy: 0.5858
# Epoch 7/7
# 141/140 [==============================] - 3s 18ms/step - loss: 0.9696 - accuracy: 0.5644
# Predictions Counter({3: 127, 2: 110, 7: 81, 5: 57, 1: 43, 6: 39, 4: 26, 0: 17})
#
# Confusion matrix
# [[14  0  2 39  0  8  0  0]
#  [ 0 18 41  0  1  3  0  0]
#  [ 0  0 52  8  0  2  0  0]
#  [ 0  0  2 58  0  2  0  0]
#  [ 0 25  7  0 19 11  1  0]
#  [ 3  0  6 22  0 31  0  0]
#  [ 0  0  0  0  5  0 38 19]
#  [ 0  0  0  0  1  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.82      0.22      0.35        63
#       STROMA       0.42      0.29      0.34        63
#      COMPLEX       0.47      0.84      0.60        62
#       LYMPHO       0.46      0.94      0.61        62
#       DEBRIS       0.73      0.30      0.43        63
#       MUCOSA       0.54      0.50      0.52        62
#      ADIPOSE       0.97      0.61      0.75        62
#        EMPTY       0.77      0.98      0.86        63
#
#     accuracy                           0.58       500
#    macro avg       0.65      0.59      0.56       500
# weighted avg       0.65      0.58      0.56       500
#
# AUC 0.9466
# loss: 0.95 acc: 0.58
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  7
# Epoch 1/7
# 141/140 [==============================] - 3s 18ms/step - loss: 1.4803 - accuracy: 0.3778
# Epoch 2/7
# 141/140 [==============================] - 2s 17ms/step - loss: 1.0886 - accuracy: 0.5178
# Epoch 3/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.9840 - accuracy: 0.5796
# Epoch 4/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.9770 - accuracy: 0.5811
# Epoch 5/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.9240 - accuracy: 0.6269
# Epoch 6/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.8772 - accuracy: 0.6391
# Epoch 7/7
# 141/140 [==============================] - 2s 17ms/step - loss: 0.8667 - accuracy: 0.6527
# Predictions Counter({3: 128, 2: 77, 6: 65, 7: 61, 5: 56, 4: 53, 1: 38, 0: 22})
#
# Confusion matrix
# [[15  0  0 38  0 10  0  0]
#  [ 0 26 25  0  9  2  1  0]
#  [ 3  2 42  8  1  6  0  0]
#  [ 1  0  1 57  0  3  0  0]
#  [ 0 10  6  1 40  4  2  0]
#  [ 3  0  3 24  1 31  0  0]
#  [ 0  0  0  0  2  0 58  2]
#  [ 0  0  0  0  0  0  4 59]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.68      0.24      0.35        63
#       STROMA       0.68      0.41      0.51        63
#      COMPLEX       0.55      0.68      0.60        62
#       LYMPHO       0.45      0.92      0.60        62
#       DEBRIS       0.75      0.63      0.69        63
#       MUCOSA       0.55      0.50      0.53        62
#      ADIPOSE       0.89      0.94      0.91        62
#        EMPTY       0.97      0.94      0.95        63
#
#     accuracy                           0.66       500
#    macro avg       0.69      0.66      0.64       500
# weighted avg       0.69      0.66      0.64       500
#
# AUC 0.9398
# loss: 1.01 acc: 0.66
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  7
# Epoch 1/7
# 141/140 [==============================] - 3s 18ms/step - loss: 1.3631 - accuracy: 0.4373
# Epoch 2/7
# 141/140 [==============================] - 2s 18ms/step - loss: 1.0317 - accuracy: 0.5598
# Epoch 3/7
# 141/140 [==============================] - 3s 18ms/step - loss: 0.9730 - accuracy: 0.5884
# Epoch 4/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.9186 - accuracy: 0.6227
# Epoch 5/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.8768 - accuracy: 0.6402
# Epoch 6/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.8106 - accuracy: 0.6740
# Epoch 7/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.8429 - accuracy: 0.6536
# Predictions Counter({3: 124, 4: 106, 7: 81, 5: 48, 6: 46, 0: 38, 2: 37, 1: 20})
#
# Confusion matrix
# [[33  0  1 27  0  2  0  0]
#  [ 0 15  6  0 38  4  0  0]
#  [ 2  4 29 18  9  0  0  0]
#  [ 0  0  0 60  0  2  0  0]
#  [ 0  0  1  1 55  3  3  0]
#  [ 3  1  0 18  3 37  0  0]
#  [ 0  0  0  0  1  0 43 18]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.87      0.52      0.65        63
#       STROMA       0.75      0.24      0.36        63
#      COMPLEX       0.78      0.47      0.59        62
#       LYMPHO       0.48      0.97      0.65        62
#       DEBRIS       0.52      0.87      0.65        63
#       MUCOSA       0.77      0.60      0.67        62
#      ADIPOSE       0.93      0.69      0.80        62
#        EMPTY       0.78      1.00      0.88        63
#
#     accuracy                           0.67       500
#    macro avg       0.74      0.67      0.66       500
# weighted avg       0.74      0.67      0.65       500
#
# AUC 0.9591
# loss: 0.83 acc: 0.67
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  7
# Epoch 1/7
# 141/140 [==============================] - 2s 17ms/step - loss: 1.4451 - accuracy: 0.3840
# Epoch 2/7
# 141/140 [==============================] - 3s 18ms/step - loss: 1.0605 - accuracy: 0.5416
# Epoch 3/7
# 141/140 [==============================] - 2s 18ms/step - loss: 1.0680 - accuracy: 0.5320
# Epoch 4/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.9888 - accuracy: 0.5571
# Epoch 5/7
# 141/140 [==============================] - 3s 18ms/step - loss: 0.9495 - accuracy: 0.5900
# Epoch 6/7
# 141/140 [==============================] - 2s 17ms/step - loss: 0.9319 - accuracy: 0.6024
# Epoch 7/7
# 141/140 [==============================] - 3s 18ms/step - loss: 0.9407 - accuracy: 0.5884
# Predictions Counter({7: 87, 4: 86, 3: 82, 2: 82, 0: 52, 6: 41, 1: 41, 5: 29})
#
# Confusion matrix
# [[32  1  9 20  0  1  0  0]
#  [ 0 27  8  0 28  0  0  0]
#  [ 3  3 49  3  3  1  0  0]
#  [ 5  0  5 50  0  2  0  0]
#  [ 0  7  2  0 51  0  3  0]
#  [12  3  9  9  4 25  0  0]
#  [ 0  0  0  0  0  0 38 24]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.62      0.51      0.56        63
#       STROMA       0.66      0.43      0.52        63
#      COMPLEX       0.60      0.79      0.68        62
#       LYMPHO       0.61      0.81      0.69        62
#       DEBRIS       0.59      0.81      0.68        63
#       MUCOSA       0.86      0.40      0.55        62
#      ADIPOSE       0.93      0.61      0.74        62
#        EMPTY       0.72      1.00      0.84        63
#
#     accuracy                           0.67       500
#    macro avg       0.70      0.67      0.66       500
# weighted avg       0.70      0.67      0.66       500
#
# AUC 0.9548
# loss: 0.81 acc: 0.67
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  7
# Epoch 1/7
# 141/140 [==============================] - 2s 18ms/step - loss: 1.3697 - accuracy: 0.4113
# Epoch 2/7
# 141/140 [==============================] - 2s 18ms/step - loss: 1.0481 - accuracy: 0.5316
# Epoch 3/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.9660 - accuracy: 0.5796
# Epoch 4/7
# 141/140 [==============================] - 3s 18ms/step - loss: 0.9547 - accuracy: 0.5851
# Epoch 5/7
# 141/140 [==============================] - 3s 18ms/step - loss: 0.8922 - accuracy: 0.6249
# Epoch 6/7
# 141/140 [==============================] - 3s 18ms/step - loss: 0.8679 - accuracy: 0.6496
# Epoch 7/7
# 141/140 [==============================] - 3s 18ms/step - loss: 0.8431 - accuracy: 0.6413
# Predictions Counter({3: 104, 0: 89, 7: 74, 4: 66, 2: 54, 6: 52, 1: 34, 5: 27})
#
# Confusion matrix
# [[32  0  2 28  0  0  0  0]
#  [ 2 25 14  0 18  3  0  0]
#  [15  3 31  7  0  7  0  0]
#  [ 5  0  1 55  0  2  0  0]
#  [ 2  6  4  0 46  3  1  0]
#  [33  0  2 14  2 12  0  0]
#  [ 0  0  0  0  0  0 49 14]
#  [ 0  0  0  0  0  0  2 60]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.36      0.52      0.42        62
#       STROMA       0.74      0.40      0.52        62
#      COMPLEX       0.57      0.49      0.53        63
#       LYMPHO       0.53      0.87      0.66        63
#       DEBRIS       0.70      0.74      0.72        62
#       MUCOSA       0.44      0.19      0.27        63
#      ADIPOSE       0.94      0.78      0.85        63
#        EMPTY       0.81      0.97      0.88        62
#
#     accuracy                           0.62       500
#    macro avg       0.64      0.62      0.61       500
# weighted avg       0.64      0.62      0.61       500
#
# AUC 0.9330
# loss: 1.02 acc: 0.62
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  7
# Epoch 1/7
# 141/140 [==============================] - 2s 18ms/step - loss: 1.3835 - accuracy: 0.3918
# Epoch 2/7
# 141/140 [==============================] - 2s 18ms/step - loss: 1.1074 - accuracy: 0.5364
# Epoch 3/7
# 141/140 [==============================] - 3s 18ms/step - loss: 1.0552 - accuracy: 0.5442
# Epoch 4/7
# 141/140 [==============================] - 2s 18ms/step - loss: 1.0289 - accuracy: 0.5744
# Epoch 5/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.9611 - accuracy: 0.5958
# Epoch 6/7
# 141/140 [==============================] - 3s 18ms/step - loss: 0.9729 - accuracy: 0.5951
# Epoch 7/7
# 141/140 [==============================] - 2s 18ms/step - loss: 0.9555 - accuracy: 0.6096
# Predictions Counter({0: 77, 7: 75, 3: 71, 2: 62, 1: 60, 5: 57, 6: 53, 4: 45})
#
# Confusion matrix
# ...
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9216 - accuracy: 0.6129
# Epoch 7/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8967 - accuracy: 0.6331
# Epoch 8/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8804 - accuracy: 0.6276
# Epoch 9/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8562 - accuracy: 0.6529
# Epoch 10/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8533 - accuracy: 0.6478
# Epoch 11/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8206 - accuracy: 0.6673
# Predictions Counter({3: 124, 5: 104, 7: 80, 1: 74, 6: 47, 4: 37, 2: 24, 0: 10})
#
# Confusion matrix
# [[ 9  0  1 45  0  8  0  0]
#  [ 0 39  3  0  9 12  0  0]
#  [ 0  7 19 12  2 22  0  0]
#  [ 1  0  0 50  0 11  0  0]
#  [ 0 27  1  0 25  8  2  0]
#  [ 0  1  0 17  1 43  0  0]
#  [ 0  0  0  0  0  0 45 17]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.90      0.14      0.25        63
#       STROMA       0.53      0.62      0.57        63
#      COMPLEX       0.79      0.31      0.44        62
#       LYMPHO       0.40      0.81      0.54        62
#       DEBRIS       0.68      0.40      0.50        63
#       MUCOSA       0.41      0.69      0.52        62
#      ADIPOSE       0.96      0.73      0.83        62
#        EMPTY       0.79      1.00      0.88        63
#
#     accuracy                           0.59       500
#    macro avg       0.68      0.59      0.57       500
# weighted avg       0.68      0.59      0.56       500
#
# AUC 0.9392
# loss: 1.06 acc: 0.59
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  11
# Epoch 1/11
# 141/140 [==============================] - 3s 19ms/step - loss: 1.3306 - accuracy: 0.4318
# Epoch 2/11
# 141/140 [==============================] - 3s 19ms/step - loss: 1.0497 - accuracy: 0.5551
# Epoch 3/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9769 - accuracy: 0.5771
# Epoch 4/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9714 - accuracy: 0.5887
# Epoch 5/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9107 - accuracy: 0.6247
# Epoch 6/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8548 - accuracy: 0.6444
# Epoch 7/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8863 - accuracy: 0.6300
# Epoch 8/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8073 - accuracy: 0.6722
# Epoch 9/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8442 - accuracy: 0.6551
# Epoch 10/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8109 - accuracy: 0.6764
# Epoch 11/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8369 - accuracy: 0.6618
# Predictions Counter({3: 110, 5: 78, 7: 76, 2: 67, 1: 60, 6: 49, 4: 44, 0: 16})
#
# Confusion matrix
# [[16  0  5 28  0 14  0  0]
#  [ 0 34 16  0 12  1  0  0]
#  [ 0  4 40 12  0  6  0  0]
#  [ 0  0  2 58  0  2  0  0]
#  [ 0 22  2  1 30  6  2  0]
#  [ 0  0  2 11  0 49  0  0]
#  [ 0  0  0  0  2  0 47 13]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       1.00      0.25      0.41        63
#       STROMA       0.57      0.54      0.55        63
#      COMPLEX       0.60      0.65      0.62        62
#       LYMPHO       0.53      0.94      0.67        62
#       DEBRIS       0.68      0.48      0.56        63
#       MUCOSA       0.63      0.79      0.70        62
#      ADIPOSE       0.96      0.76      0.85        62
#        EMPTY       0.83      1.00      0.91        63
#
#     accuracy                           0.67       500
#    macro avg       0.72      0.67      0.66       500
# weighted avg       0.72      0.67      0.66       500
#
# AUC 0.9541
# loss: 0.87 acc: 0.67
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  11
# Epoch 1/11
# 141/140 [==============================] - 3s 19ms/step - loss: 1.4556 - accuracy: 0.3773
# Epoch 2/11
# 141/140 [==============================] - 3s 19ms/step - loss: 1.0850 - accuracy: 0.5242
# Epoch 3/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9953 - accuracy: 0.5600
# Epoch 4/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9721 - accuracy: 0.5878
# Epoch 5/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9157 - accuracy: 0.6278
# Epoch 6/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8773 - accuracy: 0.6402
# Epoch 7/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8429 - accuracy: 0.6662
# Epoch 8/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8187 - accuracy: 0.6767
# Epoch 9/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8245 - accuracy: 0.6633
# Epoch 10/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.7903 - accuracy: 0.6729
# Epoch 11/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8182 - accuracy: 0.6604
# Predictions Counter({3: 106, 2: 97, 7: 70, 4: 60, 1: 54, 6: 46, 0: 35, 5: 32})
#
# Confusion matrix
# [[29  0  7 24  0  2  0  0]
#  [ 0 32 16  0 14  0  0  0]
#  [ 1  4 50  7  0  1  0  0]
#  [ 0  0  5 58  0  0  0  0]
#  [ 0 15  7  0 37  3  0  0]
#  [ 5  3 12 17  0 26  0  0]
#  [ 0  0  0  0  9  0 44 10]
#  [ 0  0  0  0  0  0  2 60]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.83      0.47      0.60        62
#       STROMA       0.59      0.52      0.55        62
#      COMPLEX       0.52      0.79      0.62        63
#       LYMPHO       0.55      0.92      0.69        63
#       DEBRIS       0.62      0.60      0.61        62
#       MUCOSA       0.81      0.41      0.55        63
#      ADIPOSE       0.96      0.70      0.81        63
#        EMPTY       0.86      0.97      0.91        62
#
#     accuracy                           0.67       500
#    macro avg       0.72      0.67      0.67       500
# weighted avg       0.72      0.67      0.67       500
#
# AUC 0.9556
# loss: 0.81 acc: 0.67
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  11
# Epoch 1/11
# 141/140 [==============================] - 3s 19ms/step - loss: 1.4311 - accuracy: 0.3884
# Epoch 2/11
# 141/140 [==============================] - 3s 19ms/step - loss: 1.0595 - accuracy: 0.5369
# Epoch 3/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9961 - accuracy: 0.5809
# Epoch 4/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9765 - accuracy: 0.5831
# Epoch 5/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9349 - accuracy: 0.6151
# Epoch 6/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9370 - accuracy: 0.6098
# Epoch 7/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9529 - accuracy: 0.6062
# Epoch 8/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8456 - accuracy: 0.6524
# Epoch 9/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8736 - accuracy: 0.6324
# Epoch 10/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8512 - accuracy: 0.6433
# Epoch 11/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8627 - accuracy: 0.6398
# Predictions Counter({3: 107, 4: 78, 7: 74, 5: 70, 6: 63, 2: 62, 0: 32, 1: 14})
#
# Confusion matrix
# [[24  0  0 33  0  5  0  0]
#  [ 0 12 10  0 31  7  2  0]
#  [ 4  0 47  4  1  7  0  0]
#  [ 3  0  2 54  0  4  0  0]
#  [ 0  1  2  0 43  5 11  0]
#  [ 1  1  1 16  2 42  0  0]
#  [ 0  0  0  0  1  0 50 12]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.75      0.39      0.51        62
#       STROMA       0.86      0.19      0.32        62
#      COMPLEX       0.76      0.75      0.75        63
#       LYMPHO       0.50      0.86      0.64        63
#       DEBRIS       0.55      0.69      0.61        62
#       MUCOSA       0.60      0.67      0.63        63
#      ADIPOSE       0.79      0.79      0.79        63
#        EMPTY       0.84      1.00      0.91        62
#
#     accuracy                           0.67       500
#    macro avg       0.71      0.67      0.65       500
# weighted avg       0.71      0.67      0.65       500
#
# AUC 0.9426
# loss: 0.95 acc: 0.67
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  11
# Epoch 1/11
# 141/140 [==============================] - 3s 19ms/step - loss: 1.2725 - accuracy: 0.4671
# Epoch 2/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9970 - accuracy: 0.5829
# Epoch 3/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9557 - accuracy: 0.5982
# Epoch 4/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9476 - accuracy: 0.6016
# Epoch 5/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9044 - accuracy: 0.6191
# Epoch 6/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8481 - accuracy: 0.6596
# Epoch 7/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8673 - accuracy: 0.6338
# Epoch 8/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8283 - accuracy: 0.6633
# Epoch 9/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8991 - accuracy: 0.6262
# Epoch 10/11
# 141/140 [==============================] - 3s 20ms/step - loss: 0.8269 - accuracy: 0.6653
# Epoch 11/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.7945 - accuracy: 0.6798
# Predictions Counter({3: 112, 5: 71, 4: 68, 2: 64, 7: 64, 6: 62, 1: 35, 0: 24})
#
# Confusion matrix
# [[17  0  2 31  0 12  0  0]
#  [ 0 25 19  0 14  4  0  0]
#  [ 3  4 39  4  4  9  0  0]
#  [ 2  0  0 60  0  1  0  0]
#  [ 0  6  4  0 47  3  2  0]
#  [ 2  0  0 17  2 42  0  0]
#  [ 0  0  0  0  1  0 59  3]
#  [ 0  0  0  0  0  0  1 61]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.71      0.27      0.40        62
#       STROMA       0.71      0.40      0.52        62
#      COMPLEX       0.61      0.62      0.61        63
#       LYMPHO       0.54      0.95      0.69        63
#       DEBRIS       0.69      0.76      0.72        62
#       MUCOSA       0.59      0.67      0.63        63
#      ADIPOSE       0.95      0.94      0.94        63
#        EMPTY       0.95      0.98      0.97        62
#
#     accuracy                           0.70       500
#    macro avg       0.72      0.70      0.68       500
# weighted avg       0.72      0.70      0.68       500
#
# AUC 0.9463
# loss: 0.93 acc: 0.70
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  11
# Epoch 1/11
# 141/140 [==============================] - 3s 20ms/step - loss: 1.4096 - accuracy: 0.3833
# Epoch 2/11
# 141/140 [==============================] - 3s 20ms/step - loss: 1.0427 - accuracy: 0.5369
# Epoch 3/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9714 - accuracy: 0.5827
# Epoch 4/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9367 - accuracy: 0.6018
# Epoch 5/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8790 - accuracy: 0.6324
# Epoch 6/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8950 - accuracy: 0.6242
# Epoch 7/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8711 - accuracy: 0.6407
# Epoch 8/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8259 - accuracy: 0.6591
# Epoch 9/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8591 - accuracy: 0.6500
# Epoch 10/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.7984 - accuracy: 0.6716
# Epoch 11/11
# 141/140 [==============================] - 3s 20ms/step - loss: 0.8172 - accuracy: 0.6651
# Predictions Counter({5: 86, 2: 79, 3: 67, 7: 67, 4: 61, 6: 58, 0: 41, 1: 41})
#
# Confusion matrix
# [[32  0  4 15  0 11  0  0]
#  [ 0 28 17  0 14  3  0  0]
#  [ 0  7 48  1  1  6  0  0]
#  [ 6  0  4 47  0  6  0  0]
#  [ 0  6  6  0 43  5  1  1]
#  [ 3  0  0  4  1 55  0  0]
#  [ 0  0  0  0  2  0 57  4]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.78      0.52      0.62        62
#       STROMA       0.68      0.45      0.54        62
#      COMPLEX       0.61      0.76      0.68        63
#       LYMPHO       0.70      0.75      0.72        63
#       DEBRIS       0.70      0.69      0.70        62
#       MUCOSA       0.64      0.87      0.74        63
#      ADIPOSE       0.98      0.90      0.94        63
#        EMPTY       0.93      1.00      0.96        62
#
#     accuracy                           0.74       500
#    macro avg       0.75      0.74      0.74       500
# weighted avg       0.75      0.74      0.74       500
#
# AUC 0.9631
# loss: 0.71 acc: 0.74
# Before  4500
# Y TRAIN [4 5 5 ... 0 0 0]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  11
# Epoch 1/11
# 141/140 [==============================] - 3s 20ms/step - loss: 1.3783 - accuracy: 0.4011
# Epoch 2/11
# 141/140 [==============================] - 3s 20ms/step - loss: 1.0689 - accuracy: 0.5324
# Epoch 3/11
# 141/140 [==============================] - 3s 20ms/step - loss: 0.9948 - accuracy: 0.5738
# Epoch 4/11
# 141/140 [==============================] - 3s 20ms/step - loss: 0.9724 - accuracy: 0.5844
# Epoch 5/11
# 141/140 [==============================] - 3s 20ms/step - loss: 0.9344 - accuracy: 0.6000
# Epoch 6/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.9045 - accuracy: 0.6284
# Epoch 7/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8695 - accuracy: 0.6456
# Epoch 8/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8423 - accuracy: 0.6551
# Epoch 9/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8317 - accuracy: 0.6658
# Epoch 10/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.7871 - accuracy: 0.6793
# Epoch 11/11
# 141/140 [==============================] - 3s 19ms/step - loss: 0.8018 - accuracy: 0.6624
# Predictions Counter({3: 106, 4: 85, 7: 78, 2: 56, 1: 55, 5: 54, 6: 47, 0: 19})
#
# Confusion matrix
# [[19  2  7 25  0  9  0  0]
#  [ 0 32  6  0 23  1  0  0]
#  [ 0 15 37  6  4  1  0  0]
#  [ 0  0  2 61  0  0  0  0]
#  [ 0  3  0  0 55  4  0  0]
#  [ 0  3  4 14  3 39  0  0]
#  [ 0  0  0  0  0  0 47 16]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       1.00      0.31      0.47        62
#       STROMA       0.58      0.52      0.55        62
#      COMPLEX       0.66      0.59      0.62        63
#       LYMPHO       0.58      0.97      0.72        63
#       DEBRIS       0.65      0.89      0.75        62
#       MUCOSA       0.72      0.62      0.67        63
#      ADIPOSE       1.00      0.75      0.85        63
#        EMPTY       0.79      1.00      0.89        62
#
#     accuracy                           0.70       500
#    macro avg       0.75      0.70      0.69       500
# weighted avg       0.75      0.70      0.69       500
#
# AUC 0.9691
# loss: 0.72 acc: 0.70
# The media value acc is   0.6680000007152558 And the value auc is  0.9551204713545667 And the activation epoch is  11
# VALUES ACC  0.0 0.005062032126267864
# VALUES AUC  1.0 0.0069104298078147995
# AND WITH THE OPTIMIZER adam
# THE BEST MODEL IS  ['relu', 'relu', 'relu', 'relu', 'softmax']
# WITH A EPOCH_NUMBER OF  11  AND A BATCH SIZE OF  32
# BEST MEDIA AUC  0.9551204713545667
# BEST MEDIA ACC  0.6680000007152558
# AND WITH DATA_AUGMENTATION  True
# FIRST MODEL GRAPHIC

# %%
datagen = ImageDataGenerator(
  rotation_range=20,
  width_shift_range=0.5,
  height_shift_range=0.5,
  horizontal_flip=True)

# %%
def get_score(X_train, X_test, y_test, y_train_nn, y_test_nn, activation_function, optimizer , data_augmentation, batch_size , epochs, auc_per_fold, auc_percent_per_fold):
  

  print("The batch and the epoch are  ", batch_size, ", " , epochs)
  
  model = cnn_model(activation_function)
  
  model.compile(loss='categorical_crossentropy',optimizer=optimizer, metrics=['accuracy'])
  
  if data_augmentation == True:  
    datagen.fit(X_train)
    model.fit(datagen.flow(X_train, y_train_nn, batch_size=batch_size), steps_per_epoch=len(X_train) / batch_size, epochs=epochs)
  else: 
  
    early_stopping = EarlyStopping(monitor='val_loss', patience = 10)
    model.fit(X_train, y_train_nn , batch_size=batch_size ,validation_split = 0.1, verbose=2, callbacks=[early_stopping] )
  
  #model.fit(datagen.flow(X_train, y_train_nn, batch_size=batch_size), steps_per_epoch=len(X_train) / batch_size, epochs=epochs) #, callbacks=[early_stopping])
  loss, acc = model.evaluate(X_test, y_test_nn,verbose= 0)
  y_scores = model.predict(X_test) # Confidence prediction per class
  y_pred = y_scores.argmax(axis=1) # Select classes with most confidence prediction
  print('Predictions', collections.Counter(y_pred),'\n')

  print('Confusion matrix')
  print(metrics.confusion_matrix(y_test,y_pred),'\n')

  target_names = ['TUMOR', 'HEALTHY'] if nb_classes ==  2 else ['TUMOR','STROMA','COMPLEX','LYMPHO','DEBRIS','MUCOSA','ADIPOSE','EMPTY']

  print(metrics.classification_report(y_test, y_pred, target_names=target_names))
  if nb_classes ==  2:
    auc_per_fold.append(metrics.roc_auc_score(y_test, np.round(y_scores[:,1],2)))
    auc_percent_per_fold.append(metrics.roc_auc_score(y_test, np.round(y_scores[:,1],2))*100)
    print(f'AUC {metrics.roc_auc_score(y_test, np.round(y_scores[:,1],2)):.4f} ')
  else:
    auc_per_fold.append(metrics.roc_auc_score(y_test, y_scores, multi_class = "ovr"))
    auc_percent_per_fold.append(metrics.roc_auc_score(y_test, y_scores, multi_class = "ovr")*100)
    print(f'AUC {metrics.roc_auc_score(y_test, y_scores, multi_class = "ovr"):.4f} ')
 
  
  
  return loss, acc, auc_per_fold, auc_percent_per_fold, model

# %%
def balance_X_train(X_train, y_train): 
  X_train_0 = X_train[y_train[y_train == 0]].view()
 

  y_train_0 = y_train[y_train == 0].view()
  print("Getting the len of the arrays " , len(X_train_0) , " " , len(y_train_0))
  #print(y_train_0)
  size_to_add =X_train.shape[0]- 2*X_train_0.shape[0]
  print("The old size was " ,X_train_0.shape[0] )
  #Setting the x_train and the y_train to the balancing size
  #if size_to_add > 0:     
  for i in range(6):
    
    
    print("The shape is " ,X_train.shape)
    print(y_train)
    
    y_train = np.concatenate([ y_train_0 ,   y_train], axis= 0)
    X_train = np.concatenate([  X_train_0 , X_train] , axis =0) 
    if len(y_train[y_train==0]) > size_to_add:
      break
    
    
    
  print("The new size is " , X_train[y_train[y_train== 0]].shape[0])
  return X_train,y_train

# %%
full_test_X = []
full_test_Y = []

def cross_validation( k , activation_function , optimizer, data_augmentation ,batch_size_new, epochs_new):
  batch_size = batch_size_new
  epochs = epochs_new
  auc_per_fold = []
  auc_percent_per_fold = []
  acc_per_fold = []
  acc_percent_per_fold = []
  loss_per_fold = []
  kf = StratifiedKFold(n_splits=k )
  for train_index, test_index in kf.split(X,y): 
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    full_test_X.append(X_test)
    full_test_Y.append( y_test)
    print("Before " ,  X_train.shape[0])
    #Balancing the dataset if it's necessary (Solo cuando es 0 y 1 )
    if nb_classes ==2:
      X_train, y_train= balance_X_train(X_train , y_train);
    print("Y TRAIN" , y_train)
    print("After " ,  X_train[y_train[y_train == 0]].shape[0])
    # Convert integers to one-hot vector
    y_train_nn = keras.utils.to_categorical(y_train, nb_classes)
    y_test_nn = keras.utils.to_categorical(y_test, nb_classes)
    print(f'X_train {X_train.shape} X_test {X_test.shape}')
    print(f'y_train {y_train.shape} y_test {y_test.shape}')
    print(f'y_train_nn {y_train_nn.shape} y_test_nn {y_test_nn.shape}')
  
    actual_loss, actual_acc, auc_per_fold, auc_percent_per_fold, model= get_score(X_train, X_test, y_test, y_train_nn, y_test_nn , activation_function, optimizer, data_augmentation, batch_size_new, epochs_new , auc_per_fold , auc_percent_per_fold )
    
    print(f'loss: {actual_loss:.2f} acc: {actual_acc:.2f}')
    acc_per_fold.append(actual_acc)
    loss_per_fold.append(actual_loss)
    acc_percent_per_fold.append(actual_acc*100) #For getting the wilcoxon 
    
    
  return acc_per_fold, loss_per_fold, auc_per_fold, acc_percent_per_fold, auc_percent_per_fold, model
  #return X_train_output, X_test_output, y_test_nn_output, y_train_nn_output, y_test_output, y_train_output;

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

acc_per_fold, loss_per_fold, auc_per_fold, acc_percent_per_fold, auc_percent_per_fold, model = cross_validation(10 , ["relu", "relu" , "relu" , "relu", "softmax"] , 'adam' , True ,32 , 10 )
print(acc_per_fold)
print(loss_per_fold)
print("AUC PER FOLD " , auc_per_fold)
print(model.summary())
#loss, acc = get_score(X_train, X_test, y_train_nn, y_test_nn)
# Out:
# Before  4500
# Y TRAIN [7 7 6 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  10
# Epoch 1/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4450 - accuracy: 0.3893
# Epoch 2/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0186 - accuracy: 0.5593
# Epoch 3/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0018 - accuracy: 0.5733
# Epoch 4/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9312 - accuracy: 0.6098
# Epoch 5/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9065 - accuracy: 0.6251
# Epoch 6/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8534 - accuracy: 0.6480
# Epoch 7/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8691 - accuracy: 0.6424
# Epoch 8/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8168 - accuracy: 0.6642
# Epoch 9/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8312 - accuracy: 0.6669
# Epoch 10/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8262 - accuracy: 0.6713
# Predictions Counter({3: 126, 6: 122, 2: 100, 5: 58, 4: 37, 1: 30, 0: 22, 7: 5})
#
# Confusion matrix
# [[16  0  3 41  0  3  0  0]
#  [ 0 20 30  0 10  3  0  0]
#  [ 1  1 49  4  2  5  0  0]
#  [ 4  0  4 54  0  0  0  0]
#  [ 0  9 12  0 24 15  3  0]
#  [ 1  0  2 27  0 32  0  0]
#  [ 0  0  0  0  1  0 60  1]
#  [ 0  0  0  0  0  0 59  4]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.73      0.25      0.38        63
#       STROMA       0.67      0.32      0.43        63
#      COMPLEX       0.49      0.79      0.60        62
#       LYMPHO       0.43      0.87      0.57        62
#       DEBRIS       0.65      0.38      0.48        63
#       MUCOSA       0.55      0.52      0.53        62
#      ADIPOSE       0.49      0.97      0.65        62
#        EMPTY       0.80      0.06      0.12        63
#
#     accuracy                           0.52       500
#    macro avg       0.60      0.52      0.47       500
# weighted avg       0.60      0.52      0.47       500
#
# AUC 0.9312
# loss: 1.11 acc: 0.52
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  10
# Epoch 1/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5476 - accuracy: 0.3409
# Epoch 2/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0794 - accuracy: 0.5433
# Epoch 3/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0023 - accuracy: 0.5727
# Epoch 4/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9552 - accuracy: 0.5956
# Epoch 5/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9845 - accuracy: 0.5893
# Epoch 6/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9029 - accuracy: 0.6349
# Epoch 7/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8817 - accuracy: 0.6244
# Epoch 8/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8342 - accuracy: 0.6638
# Epoch 9/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8119 - accuracy: 0.6713
# Epoch 10/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.7970 - accuracy: 0.6731
# Predictions Counter({5: 93, 1: 84, 7: 74, 3: 74, 6: 57, 0: 45, 2: 43, 4: 30})
#
# Confusion matrix
# [[38  1  1 14  0  9  0  0]
#  [ 0 49  8  0  3  2  1  0]
#  [ 1  8 33  2  0 18  0  0]
#  [ 2  0  0 53  0  7  0  0]
#  [ 0 25  0  0 25  8  5  0]
#  [ 4  1  1  5  2 49  0  0]
#  [ 0  0  0  0  0  0 50 12]
#  [ 0  0  0  0  0  0  1 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.84      0.60      0.70        63
#       STROMA       0.58      0.78      0.67        63
#      COMPLEX       0.77      0.53      0.63        62
#       LYMPHO       0.72      0.85      0.78        62
#       DEBRIS       0.83      0.40      0.54        63
#       MUCOSA       0.53      0.79      0.63        62
#      ADIPOSE       0.88      0.81      0.84        62
#        EMPTY       0.84      0.98      0.91        63
#
#     accuracy                           0.72       500
#    macro avg       0.75      0.72      0.71       500
# weighted avg       0.75      0.72      0.71       500
#
# AUC 0.9641
# loss: 0.68 acc: 0.72
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  10
# Epoch 1/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4984 - accuracy: 0.3529
# Epoch 2/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1253 - accuracy: 0.5016
# Epoch 3/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0594 - accuracy: 0.5404
# Epoch 4/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0065 - accuracy: 0.5893
# Epoch 5/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9978 - accuracy: 0.5893
# Epoch 6/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9442 - accuracy: 0.6136
# Epoch 7/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9217 - accuracy: 0.6269
# Epoch 8/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9002 - accuracy: 0.6311
# Epoch 9/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9428 - accuracy: 0.6029
# Epoch 10/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8935 - accuracy: 0.6362
# Predictions Counter({2: 77, 4: 71, 3: 71, 0: 64, 7: 57, 6: 54, 1: 54, 5: 52})
#
# Confusion matrix
# [[44  0  0 12  0  7  0  0]
#  [ 0 33 16  0 14  0  0  0]
#  [ 3  3 47  3  1  5  0  0]
#  [ 7  0  3 50  0  2  0  0]
#  [ 0 18  3  0 40  2  0  0]
#  [10  0  8  6  2 36  0  0]
#  [ 0  0  0  0 14  0 47  1]
#  [ 0  0  0  0  0  0  7 56]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.69      0.70      0.69        63
#       STROMA       0.61      0.52      0.56        63
#      COMPLEX       0.61      0.76      0.68        62
#       LYMPHO       0.70      0.81      0.75        62
#       DEBRIS       0.56      0.63      0.60        63
#       MUCOSA       0.69      0.58      0.63        62
#      ADIPOSE       0.87      0.76      0.81        62
#        EMPTY       0.98      0.89      0.93        63
#
#     accuracy                           0.71       500
#    macro avg       0.72      0.71      0.71       500
# weighted avg       0.72      0.71      0.71       500
#
# AUC 0.9540
# loss: 0.79 acc: 0.71
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  10
# Epoch 1/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.3929 - accuracy: 0.4122
# Epoch 2/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0201 - accuracy: 0.5620
# Epoch 3/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9674 - accuracy: 0.6029
# Epoch 4/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9362 - accuracy: 0.5980
# Epoch 5/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8937 - accuracy: 0.6256
# Epoch 6/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8712 - accuracy: 0.6378
# Epoch 7/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8437 - accuracy: 0.6484
# Epoch 8/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8216 - accuracy: 0.6604
# Epoch 9/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8081 - accuracy: 0.6698
# Epoch 10/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.7937 - accuracy: 0.6698
# Predictions Counter({3: 109, 5: 73, 1: 72, 7: 69, 2: 66, 6: 50, 4: 36, 0: 25})
#
# Confusion matrix
# [[23  0  2 29  0  9  0  0]
#  [ 0 36 15  0  5  7  0  0]
#  [ 0  5 39 12  0  6  0  0]
#  [ 0  0  5 56  0  1  0  0]
#  [ 0 29  2  0 24  8  0  0]
#  [ 2  2  3 12  1 42  0  0]
#  [ 0  0  0  0  6  0 50  6]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.92      0.37      0.52        63
#       STROMA       0.50      0.57      0.53        63
#      COMPLEX       0.59      0.63      0.61        62
#       LYMPHO       0.51      0.90      0.65        62
#       DEBRIS       0.67      0.38      0.48        63
#       MUCOSA       0.58      0.68      0.62        62
#      ADIPOSE       1.00      0.81      0.89        62
#        EMPTY       0.91      1.00      0.95        63
#
#     accuracy                           0.67       500
#    macro avg       0.71      0.67      0.66       500
# weighted avg       0.71      0.67      0.66       500
#
# AUC 0.9538
# loss: 0.82 acc: 0.67
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  562
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  10
# Epoch 1/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.2995 - accuracy: 0.4307
# Epoch 2/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0196 - accuracy: 0.5536
# Epoch 3/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9516 - accuracy: 0.5831
# Epoch 4/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9525 - accuracy: 0.5927
# Epoch 5/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9136 - accuracy: 0.6076
# Epoch 6/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9235 - accuracy: 0.5980
# Epoch 7/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8879 - accuracy: 0.6293
# Epoch 8/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9113 - accuracy: 0.6111
# Epoch 9/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8627 - accuracy: 0.6262
# Epoch 10/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8431 - accuracy: 0.6522
# Predictions Counter({2: 104, 5: 71, 1: 67, 3: 66, 7: 64, 6: 60, 0: 34, 4: 34})
#
# Confusion matrix
# [[27  0  9 14  0 13  0  0]
#  [ 0 38 21  0  4  0  0  0]
#  [ 1  1 54  3  0  3  0  0]
#  [ 6  0  5 45  0  6  0  0]
#  [ 0 28  5  0 26  2  2  0]
#  [ 0  0 10  4  1 47  0  0]
#  [ 0  0  0  0  3  0 54  5]
#  [ 0  0  0  0  0  0  4 59]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.79      0.43      0.56        63
#       STROMA       0.57      0.60      0.58        63
#      COMPLEX       0.52      0.87      0.65        62
#       LYMPHO       0.68      0.73      0.70        62
#       DEBRIS       0.76      0.41      0.54        63
#       MUCOSA       0.66      0.76      0.71        62
#      ADIPOSE       0.90      0.87      0.89        62
#        EMPTY       0.92      0.94      0.93        63
#
#     accuracy                           0.70       500
#    macro avg       0.73      0.70      0.69       500
# weighted avg       0.73      0.70      0.69       500
#
# AUC 0.9531
# loss: 0.79 acc: 0.70
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  10
# Epoch 1/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4094 - accuracy: 0.3913
# Epoch 2/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0346 - accuracy: 0.5442
# Epoch 3/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9928 - accuracy: 0.5607
# Epoch 4/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9657 - accuracy: 0.5816
# Epoch 5/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9291 - accuracy: 0.6062
# Epoch 6/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9422 - accuracy: 0.5847
# Epoch 7/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9052 - accuracy: 0.6093
# Epoch 8/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8858 - accuracy: 0.6291
# Epoch 9/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8963 - accuracy: 0.6236
# Epoch 10/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8831 - accuracy: 0.6342
# Predictions Counter({3: 133, 1: 87, 7: 68, 6: 57, 5: 47, 4: 45, 2: 34, 0: 29})
#
# Confusion matrix
# [[17  1  1 42  0  1  0  0]
#  [ 0 52  3  0  6  1  0  0]
#  [ 8 11 27 11  0  6  0  0]
#  [ 1  0  1 59  0  2  0  0]
#  [ 0 23  1  0 35  2  1  0]
#  [ 3  0  1 21  3 35  0  0]
#  [ 0  0  0  0  1  0 54  8]
#  [ 0  0  0  0  0  0  2 60]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.59      0.27      0.37        62
#       STROMA       0.60      0.84      0.70        62
#      COMPLEX       0.79      0.43      0.56        63
#       LYMPHO       0.44      0.94      0.60        63
#       DEBRIS       0.78      0.56      0.65        62
#       MUCOSA       0.74      0.56      0.64        63
#      ADIPOSE       0.95      0.86      0.90        63
#        EMPTY       0.88      0.97      0.92        62
#
#     accuracy                           0.68       500
#    macro avg       0.72      0.68      0.67       500
# weighted avg       0.72      0.68      0.67       500
#
# AUC 0.9525
# loss: 0.82 acc: 0.68
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  10
# Epoch 1/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4819 - accuracy: 0.3667
# Epoch 2/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0479 - accuracy: 0.5416
# Epoch 3/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9849 - accuracy: 0.5711
# Epoch 4/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9594 - accuracy: 0.5833
# Epoch 5/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9642 - accuracy: 0.5771
# Epoch 6/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9692 - accuracy: 0.5849
# Epoch 7/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9164 - accuracy: 0.6058
# Epoch 8/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9291 - accuracy: 0.6031
# Epoch 9/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8808 - accuracy: 0.6276
# Epoch 10/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8194 - accuracy: 0.6718
# Predictions Counter({3: 84, 1: 81, 2: 71, 5: 69, 7: 67, 6: 58, 0: 38, 4: 32})
#
# Confusion matrix
# [[32  0  2 21  0  7  0  0]
#  [ 0 42 13  0  4  3  0  0]
#  [ 3  4 49  3  0  4  0  0]
#  [ 2  0  4 53  0  4  0  0]
#  [ 0 32  1  0 21  3  5  0]
#  [ 1  3  2  7  2 48  0  0]
#  [ 0  0  0  0  5  0 53  5]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.84      0.52      0.64        62
#       STROMA       0.52      0.68      0.59        62
#      COMPLEX       0.69      0.78      0.73        63
#       LYMPHO       0.63      0.84      0.72        63
#       DEBRIS       0.66      0.34      0.45        62
#       MUCOSA       0.70      0.76      0.73        63
#      ADIPOSE       0.91      0.84      0.88        63
#        EMPTY       0.93      1.00      0.96        62
#
#     accuracy                           0.72       500
#    macro avg       0.73      0.72      0.71       500
# weighted avg       0.73      0.72      0.71       500
#
# AUC 0.9590
# loss: 0.75 acc: 0.72
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  10
# Epoch 1/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5235 - accuracy: 0.3560
# Epoch 2/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0894 - accuracy: 0.5098
# Epoch 3/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0615 - accuracy: 0.5227
# Epoch 4/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9999 - accuracy: 0.5571
# Epoch 5/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9942 - accuracy: 0.5584
# Epoch 6/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9701 - accuracy: 0.5818
# Epoch 7/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9545 - accuracy: 0.5931
# Epoch 8/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9203 - accuracy: 0.6040
# Epoch 9/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8934 - accuracy: 0.6358
# Epoch 10/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8666 - accuracy: 0.6489
# Predictions Counter({5: 127, 7: 89, 4: 82, 3: 80, 6: 43, 2: 35, 1: 28, 0: 16})
#
# Confusion matrix
# [[13  0  2 24  0 23  0  0]
#  [ 0 23  7  0 25  7  0  0]
#  [ 3  5 25  0  6 24  0  0]
#  [ 0  0  0 53  0 10  0  0]
#  [ 0  0  1  0 49  5  7  0]
#  [ 0  0  0  3  2 58  0  0]
#  [ 0  0  0  0  0  0 36 27]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.81      0.21      0.33        62
#       STROMA       0.82      0.37      0.51        62
#      COMPLEX       0.71      0.40      0.51        63
#       LYMPHO       0.66      0.84      0.74        63
#       DEBRIS       0.60      0.79      0.68        62
#       MUCOSA       0.46      0.92      0.61        63
#      ADIPOSE       0.84      0.57      0.68        63
#        EMPTY       0.70      1.00      0.82        62
#
#     accuracy                           0.64       500
#    macro avg       0.70      0.64      0.61       500
# weighted avg       0.70      0.64      0.61       500
#
# AUC 0.9576
# loss: 0.89 acc: 0.64
# Before  4500
# Y TRAIN [4 5 5 ... 5 4 4]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  10
# Epoch 1/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.5250 - accuracy: 0.3404
# Epoch 2/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0602 - accuracy: 0.5333
# Epoch 3/10
# 141/140 [==============================] - 2s 16ms/step - loss: 1.0120 - accuracy: 0.5549
# Epoch 4/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9809 - accuracy: 0.5611
# Epoch 5/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9571 - accuracy: 0.5780
# Epoch 6/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9744 - accuracy: 0.5600
# Epoch 7/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9463 - accuracy: 0.5936
# Epoch 8/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.9216 - accuracy: 0.5969
# Epoch 9/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8712 - accuracy: 0.6398
# Epoch 10/10
# 141/140 [==============================] - 2s 15ms/step - loss: 0.8524 - accuracy: 0.6396
# Predictions Counter({3: 134, 7: 76, 2: 74, 1: 68, 5: 56, 6: 52, 4: 36, 0: 4})
#
# Confusion matrix
# [[ 4  1  1 48  0  8  0  0]
#  [ 0 37 18  0  6  1  0  0]
#  [ 0  8 46  8  0  1  0  0]
#  [ 0  0  4 58  0  1  0  0]
#  [ 0 22  5  0 27  4  3  1]
#  [ 0  0  0 20  2 41  0  0]
#  [ 0  0  0  0  1  0 49 13]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       1.00      0.06      0.12        62
#       STROMA       0.54      0.60      0.57        62
#      COMPLEX       0.62      0.73      0.67        63
#       LYMPHO       0.43      0.92      0.59        63
#       DEBRIS       0.75      0.44      0.55        62
#       MUCOSA       0.73      0.65      0.69        63
#      ADIPOSE       0.94      0.78      0.85        63
#        EMPTY       0.82      1.00      0.90        62
#
#     accuracy                           0.65       500
#    macro avg       0.73      0.65      0.62       500
# weighted avg       0.73      0.65      0.62       500
#
# AUC 0.9583
# loss: 0.86 acc: 0.65
# Before  4500
# Y TRAIN [4 5 5 ... 0 0 0]
# After  563
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)
# y_train_nn (4500, 8) y_test_nn (500, 8)
# The batch and the epoch are   32 ,  10
# Epoch 1/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.4623 - accuracy: 0.3618
# Epoch 2/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.1091 - accuracy: 0.5193
# Epoch 3/10
# 141/140 [==============================] - 2s 15ms/step - loss: 1.0308 - accuracy: 0.5720
# Epoch 4/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9986 - accuracy: 0.5769
# Epoch 5/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9631 - accuracy: 0.5916
# Epoch 6/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9294 - accuracy: 0.6171
# Epoch 7/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.9094 - accuracy: 0.6289
# Epoch 8/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8810 - accuracy: 0.6371
# Epoch 9/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8663 - accuracy: 0.6387
# Epoch 10/10
# 141/140 [==============================] - 2s 16ms/step - loss: 0.8197 - accuracy: 0.6731
# Predictions Counter({3: 130, 7: 78, 2: 75, 5: 66, 6: 46, 4: 45, 1: 39, 0: 21})
#
# Confusion matrix
# [[15  0  1 41  0  5  0  0]
#  [ 0 18 28  0 10  6  0  0]
#  [ 1  1 36 13  3  9  0  0]
#  [ 2  0  1 59  0  1  0  0]
#  [ 0 19  7  0 29  7  0  0]
#  [ 3  1  2 17  2 38  0  0]
#  [ 0  0  0  0  1  0 46 16]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.71      0.24      0.36        62
#       STROMA       0.46      0.29      0.36        62
#      COMPLEX       0.48      0.57      0.52        63
#       LYMPHO       0.45      0.94      0.61        63
#       DEBRIS       0.64      0.47      0.54        62
#       MUCOSA       0.58      0.60      0.59        63
#      ADIPOSE       1.00      0.73      0.84        63
#        EMPTY       0.79      1.00      0.89        62
#
#     accuracy                           0.61       500
#    macro avg       0.64      0.61      0.59       500
# weighted avg       0.64      0.61      0.59       500
#
# AUC 0.9485
# loss: 0.92 acc: 0.61
# [0.5180000066757202, 0.7179999947547913, 0.7059999704360962, 0.6660000085830688, 0.699999988079071, 0.6779999732971191, 0.7200000286102295, 0.6380000114440918, 0.6480000019073486, 0.6060000061988831]
# [1.1105799674987793, 0.6830612421035767, 0.7914034128189087, 0.8210502862930298, 0.7930273413658142, 0.8195599913597107, 0.7453043460845947, 0.8859900236129761, 0.8645588755607605, 0.9249343872070312]
# AUC PER FOLD  [0.9311863708877695, 0.9640750696643688, 0.9539655583567204, 0.9537800210129093, 0.9530562948097893, 0.9525006282637756, 0.9589703256697593, 0.9575606846549536, 0.9582769287328743, 0.9485185752242364]
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, None, None, 6)     456
# _________________________________________________________________
# activation_45 (Activation)   (None, None, None, 6)     0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, None, None, 6)     0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, None, None, 16)    2416
# _________________________________________________________________
# activation_46 (Activation)   (None, None, None, 16)    0
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, None, None, 16)    0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, None)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 120)               48120
# _________________________________________________________________
# activation_47 (Activation)   (None, 120)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 84)                10164
# _________________________________________________________________
# activation_48 (Activation)   (None, 84)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 8)                 680
# _________________________________________________________________
# activation_49 (Activation)   (None, 8)                 0
# =================================================================
# Total params: 61,836
# Trainable params: 61,836
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def get_graphic_plot():
  plt.plot(range(len( acc_percent_per_fold)) , acc_percent_per_fold , 'ro-',label='acc_x')
  plt.ylabel('Aciertos')
  plt.xlabel('Prueba')
  plt.legend()

# %%
get_graphic_plot()

# %% [markdown]
# #WILCOXON

# %%
def wilcoxon(x,y):
  wilcox_V, p_value =  wilcoxon(x, y, alternative='greater', zero_method='wilcox', correction=False)
  print('Resultado completo del test de Wilcoxon')
  print(f'Wilcox V: {wilcox_V}, p-value: {p_value:.2f}')
  return x, y

# %% [markdown]
# ### Model and optimizers

# %% [markdown]
# Test [optimizer](https://keras.io/optimizers/) parameter with `sgd`, `adadelta` or `adam` values in order to check the final precision achieved.

# %%
print(f'loss: {loss:.2f} acc: {acc:.2f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-dc262fa8d9e2> in <module>()
# ----> 1 print(f'loss: {loss:.2f} acc: {acc:.2f}')
#
# NameError: name 'loss' is not defined

# %%
print(model.summary())
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, None, None, 6)     456
# _________________________________________________________________
# activation_45 (Activation)   (None, None, None, 6)     0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, None, None, 6)     0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, None, None, 16)    2416
# _________________________________________________________________
# activation_46 (Activation)   (None, None, None, 16)    0
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, None, None, 16)    0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, None)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 120)               48120
# _________________________________________________________________
# activation_47 (Activation)   (None, 120)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 84)                10164
# _________________________________________________________________
# activation_48 (Activation)   (None, 84)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 8)                 680
# _________________________________________________________________
# activation_49 (Activation)   (None, 8)                 0
# =================================================================
# Total params: 61,836
# Trainable params: 61,836
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Testing AUC result for two and multiple classes

# %%
for i in range(len(full_test_X)):

  y_scores = model.predict(full_test_X[i]) # Confidence prediction per class
  y_pred = y_scores.argmax(axis=1) # Select classes with most confidence prediction

  if nb_classes ==  2:
    print(f'AUC {metrics.roc_auc_score(full_test_Y[i], np.round(y_scores[:,1],2)):.4f} ')
  else:
    print(f'AUC {metrics.roc_auc_score(full_test_Y[i], y_scores, multi_class = "ovr"):.4f} ')
# Out:
# AUC 0.9440
# AUC 0.9510
# AUC 0.9473
# AUC 0.9459
# AUC 0.9440
# AUC 0.9449
# AUC 0.9467
# AUC 0.9506
# AUC 0.9474
# AUC 0.9485

# %% [markdown]
# ## More metrics about results

# %% [markdown]
# We can find more information about `precision`, `recall` and `f1` metrics in <https://en.wikipedia.org/wiki/Precision_and_recall>.

# %%
for i in range(len(full_test_X)):
  y_scores = model.predict(full_test_X[i]) # Confidence prediction per class
  y_pred = y_scores.argmax(axis=1) # Select classes with most confidence prediction

  if nb_classes ==  2:
    print(f'AUC {metrics.roc_auc_score(full_test_Y[i], np.round(y_scores[:,1],2)):.4f} ')
  else:
    print(f'AUC {metrics.roc_auc_score(full_test_Y[i], y_scores, multi_class = "ovr"):.4f} ')
  print('Predictions', collections.Counter(y_pred),'\n')

  print('Confusion matrix')
  print(metrics.confusion_matrix(full_test_Y[i],y_pred),'\n')

  target_names = ['TUMOR', 'HEALTHY'] if nb_classes ==  2 else ['TUMOR','STROMA','COMPLEX','LYMPHO','DEBRIS','MUCOSA','ADIPOSE','EMPTY']

  print(metrics.classification_report(full_test_Y[i], y_pred, target_names=target_names))
# Out:
# AUC 0.9440
# Predictions Counter({3: 118, 5: 82, 7: 77, 2: 72, 6: 50, 4: 39, 1: 35, 0: 27})
#
# Confusion matrix
# [[22  0  2 31  0  8  0  0]
#  [ 0 16 27  0  9 11  0  0]
#  [ 1  1 33 15  2 10  0  0]
#  [ 2  0  3 57  0  0  0  0]
#  [ 0 18  6  0 25 11  3  0]
#  [ 2  0  1 15  2 42  0  0]
#  [ 0  0  0  0  1  0 47 14]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.81      0.35      0.49        63
#       STROMA       0.46      0.25      0.33        63
#      COMPLEX       0.46      0.53      0.49        62
#       LYMPHO       0.48      0.92      0.63        62
#       DEBRIS       0.64      0.40      0.49        63
#       MUCOSA       0.51      0.68      0.58        62
#      ADIPOSE       0.94      0.76      0.84        62
#        EMPTY       0.82      1.00      0.90        63
#
#     accuracy                           0.61       500
#    macro avg       0.64      0.61      0.59       500
# weighted avg       0.64      0.61      0.59       500
#
# AUC 0.9510
# Predictions Counter({3: 121, 5: 83, 2: 79, 7: 70, 6: 53, 4: 43, 1: 31, 0: 20})
#
# Confusion matrix
# [[19  0  0 34  0 10  0  0]
#  [ 0 16 29  0  7 11  0  0]
#  [ 0  0 45 10  1  6  0  0]
#  [ 0  0  0 58  0  4  0  0]
#  [ 0 15  3  0 32 12  1  0]
#  [ 1  0  2 19  0 40  0  0]
#  [ 0  0  0  0  2  0 52  8]
#  [ 0  0  0  0  1  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.95      0.30      0.46        63
#       STROMA       0.52      0.25      0.34        63
#      COMPLEX       0.57      0.73      0.64        62
#       LYMPHO       0.48      0.94      0.63        62
#       DEBRIS       0.74      0.51      0.60        63
#       MUCOSA       0.48      0.65      0.55        62
#      ADIPOSE       0.98      0.84      0.90        62
#        EMPTY       0.89      0.98      0.93        63
#
#     accuracy                           0.65       500
#    macro avg       0.70      0.65      0.63       500
# weighted avg       0.70      0.65      0.63       500
#
# AUC 0.9473
# Predictions Counter({3: 127, 2: 77, 7: 68, 5: 66, 6: 58, 4: 45, 1: 30, 0: 29})
#
# Confusion matrix
# [[25  0  0 32  0  6  0  0]
#  [ 0 17 28  0  7 10  1  0]
#  [ 0  0 42 12  1  7  0  0]
#  [ 1  0  1 58  0  2  0  0]
#  [ 0 13  6  1 35  7  1  0]
#  [ 3  0  0 24  1 34  0  0]
#  [ 0  0  0  0  1  0 53  8]
#  [ 0  0  0  0  0  0  3 60]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.86      0.40      0.54        63
#       STROMA       0.57      0.27      0.37        63
#      COMPLEX       0.55      0.68      0.60        62
#       LYMPHO       0.46      0.94      0.61        62
#       DEBRIS       0.78      0.56      0.65        63
#       MUCOSA       0.52      0.55      0.53        62
#      ADIPOSE       0.91      0.85      0.88        62
#        EMPTY       0.88      0.95      0.92        63
#
#     accuracy                           0.65       500
#    macro avg       0.69      0.65      0.64       500
# weighted avg       0.69      0.65      0.64       500
#
# AUC 0.9459
# Predictions Counter({3: 120, 2: 78, 7: 74, 5: 68, 6: 48, 4: 44, 1: 38, 0: 30})
#
# Confusion matrix
# [[26  0  2 31  0  4  0  0]
#  [ 0 16 29  0 10  8  0  0]
#  [ 1  3 35 17  0  6  0  0]
#  [ 1  0  2 56  0  3  0  0]
#  [ 0 18  7  0 29  8  1  0]
#  [ 2  1  3 16  1 39  0  0]
#  [ 0  0  0  0  4  0 47 11]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.87      0.41      0.56        63
#       STROMA       0.42      0.25      0.32        63
#      COMPLEX       0.45      0.56      0.50        62
#       LYMPHO       0.47      0.90      0.62        62
#       DEBRIS       0.66      0.46      0.54        63
#       MUCOSA       0.57      0.63      0.60        62
#      ADIPOSE       0.98      0.76      0.85        62
#        EMPTY       0.85      1.00      0.92        63
#
#     accuracy                           0.62       500
#    macro avg       0.66      0.62      0.61       500
# weighted avg       0.66      0.62      0.61       500
#
# AUC 0.9440
# Predictions Counter({3: 121, 7: 76, 5: 75, 2: 75, 4: 51, 6: 50, 0: 28, 1: 24})
#
# Confusion matrix
# [[21  0  2 32  0  8  0  0]
#  [ 0 13 28  0 12 10  0  0]
#  [ 1  0 37 15  1  8  0  0]
#  [ 2  0  2 56  0  2  0  0]
#  [ 0 11  6  1 36  7  2  0]
#  [ 4  0  0 17  1 40  0  0]
#  [ 0  0  0  0  1  0 48 13]
#  [ 0  0  0  0  0  0  0 63]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.75      0.33      0.46        63
#       STROMA       0.54      0.21      0.30        63
#      COMPLEX       0.49      0.60      0.54        62
#       LYMPHO       0.46      0.90      0.61        62
#       DEBRIS       0.71      0.57      0.63        63
#       MUCOSA       0.53      0.65      0.58        62
#      ADIPOSE       0.96      0.77      0.86        62
#        EMPTY       0.83      1.00      0.91        63
#
#     accuracy                           0.63       500
#    macro avg       0.66      0.63      0.61       500
# weighted avg       0.66      0.63      0.61       500
#
# AUC 0.9449
# Predictions Counter({3: 123, 5: 75, 2: 72, 7: 71, 4: 54, 6: 49, 0: 29, 1: 27})
#
# Confusion matrix
# [[23  0  2 32  0  5  0  0]
#  [ 0 11 31  0 14  6  0  0]
#  [ 2  1 33 16  1 10  0  0]
#  [ 0  0  1 60  0  2  0  0]
#  [ 0 15  5  0 32 10  0  0]
#  [ 4  0  0 15  2 42  0  0]
#  [ 0  0  0  0  5  0 47 11]
#  [ 0  0  0  0  0  0  2 60]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.79      0.37      0.51        62
#       STROMA       0.41      0.18      0.25        62
#      COMPLEX       0.46      0.52      0.49        63
#       LYMPHO       0.49      0.95      0.65        63
#       DEBRIS       0.59      0.52      0.55        62
#       MUCOSA       0.56      0.67      0.61        63
#      ADIPOSE       0.96      0.75      0.84        63
#        EMPTY       0.85      0.97      0.90        62
#
#     accuracy                           0.62       500
#    macro avg       0.64      0.62      0.60       500
# weighted avg       0.64      0.62      0.60       500
#
# AUC 0.9467
# Predictions Counter({3: 131, 7: 75, 2: 74, 5: 73, 4: 50, 6: 48, 0: 25, 1: 24})
#
# Confusion matrix
# [[24  0  0 34  0  4  0  0]
#  [ 0 13 24  0 14 11  0  0]
#  [ 0  0 39 17  1  6  0  0]
#  [ 1  0  3 58  0  1  0  0]
#  [ 0 11  7  0 28 12  4  0]
#  [ 0  0  1 22  1 39  0  0]
#  [ 0  0  0  0  6  0 44 13]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.96      0.39      0.55        62
#       STROMA       0.54      0.21      0.30        62
#      COMPLEX       0.53      0.62      0.57        63
#       LYMPHO       0.44      0.92      0.60        63
#       DEBRIS       0.56      0.45      0.50        62
#       MUCOSA       0.53      0.62      0.57        63
#      ADIPOSE       0.92      0.70      0.79        63
#        EMPTY       0.83      1.00      0.91        62
#
#     accuracy                           0.61       500
#    macro avg       0.66      0.61      0.60       500
# weighted avg       0.66      0.61      0.60       500
#
# AUC 0.9506
# Predictions Counter({3: 116, 5: 80, 2: 79, 7: 72, 4: 52, 6: 51, 1: 29, 0: 21})
#
# Confusion matrix
# [[17  0  3 27  0 15  0  0]
#  [ 0 13 34  0  9  6  0  0]
#  [ 2  2 38 11  2  8  0  0]
#  [ 1  0  0 61  0  1  0  0]
#  [ 0 14  3  0 37  7  1  0]
#  [ 1  0  1 17  1 43  0  0]
#  [ 0  0  0  0  3  0 50 10]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.81      0.27      0.41        62
#       STROMA       0.45      0.21      0.29        62
#      COMPLEX       0.48      0.60      0.54        63
#       LYMPHO       0.53      0.97      0.68        63
#       DEBRIS       0.71      0.60      0.65        62
#       MUCOSA       0.54      0.68      0.60        63
#      ADIPOSE       0.98      0.79      0.88        63
#        EMPTY       0.86      1.00      0.93        62
#
#     accuracy                           0.64       500
#    macro avg       0.67      0.64      0.62       500
# weighted avg       0.67      0.64      0.62       500
#
# AUC 0.9474
# Predictions Counter({3: 117, 2: 91, 5: 82, 7: 76, 6: 51, 4: 34, 1: 30, 0: 19})
#
# Confusion matrix
# [[14  0  2 36  0 10  0  0]
#  [ 0 10 34  0  7 11  0  0]
#  [ 0  2 45  7  0  9  0  0]
#  [ 1  0  4 56  0  2  0  0]
#  [ 0 18  6  0 25 10  2  1]
#  [ 4  0  0 18  1 40  0  0]
#  [ 0  0  0  0  1  0 49 13]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.74      0.23      0.35        62
#       STROMA       0.33      0.16      0.22        62
#      COMPLEX       0.49      0.71      0.58        63
#       LYMPHO       0.48      0.89      0.62        63
#       DEBRIS       0.74      0.40      0.52        62
#       MUCOSA       0.49      0.63      0.55        63
#      ADIPOSE       0.96      0.78      0.86        63
#        EMPTY       0.82      1.00      0.90        62
#
#     accuracy                           0.60       500
#    macro avg       0.63      0.60      0.58       500
# weighted avg       0.63      0.60      0.58       500
#
# AUC 0.9485
# Predictions Counter({3: 130, 7: 78, 2: 75, 5: 66, 6: 46, 4: 45, 1: 39, 0: 21})
#
# Confusion matrix
# [[15  0  1 41  0  5  0  0]
#  [ 0 18 28  0 10  6  0  0]
#  [ 1  1 36 13  3  9  0  0]
#  [ 2  0  1 59  0  1  0  0]
#  [ 0 19  7  0 29  7  0  0]
#  [ 3  1  2 17  2 38  0  0]
#  [ 0  0  0  0  1  0 46 16]
#  [ 0  0  0  0  0  0  0 62]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.71      0.24      0.36        62
#       STROMA       0.46      0.29      0.36        62
#      COMPLEX       0.48      0.57      0.52        63
#       LYMPHO       0.45      0.94      0.61        63
#       DEBRIS       0.64      0.47      0.54        62
#       MUCOSA       0.58      0.60      0.59        63
#      ADIPOSE       1.00      0.73      0.84        63
#        EMPTY       0.79      1.00      0.89        62
#
#     accuracy                           0.61       500
#    macro avg       0.64      0.61      0.59       500
# weighted avg       0.64      0.61      0.59       500
